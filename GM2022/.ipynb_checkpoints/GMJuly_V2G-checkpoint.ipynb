# %%
import pybamm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
import dfols
import signal
from scipy.integrate import solve_ivp
from scipy.fft import fft, fftfreq, fftshift
from scipy.signal import savgol_filter
from scipy.signal import find_peaks
from scipy import interpolate
from stopit import threading_timeoutable as timeoutable
import os, sys
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath("__file__"))))
from stopit import threading_timeoutable as timeoutable
from batfuns import *
plt.rcParams = set_rc_params(plt.rcParams)
eSOH_DIR = f"F:/Git Hub rep/PyBaMM/UMBLFeb2022/data/esoh/"
oCV_DIR = f"F:/Git Hub rep/PyBaMM/UMBLFeb2022/data/ocv/"
fig_DIR = "../figures/figures_fit/"
res_DIR = "../data/results_fit/"
# %matplotlib widget

# %%
parameter_values = get_parameter_values()

# %%
parameter_values.search("plating")
# Out:
# Exchange-current density for plating [A.m-2]	<function plating_exchange_current_density_Mohtat2020 at 0x000001FDD6C9F820>
# Li plating open-circuit potential [V]	0.05
# Lithium plating kinetic rate constant [m.s-1]	1e-09
# Lithium plating transfer coefficient	0.65

# %%
spm = pybamm.lithium_ion.SPM(
    {
        "SEI": "ec reaction limited",
        # "loss of active material": ("stress-driven","none"),
        "loss of active material": "stress-driven",
        # "stress-induced diffusion": "true",
        "lithium plating": "irreversible",
        "calculate discharge energy":"true"
    }
)

# %%
# spm.print_parameter_info()
param=spm.param
parameter_values.update(
    {
    "Electrode width [m]":0.1,
#     "Maximum concentration in negative electrode [mol.m-3]":30000,
       "Nominal cell capacity [A.h]":2.5,
        "Maximum concentration in positive electrode [mol.m-3]":37500,
        
        "Positive electrode thickness [m]":5.45e-05,

        
        
    }
)
cell = 152002

# %%
cell_no,dfe,dfe_0,dfo_0,N,N_0 = load_data(cell,eSOH_DIR,oCV_DIR)
eps_n_data,eps_p_data,c_rate_c,c_rate_d,dis_set,Temp,SOC_0 = init_exp(cell_no,dfe,spm,parameter_values)
# Temp
# cell_no,dfe,N,dfo_0 = load_data_calendar(cell,eSOH_DIR,oCV_DIR)
# eps_n_data,eps_p_data,SOC_0,Temp = init_exp_calendar(cell_no,dfe,param,parameter_values)
Temp=45

# %%
#experimets
# pybamm.set_logging_level("WARNING")
pybamm.set_logging_level("NOTICE")


# drive_cycle = pd.read_csv(r"F:\Stefanapolu application\CRC\Drive Cycle\US06_default_5Ah.csv", comment="#", header=None).to_numpy()
# drive_cycle = pd.read_csv(r"F:\Stefanapolu application\CRC\Drive Cycle\US06_default_5A_norgen10_min.csv", comment="#", header=None).to_numpy()

# drive_cycle2 = pd.read_csv(r"F:\Stefanapolu application\CRC\Drive Cycle\US06_GM_5Ah.csv", comment="#", header=None).to_numpy()
drive_cycle_OEM1 = pd.read_csv(r"F:\Stefanapolu application\CRC\Drive Cycle\US06_GM_2_5Ah_norgen10_min.csv", comment="#", header=None).to_numpy()
Created_Drive = pd.read_csv(r"F:\Stefanapolu application\CRC\Drive Cycle\Created_Drive_2_5Ah.csv", comment="#", header=None).to_numpy()


experiment3 = pybamm.Experiment( #GM_ DRC-DRC
    [
        ("Run US06_OEM1 (A) for 1 hours",
         "Rest for 5 minutes",
         "Discharge at C/4 for 1 hours", # should be P/4 
         "Rest for 5 minutes",
         "Charge at C/4 until 4.2V",
         "Hold at 4.2V for .6 hours",  # needs fixing : last step +this step =2.5 hrs
         "Rest for 20 minutes", 
         # Home
         "Run US06_OEM1 (A) for 1 hours",
         "Rest for 5 minutes",
         "Discharge at C/4 for 1 hours", # should be P/4 
         "Rest for 5 minutes",
         "Charge at C/8 until 4.2V",
          "Hold at 4.2V for 1 hours",  # needs fixing : last step +this step =4.5 hrs
         "Rest for 20 minutes",     
        )

    ]*1000,
    drive_cycles={"US06_OEM1": drive_cycle_OEM1},
    termination="50% capacity",
#     cccv_handling="ode",
)

experiment4 = pybamm.Experiment( #Gm-RCRC
    [
        ("Run US06_OEM1 (A) for 1 hours",
         "Rest for 5 minutes",
         "Rest for 1 hours", # should be P/4 
         "Rest for 5 minutes",
         "Charge at C/4 until 4.2V",
         "Hold at 4.2V for 1.6 hours",  # needs fixing : last step +this step =2.5 hrs
         "Rest for 20 minutes", 
         # Home
         "Run US06_OEM1 (A) for 1 hours",
         "Rest for 5 minutes",
         "Rest for 1 hours", # should be P/4 
         "Rest for 5 minutes",
         "Charge at C/8 until 4.2V",
          "Hold at 4.2V for 3.1 hours",  # needs fixing : last step +this step =4.5 hrs
         "Rest for 20 minutes",     
        )

    ]*1000,
    drive_cycles={"US06_OEM1": drive_cycle_OEM1},
    termination="50% capacity",
#     cccv_handling="ode",
)

experiment13 = pybamm.Experiment( #Created_ DRC-DRC
    [
        ("Run Creeted_Drive (A) for 1 hours",
         "Rest for 5 minutes",
         "Discharge at C/4 for 1 hours", # should be P/4 
         "Rest for 5 minutes",
         "Charge at C/4 until 4.2V",
         "Hold at 4.2V for .7 hours",  # needs fixing : last step +this step =2.5 hrs
         "Rest for 20 minutes", 
         # Home
         "Run Creeted_Drive (A) for 1 hours",
         "Rest for 5 minutes",
         "Discharge at C/4 for 1 hours", # should be P/4 
         "Rest for 5 minutes",
         "Charge at C/8 until 4.2V",
          "Hold at 4.2V for 1.1 hours",  # needs fixing : last step +this step =4.5 hrs
         "Rest for 20 minutes",     
        )

    ]*900,
    drive_cycles={"Creeted_Drive": Created_Drive},
    termination="50% capacity",
#     cccv_handling="ode",
)

experiment14 = pybamm.Experiment( #Creeted-RCRC
    [
        ("Run Creeted_Drive (A) for 1 hours",
         "Rest for 5 minutes",
         "Rest for 1 hours", # should be P/4 
         "Rest for 5 minutes",
         "Charge at C/4 until 4.2V",
         "Hold at 4.2V for 1.6 hours",  # needs fixing : last step +this step =2.5 hrs
         "Rest for 20 minutes", 
         # Home
         "Run Creeted_Drive (A) for 1 hours",
         "Rest for 5 minutes",
         "Rest for 1 hours", # should be P/4 
         "Rest for 5 minutes",
         "Charge at C/8 until 4.2V",
          "Hold at 4.2V for 3.2 hours",  # needs fixing : last step +this step =4.5 hrs
         "Rest for 20 minutes",     
        )

    ]*10,
    drive_cycles={"Creeted_Drive": Created_Drive},
    termination="50% capacity",
#     cccv_handling="ode",
)



experiment23 = pybamm.Experiment( #Created_ DRC-DRC  # Charging to 4.0 V to check for dissol
    [
        ("Run Creeted_Drive (A) for 1 hours",
         "Rest for 5 minutes",
         "Discharge at C/4 for 1 hours", # should be P/4 
         "Rest for 5 minutes",
         "Charge at C/4 until 4.0V",
         "Hold at 4.0V for .7 hours",  # needs fixing : last step +this step =2.5 hrs
         "Rest for 20 minutes", 
         # Home
         "Run Creeted_Drive (A) for 1 hours",
         "Rest for 5 minutes",
         "Discharge at C/4 for 1 hours", # should be P/4 
         "Rest for 5 minutes",
         "Charge at C/8 until 4.0V",
          "Hold at 4.0V for 1.1 hours",  # needs fixing : last step +this step =4.5 hrs
         "Rest for 20 minutes",     
        )

    ]*900,
    drive_cycles={"Creeted_Drive": Created_Drive},
    termination="50% capacity",
#     cccv_handling="ode",
)

experiment24 = pybamm.Experiment( #Creeted-RCRC
    [
        ("Run Creeted_Drive (A) for 1 hours",
         "Rest for 5 minutes",
         "Rest for 1 hours", # should be P/4 
         "Rest for 5 minutes",
         "Charge at C/4 until 4.0V",
         "Hold at 4.0V for 1.6 hours",  # needs fixing : last step +this step =2.5 hrs
         "Rest for 20 minutes", 
         # Home
         "Run Creeted_Drive (A) for 1 hours",
         "Rest for 5 minutes",
         "Rest for 1 hours", # should be P/4 
         "Rest for 5 minutes",
         "Charge at C/8 until 4.0V",
          "Hold at 4.0V for 3.2 hours",  # needs fixing : last step +this step =4.5 hrs
         "Rest for 20 minutes",     
        )

    ]*10,
    drive_cycles={"Creeted_Drive": Created_Drive},
    termination="50% capacity",
#     cccv_handling="ode",
)

# %%
K_SEI_list=[4.20e-16  , 4.35e-16]
D_SEI_list=[6.66e-19  , 3.69e-19]
k_pl_list=[4.54e-10   , 4.64e-10]
k_diss_list=[0        , 6.24e-04]
b_LAM_p_list=[10.06e-8, 7.65e-08]
b_LAM_n_list=[8.73e-8 , 8.76e-08]
Ea_SEI_list=[6026     , 5997.629]
# March17(no diss)    , March23(diss)
list_num=1

# parameter_values = get_parameter_values()
parameter_values.update(
    {
        "Negative electrode active material volume fraction": eps_n_data,
        "Positive electrode active material volume fraction": eps_p_data,
        "Initial temperature [K]": 273.15+Temp,
        "Ambient temperature [K]": 273.15+Temp,
        "Positive electrode LAM constant proportional term [s-1]": b_LAM_p_list[list_num], #10.0638e-08, #8.3747149e-08,#1.27152e-07
        "Negative electrode LAM constant proportional term [s-1]":b_LAM_n_list[list_num],#8.7257e-08, #9.078886e-08,#1.27272e-06
        "Positive electrode LAM constant exponential term": 1.02,
        "Negative electrode LAM constant exponential term": 1.02,
        "SEI kinetic rate constant [m.s-1]":K_SEI_list[list_num],# 4.1964e-16,# 4.17385539e-16, #4.60788219e-16, 1.08494281e-16 , 
        "EC diffusivity [m2.s-1]": D_SEI_list[list_num], #6.6582e-19, #1.79830186e-18, #4.56607447e-19,8.30909086e-19,
        "SEI growth activation energy [J.mol-1]":Ea_SEI_list[list_num],#6.02602e+03, # 6.18700763e+03, #1.87422275e+04,1.58777981e+04,
        "Initial inner SEI thickness [m]": 0e-09,
        "Initial outer SEI thickness [m]": 5e-09,
        "SEI resistivity [Ohm.m]":  30000.0,# 1.3e06,
        "Lithium plating kinetic rate constant [m.s-1]":k_pl_list[list_num],#4.543e-10, # 4.50936e-10
        
        
        
        #Cathode disolution
        "Positive electrode dissolution exchange current density": k_diss_list[list_num],
#         "Positive electrode dissolution exchange current density": 0,
        "Negative electrode dissolution exchange current density": 0,
    },
    check_already_exists=False,
)

# %%
sim_long = pybamm.Simulation(spm, experiment=experiment14, parameter_values=parameter_values, 
                            solver=pybamm.CasadiSolver("safe",
                            rtol=1e-6, 
                            atol=1e-6,
                            dt_max=10,
                                                      ))
sol_long = sim_long.solve(initial_soc=1, save_at_cycles=1  )
# Out:
# 2023-04-20 17:42:35.534 - [NOTICE] callbacks.on_cycle_start(174): Cycle 1/10 (22.497 ms elapsed) --------------------
# 2023-04-20 17:42:35.535 - [NOTICE] callbacks.on_step_start(182): Cycle 1/10, step 1/14: Run Creeted_Drive (A) for 1 hours
# 2023-04-20 17:42:42.559 - [NOTICE] callbacks.on_step_start(182): Cycle 1/10, step 2/14: Rest for 5 minutes
# 2023-04-20 17:42:42.711 - [NOTICE] callbacks.on_step_start(182): Cycle 1/10, step 3/14: Rest for 1 hours
# 2023-04-20 17:42:42.819 - [NOTICE] callbacks.on_step_start(182): Cycle 1/10, step 4/14: Rest for 5 minutes
# 2023-04-20 17:42:42.831 - [NOTICE] callbacks.on_step_start(182): Cycle 1/10, step 5/14: Charge at C/4 until 4.2V
# 2023-04-20 17:42:43.509 - [NOTICE] callbacks.on_step_start(182): Cycle 1/10, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-04-20 17:42:45.294 - [NOTICE] callbacks.on_step_start(182): Cycle 1/10, step 7/14: Rest for 20 minutes
# 2023-04-20 17:42:45.344 - [NOTICE] callbacks.on_step_start(182): Cycle 1/10, step 8/14: Run Creeted_Drive (A) for 1 hours
# 2023-04-20 17:42:47.610 - [NOTICE] callbacks.on_step_start(182): Cycle 1/10, step 9/14: Rest for 5 minutes
# 2023-04-20 17:42:47.638 - [NOTICE] callbacks.on_step_start(182): Cycle 1/10, step 10/14: Rest for 1 hours
# 2023-04-20 17:42:47.779 - [NOTICE] callbacks.on_step_start(182): Cycle 1/10, step 11/14: Rest for 5 minutes
# 2023-04-20 17:42:47.797 - [NOTICE] callbacks.on_step_start(182): Cycle 1/10, step 12/14: Charge at C/8 until 4.2V
# 2023-04-20 17:42:48.225 - [NOTICE] callbacks.on_step_start(182): Cycle 1/10, step 13/14: Hold at 4.2V for 3.2 hours
# 2023-04-20 17:42:49.615 - [NOTICE] callbacks.on_step_start(182): Cycle 1/10, step 14/14: Rest for 20 minutes
# 2023-04-20 17:42:50.930 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.467 Ah (originally 2.467 Ah, will stop at 1.234 Ah)
# 2023-04-20 17:42:50.930 - [NOTICE] callbacks.on_cycle_start(174): Cycle 2/10 (15.423 s elapsed) --------------------
# 2023-04-20 17:42:50.930 - [NOTICE] callbacks.on_step_start(182): Cycle 2/10, step 1/14: Run Creeted_Drive (A) for 1 hours
# 2023-04-20 17:42:53.025 - [NOTICE] callbacks.on_step_start(182): Cycle 2/10, step 2/14: Rest for 5 minutes
# 2023-04-20 17:42:53.045 - [NOTICE] callbacks.on_step_start(182): Cycle 2/10, step 3/14: Rest for 1 hours
# 2023-04-20 17:42:53.145 - [NOTICE] callbacks.on_step_start(182): Cycle 2/10, step 4/14: Rest for 5 minutes
# 2023-04-20 17:42:53.160 - [NOTICE] callbacks.on_step_start(182): Cycle 2/10, step 5/14: Charge at C/4 until 4.2V
# 2023-04-20 17:42:53.307 - [NOTICE] callbacks.on_step_start(182): Cycle 2/10, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-04-20 17:42:53.914 - [NOTICE] callbacks.on_step_start(182): Cycle 2/10, step 7/14: Rest for 20 minutes
# 2023-04-20 17:42:53.970 - [NOTICE] callbacks.on_step_start(182): Cycle 2/10, step 8/14: Run Creeted_Drive (A) for 1 hours
# 2023-04-20 17:42:56.035 - [NOTICE] callbacks.on_step_start(182): Cycle 2/10, step 9/14: Rest for 5 minutes
# 2023-04-20 17:42:56.059 - [NOTICE] callbacks.on_step_start(182): Cycle 2/10, step 10/14: Rest for 1 hours
# 2023-04-20 17:42:56.158 - [NOTICE] callbacks.on_step_start(182): Cycle 2/10, step 11/14: Rest for 5 minutes
# 2023-04-20 17:42:56.169 - [NOTICE] callbacks.on_step_start(182): Cycle 2/10, step 12/14: Charge at C/8 until 4.2V
# 2023-04-20 17:42:56.415 - [NOTICE] callbacks.on_step_start(182): Cycle 2/10, step 13/14: Hold at 4.2V for 3.2 hours
# 2023-04-20 17:42:57.734 - [NOTICE] callbacks.on_step_start(182): Cycle 2/10, step 14/14: Rest for 20 minutes
# 2023-04-20 17:42:58.775 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.466 Ah (originally 2.467 Ah, will stop at 1.234 Ah)
# 2023-04-20 17:42:58.776 - [NOTICE] callbacks.on_cycle_start(174): Cycle 3/10 (23.265 s elapsed) --------------------
# 2023-04-20 17:42:58.777 - [NOTICE] callbacks.on_step_start(182): Cycle 3/10, step 1/14: Run Creeted_Drive (A) for 1 hours
# 2023-04-20 17:43:00.881 - [NOTICE] callbacks.on_step_start(182): Cycle 3/10, step 2/14: Rest for 5 minutes
# 2023-04-20 17:43:00.900 - [NOTICE] callbacks.on_step_start(182): Cycle 3/10, step 3/14: Rest for 1 hours
# 2023-04-20 17:43:01.005 - [NOTICE] callbacks.on_step_start(182): Cycle 3/10, step 4/14: Rest for 5 minutes
# 2023-04-20 17:43:01.025 - [NOTICE] callbacks.on_step_start(182): Cycle 3/10, step 5/14: Charge at C/4 until 4.2V
# 2023-04-20 17:43:01.172 - [NOTICE] callbacks.on_step_start(182): Cycle 3/10, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-04-20 17:43:01.780 - [NOTICE] callbacks.on_step_start(182): Cycle 3/10, step 7/14: Rest for 20 minutes
# 2023-04-20 17:43:01.827 - [NOTICE] callbacks.on_step_start(182): Cycle 3/10, step 8/14: Run Creeted_Drive (A) for 1 hours
# 2023-04-20 17:43:03.872 - [NOTICE] callbacks.on_step_start(182): Cycle 3/10, step 9/14: Rest for 5 minutes
# 2023-04-20 17:43:03.898 - [NOTICE] callbacks.on_step_start(182): Cycle 3/10, step 10/14: Rest for 1 hours
# 2023-04-20 17:43:03.996 - [NOTICE] callbacks.on_step_start(182): Cycle 3/10, step 11/14: Rest for 5 minutes
# 2023-04-20 17:43:04.014 - [NOTICE] callbacks.on_step_start(182): Cycle 3/10, step 12/14: Charge at C/8 until 4.2V
# 2023-04-20 17:43:04.261 - [NOTICE] callbacks.on_step_start(182): Cycle 3/10, step 13/14: Hold at 4.2V for 3.2 hours
# 2023-04-20 17:43:05.455 - [NOTICE] callbacks.on_step_start(182): Cycle 3/10, step 14/14: Rest for 20 minutes
# 2023-04-20 17:43:06.470 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.464 Ah (originally 2.467 Ah, will stop at 1.234 Ah)
# 2023-04-20 17:43:06.470 - [NOTICE] callbacks.on_cycle_start(174): Cycle 4/10 (30.963 s elapsed) --------------------
# 2023-04-20 17:43:06.470 - [NOTICE] callbacks.on_step_start(182): Cycle 4/10, step 1/14: Run Creeted_Drive (A) for 1 hours
# 2023-04-20 17:43:08.467 - [NOTICE] callbacks.on_step_start(182): Cycle 4/10, step 2/14: Rest for 5 minutes
# 2023-04-20 17:43:08.489 - [NOTICE] callbacks.on_step_start(182): Cycle 4/10, step 3/14: Rest for 1 hours
# 2023-04-20 17:43:08.589 - [NOTICE] callbacks.on_step_start(182): Cycle 4/10, step 4/14: Rest for 5 minutes
# 2023-04-20 17:43:08.603 - [NOTICE] callbacks.on_step_start(182): Cycle 4/10, step 5/14: Charge at C/4 until 4.2V
# 2023-04-20 17:43:08.753 - [NOTICE] callbacks.on_step_start(182): Cycle 4/10, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-04-20 17:43:09.368 - [NOTICE] callbacks.on_step_start(182): Cycle 4/10, step 7/14: Rest for 20 minutes
# 2023-04-20 17:43:09.407 - [NOTICE] callbacks.on_step_start(182): Cycle 4/10, step 8/14: Run Creeted_Drive (A) for 1 hours
# 2023-04-20 17:43:11.623 - [NOTICE] callbacks.on_step_start(182): Cycle 4/10, step 9/14: Rest for 5 minutes
# 2023-04-20 17:43:11.644 - [NOTICE] callbacks.on_step_start(182): Cycle 4/10, step 10/14: Rest for 1 hours
# 2023-04-20 17:43:11.765 - [NOTICE] callbacks.on_step_start(182): Cycle 4/10, step 11/14: Rest for 5 minutes
# 2023-04-20 17:43:11.778 - [NOTICE] callbacks.on_step_start(182): Cycle 4/10, step 12/14: Charge at C/8 until 4.2V
# 2023-04-20 17:43:12.055 - [NOTICE] callbacks.on_step_start(182): Cycle 4/10, step 13/14: Hold at 4.2V for 3.2 hours
# 2023-04-20 17:43:13.421 - [NOTICE] callbacks.on_step_start(182): Cycle 4/10, step 14/14: Rest for 20 minutes
# 2023-04-20 17:43:14.474 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.463 Ah (originally 2.467 Ah, will stop at 1.234 Ah)
# 2023-04-20 17:43:14.475 - [NOTICE] callbacks.on_cycle_start(174): Cycle 5/10 (38.964 s elapsed) --------------------
# 2023-04-20 17:43:14.476 - [NOTICE] callbacks.on_step_start(182): Cycle 5/10, step 1/14: Run Creeted_Drive (A) for 1 hours
# 2023-04-20 17:43:16.490 - [NOTICE] callbacks.on_step_start(182): Cycle 5/10, step 2/14: Rest for 5 minutes
# 2023-04-20 17:43:16.510 - [NOTICE] callbacks.on_step_start(182): Cycle 5/10, step 3/14: Rest for 1 hours
# 2023-04-20 17:43:16.602 - [NOTICE] callbacks.on_step_start(182): Cycle 5/10, step 4/14: Rest for 5 minutes
# 2023-04-20 17:43:16.621 - [NOTICE] callbacks.on_step_start(182): Cycle 5/10, step 5/14: Charge at C/4 until 4.2V
# 2023-04-20 17:43:16.768 - [NOTICE] callbacks.on_step_start(182): Cycle 5/10, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-04-20 17:43:17.377 - [NOTICE] callbacks.on_step_start(182): Cycle 5/10, step 7/14: Rest for 20 minutes
# 2023-04-20 17:43:17.425 - [NOTICE] callbacks.on_step_start(182): Cycle 5/10, step 8/14: Run Creeted_Drive (A) for 1 hours
# 2023-04-20 17:43:19.404 - [NOTICE] callbacks.on_step_start(182): Cycle 5/10, step 9/14: Rest for 5 minutes
# 2023-04-20 17:43:19.427 - [NOTICE] callbacks.on_step_start(182): Cycle 5/10, step 10/14: Rest for 1 hours
# 2023-04-20 17:43:19.526 - [NOTICE] callbacks.on_step_start(182): Cycle 5/10, step 11/14: Rest for 5 minutes
# 2023-04-20 17:43:19.540 - [NOTICE] callbacks.on_step_start(182): Cycle 5/10, step 12/14: Charge at C/8 until 4.2V
# 2023-04-20 17:43:19.788 - [NOTICE] callbacks.on_step_start(182): Cycle 5/10, step 13/14: Hold at 4.2V for 3.2 hours
# 2023-04-20 17:43:21.056 - [NOTICE] callbacks.on_step_start(182): Cycle 5/10, step 14/14: Rest for 20 minutes
# 2023-04-20 17:43:22.096 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.462 Ah (originally 2.467 Ah, will stop at 1.234 Ah)
# 2023-04-20 17:43:22.097 - [NOTICE] callbacks.on_cycle_start(174): Cycle 6/10 (46.587 s elapsed) --------------------
# 2023-04-20 17:43:22.098 - [NOTICE] callbacks.on_step_start(182): Cycle 6/10, step 1/14: Run Creeted_Drive (A) for 1 hours
# 2023-04-20 17:43:24.115 - [NOTICE] callbacks.on_step_start(182): Cycle 6/10, step 2/14: Rest for 5 minutes
# 2023-04-20 17:43:24.144 - [NOTICE] callbacks.on_step_start(182): Cycle 6/10, step 3/14: Rest for 1 hours
# 2023-04-20 17:43:24.241 - [NOTICE] callbacks.on_step_start(182): Cycle 6/10, step 4/14: Rest for 5 minutes
# 2023-04-20 17:43:24.252 - [NOTICE] callbacks.on_step_start(182): Cycle 6/10, step 5/14: Charge at C/4 until 4.2V
# 2023-04-20 17:43:24.404 - [NOTICE] callbacks.on_step_start(182): Cycle 6/10, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-04-20 17:43:25.025 - [NOTICE] callbacks.on_step_start(182): Cycle 6/10, step 7/14: Rest for 20 minutes
# 2023-04-20 17:43:25.067 - [NOTICE] callbacks.on_step_start(182): Cycle 6/10, step 8/14: Run Creeted_Drive (A) for 1 hours
# 2023-04-20 17:43:27.065 - [NOTICE] callbacks.on_step_start(182): Cycle 6/10, step 9/14: Rest for 5 minutes
# 2023-04-20 17:43:27.087 - [NOTICE] callbacks.on_step_start(182): Cycle 6/10, step 10/14: Rest for 1 hours
# 2023-04-20 17:43:27.178 - [NOTICE] callbacks.on_step_start(182): Cycle 6/10, step 11/14: Rest for 5 minutes
# 2023-04-20 17:43:27.199 - [NOTICE] callbacks.on_step_start(182): Cycle 6/10, step 12/14: Charge at C/8 until 4.2V
# 2023-04-20 17:43:27.452 - [NOTICE] callbacks.on_step_start(182): Cycle 6/10, step 13/14: Hold at 4.2V for 3.2 hours
# 2023-04-20 17:43:28.643 - [NOTICE] callbacks.on_step_start(182): Cycle 6/10, step 14/14: Rest for 20 minutes
# 2023-04-20 17:43:29.682 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.460 Ah (originally 2.467 Ah, will stop at 1.234 Ah)
# 2023-04-20 17:43:29.682 - [NOTICE] callbacks.on_cycle_start(174): Cycle 7/10 (54.174 s elapsed) --------------------
# 2023-04-20 17:43:29.682 - [NOTICE] callbacks.on_step_start(182): Cycle 7/10, step 1/14: Run Creeted_Drive (A) for 1 hours
# 2023-04-20 17:43:31.701 - [NOTICE] callbacks.on_step_start(182): Cycle 7/10, step 2/14: Rest for 5 minutes
# 2023-04-20 17:43:31.728 - [NOTICE] callbacks.on_step_start(182): Cycle 7/10, step 3/14: Rest for 1 hours
# 2023-04-20 17:43:31.814 - [NOTICE] callbacks.on_step_start(182): Cycle 7/10, step 4/14: Rest for 5 minutes
# 2023-04-20 17:43:31.836 - [NOTICE] callbacks.on_step_start(182): Cycle 7/10, step 5/14: Charge at C/4 until 4.2V
# 2023-04-20 17:43:32.010 - [NOTICE] callbacks.on_step_start(182): Cycle 7/10, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-04-20 17:43:32.675 - [NOTICE] callbacks.on_step_start(182): Cycle 7/10, step 7/14: Rest for 20 minutes
# 2023-04-20 17:43:32.716 - [NOTICE] callbacks.on_step_start(182): Cycle 7/10, step 8/14: Run Creeted_Drive (A) for 1 hours
# 2023-04-20 17:43:34.676 - [NOTICE] callbacks.on_step_start(182): Cycle 7/10, step 9/14: Rest for 5 minutes
# 2023-04-20 17:43:34.702 - [NOTICE] callbacks.on_step_start(182): Cycle 7/10, step 10/14: Rest for 1 hours
# 2023-04-20 17:43:34.802 - [NOTICE] callbacks.on_step_start(182): Cycle 7/10, step 11/14: Rest for 5 minutes
# 2023-04-20 17:43:34.815 - [NOTICE] callbacks.on_step_start(182): Cycle 7/10, step 12/14: Charge at C/8 until 4.2V
# 2023-04-20 17:43:35.062 - [NOTICE] callbacks.on_step_start(182): Cycle 7/10, step 13/14: Hold at 4.2V for 3.2 hours
# 2023-04-20 17:43:36.281 - [NOTICE] callbacks.on_step_start(182): Cycle 7/10, step 14/14: Rest for 20 minutes
# 2023-04-20 17:43:37.300 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.459 Ah (originally 2.467 Ah, will stop at 1.234 Ah)
# 2023-04-20 17:43:37.300 - [NOTICE] callbacks.on_cycle_start(174): Cycle 8/10 (1 minute, 2 seconds elapsed) --------------------
# 2023-04-20 17:43:37.300 - [NOTICE] callbacks.on_step_start(182): Cycle 8/10, step 1/14: Run Creeted_Drive (A) for 1 hours
# 2023-04-20 17:43:39.323 - [NOTICE] callbacks.on_step_start(182): Cycle 8/10, step 2/14: Rest for 5 minutes
# 2023-04-20 17:43:39.347 - [NOTICE] callbacks.on_step_start(182): Cycle 8/10, step 3/14: Rest for 1 hours
# 2023-04-20 17:43:39.443 - [NOTICE] callbacks.on_step_start(182): Cycle 8/10, step 4/14: Rest for 5 minutes
# 2023-04-20 17:43:39.459 - [NOTICE] callbacks.on_step_start(182): Cycle 8/10, step 5/14: Charge at C/4 until 4.2V
# 2023-04-20 17:43:39.616 - [NOTICE] callbacks.on_step_start(182): Cycle 8/10, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-04-20 17:43:40.224 - [NOTICE] callbacks.on_step_start(182): Cycle 8/10, step 7/14: Rest for 20 minutes
# 2023-04-20 17:43:40.268 - [NOTICE] callbacks.on_step_start(182): Cycle 8/10, step 8/14: Run Creeted_Drive (A) for 1 hours
# 2023-04-20 17:43:42.265 - [NOTICE] callbacks.on_step_start(182): Cycle 8/10, step 9/14: Rest for 5 minutes
# 2023-04-20 17:43:42.293 - [NOTICE] callbacks.on_step_start(182): Cycle 8/10, step 10/14: Rest for 1 hours
# 2023-04-20 17:43:42.381 - [NOTICE] callbacks.on_step_start(182): Cycle 8/10, step 11/14: Rest for 5 minutes
# 2023-04-20 17:43:42.402 - [NOTICE] callbacks.on_step_start(182): Cycle 8/10, step 12/14: Charge at C/8 until 4.2V
# 2023-04-20 17:43:42.651 - [NOTICE] callbacks.on_step_start(182): Cycle 8/10, step 13/14: Hold at 4.2V for 3.2 hours
# 2023-04-20 17:43:43.849 - [NOTICE] callbacks.on_step_start(182): Cycle 8/10, step 14/14: Rest for 20 minutes
# 2023-04-20 17:43:44.906 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.457 Ah (originally 2.467 Ah, will stop at 1.234 Ah)
# 2023-04-20 17:43:44.908 - [NOTICE] callbacks.on_cycle_start(174): Cycle 9/10 (1 minute, 9 seconds elapsed) --------------------
# 2023-04-20 17:43:44.909 - [NOTICE] callbacks.on_step_start(182): Cycle 9/10, step 1/14: Run Creeted_Drive (A) for 1 hours
# 2023-04-20 17:43:47.200 - [NOTICE] callbacks.on_step_start(182): Cycle 9/10, step 2/14: Rest for 5 minutes
# 2023-04-20 17:43:47.223 - [NOTICE] callbacks.on_step_start(182): Cycle 9/10, step 3/14: Rest for 1 hours
# 2023-04-20 17:43:47.338 - [NOTICE] callbacks.on_step_start(182): Cycle 9/10, step 4/14: Rest for 5 minutes
# 2023-04-20 17:43:47.350 - [NOTICE] callbacks.on_step_start(182): Cycle 9/10, step 5/14: Charge at C/4 until 4.2V
# 2023-04-20 17:43:47.506 - [NOTICE] callbacks.on_step_start(182): Cycle 9/10, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-04-20 17:43:48.130 - [NOTICE] callbacks.on_step_start(182): Cycle 9/10, step 7/14: Rest for 20 minutes
# 2023-04-20 17:43:48.172 - [NOTICE] callbacks.on_step_start(182): Cycle 9/10, step 8/14: Run Creeted_Drive (A) for 1 hours
# 2023-04-20 17:43:50.303 - [NOTICE] callbacks.on_step_start(182): Cycle 9/10, step 9/14: Rest for 5 minutes
# 2023-04-20 17:43:50.323 - [NOTICE] callbacks.on_step_start(182): Cycle 9/10, step 10/14: Rest for 1 hours
# 2023-04-20 17:43:50.425 - [NOTICE] callbacks.on_step_start(182): Cycle 9/10, step 11/14: Rest for 5 minutes
# 2023-04-20 17:43:50.437 - [NOTICE] callbacks.on_step_start(182): Cycle 9/10, step 12/14: Charge at C/8 until 4.2V
# 2023-04-20 17:43:50.683 - [NOTICE] callbacks.on_step_start(182): Cycle 9/10, step 13/14: Hold at 4.2V for 3.2 hours
# 2023-04-20 17:43:51.918 - [NOTICE] callbacks.on_step_start(182): Cycle 9/10, step 14/14: Rest for 20 minutes
# 2023-04-20 17:43:52.974 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.456 Ah (originally 2.467 Ah, will stop at 1.234 Ah)
# 2023-04-20 17:43:52.975 - [NOTICE] callbacks.on_cycle_start(174): Cycle 10/10 (1 minute, 17 seconds elapsed) --------------------
# 2023-04-20 17:43:52.976 - [NOTICE] callbacks.on_step_start(182): Cycle 10/10, step 1/14: Run Creeted_Drive (A) for 1 hours
# 2023-04-20 17:43:55.016 - [NOTICE] callbacks.on_step_start(182): Cycle 10/10, step 2/14: Rest for 5 minutes
# 2023-04-20 17:43:55.045 - [NOTICE] callbacks.on_step_start(182): Cycle 10/10, step 3/14: Rest for 1 hours
# 2023-04-20 17:43:55.140 - [NOTICE] callbacks.on_step_start(182): Cycle 10/10, step 4/14: Rest for 5 minutes
# 2023-04-20 17:43:55.157 - [NOTICE] callbacks.on_step_start(182): Cycle 10/10, step 5/14: Charge at C/4 until 4.2V
# 2023-04-20 17:43:55.306 - [NOTICE] callbacks.on_step_start(182): Cycle 10/10, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-04-20 17:43:55.918 - [NOTICE] callbacks.on_step_start(182): Cycle 10/10, step 7/14: Rest for 20 minutes
# 2023-04-20 17:43:55.963 - [NOTICE] callbacks.on_step_start(182): Cycle 10/10, step 8/14: Run Creeted_Drive (A) for 1 hours
# 2023-04-20 17:43:57.961 - [NOTICE] callbacks.on_step_start(182): Cycle 10/10, step 9/14: Rest for 5 minutes
# 2023-04-20 17:43:57.988 - [NOTICE] callbacks.on_step_start(182): Cycle 10/10, step 10/14: Rest for 1 hours
# 2023-04-20 17:43:58.085 - [NOTICE] callbacks.on_step_start(182): Cycle 10/10, step 11/14: Rest for 5 minutes
# 2023-04-20 17:43:58.100 - [NOTICE] callbacks.on_step_start(182): Cycle 10/10, step 12/14: Charge at C/8 until 4.2V
# 2023-04-20 17:43:58.342 - [NOTICE] callbacks.on_step_start(182): Cycle 10/10, step 13/14: Hold at 4.2V for 3.2 hours
# 2023-04-20 17:43:59.544 - [NOTICE] callbacks.on_step_start(182): Cycle 10/10, step 14/14: Rest for 20 minutes
# 2023-04-20 17:44:00.609 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.455 Ah (originally 2.467 Ah, will stop at 1.234 Ah)
# 2023-04-20 17:44:00.609 - [NOTICE] callbacks.on_experiment_end(222): Finish experiment simulation, took 1 minute, 25 seconds

# %%
sol_long.summary_variables.search("lithium")
# Out:
# Change in loss of capacity to lithium plating [A.h]
# Change in loss of lithium inventory [%]
# Change in loss of lithium inventory, including electrolyte [%]
# Change in loss of lithium to SEI [mol]
# Change in loss of lithium to SEI on cracks [mol]
# Change in loss of lithium to lithium plating [mol]
# Change in total lithium [mol]
# Change in total lithium in electrolyte [mol]
# Change in total lithium in negative electrode [mol]
# Change in total lithium in particles [mol]
# Change in total lithium in positive electrode [mol]
# Change in total lithium lost [mol]
# Change in total lithium lost from electrolyte [mol]
# Change in total lithium lost from particles [mol]
# Change in total lithium lost to side reactions [mol]
# Loss of capacity to lithium plating [A.h]
# Loss of lithium inventory [%]
# Loss of lithium inventory, including electrolyte [%]
# Loss of lithium to SEI [mol]
# Loss of lithium to SEI on cracks [mol]
# Loss of lithium to lithium plating [mol]
# Total lithium [mol]
# Total lithium in electrolyte [mol]
# Total lithium in negative electrode [mol]
# Total lithium in particles [mol]
# Total lithium in positive electrode [mol]
# Total lithium lost [mol]
# Total lithium lost from electrolyte [mol]
# Total lithium lost from particles [mol]
# Total lithium lost to side reactions [mol]

# %%
sim_long.plot(
    [
#         "Negative particle surface concentration [mol.m-3]",
#         "Electrolyte concentration [mol.m-3]",
        "Positive particle surface concentration [mol.m-3]",
        "Current [A]",
#         "Negative electrode potential [V]",
#         "Electrolyte potential [V]",
#         "Positive electrode potential [V]",
        "Terminal voltage [V]",
#         "X-averaged cell temperature",
        "Negative electrode SOC",
        "Positive electrode SOC",
        "Total lithium [mol]",
        "Total lithium in electrolyte [mol]",
        "Total lithium in negative electrode [mol]",
        "Total lithium in particles [mol]",
        "Total lithium in positive electrode [mol]",
        "Total lithium lost [mol]",
        "Total lithium lost from electrolyte [mol]",
        "Total lithium lost from particles [mol]",
        "Total lithium lost to side reactions [mol]",
        "Loss of lithium to lithium plating [mol]",
        "Loss of lithium to SEI [mol]",

    ]
)
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=127.14228802792022, step=1.2714228802792022)…

# %%
# pybamm.plot_summary_variables(sol_long)

# %%
gnffjj
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 gnffjj
#
# NameError: name 'gnffjj' is not defined

# %%
x100=sol_long.summary_variables["x_100"]
y100=sol_long.summary_variables["y_100"]
x0=sol_long.summary_variables["x_0"]
y0=sol_long.summary_variables["y_0"]
Cap=sol_long.summary_variables["Capacity [A.h]"]
LoC_SEI_summ=sol_long.summary_variables["Loss of capacity to SEI [A.h]"]
LAM_P=sol_long.summary_variables["Loss of active material in positive electrode [%]"]
LAM_N=sol_long.summary_variables["Loss of active material in negative electrode [%]"]
C_Neg=sol_long.summary_variables["C_n"]
C_pos=sol_long.summary_variables["C_p"]


LLI=sol_long.summary_variables["Loss of lithium inventory [%]"]
LLI_mol= sol_long.summary_variables["Total lithium lost [mol]"]
LLI_Side_mol= sol_long.summary_variables["Total lithium lost to side reactions [mol]"]
LLI_plating_mol= sol_long.summary_variables["Loss of lithium to lithium plating [mol]"]
LLI_SEI_mol= sol_long.summary_variables["Loss of lithium to SEI [mol]"]


cycle_num=sol_long.summary_variables["Cycle number"]
t = sol_long["Time [s]"].entries
I = sol_long["Current [A]"].entries
Q = sol_long['Discharge capacity [A.h]'].entries
LoC_SEI = sol_long["Loss of capacity to SEI [A.h]"].entries
N_SoC = sol_long["Negative electrode SOC"].entries
P_SoC = sol_long["Positive electrode SOC"].entries
Epsilon_n_s_cycled=sol_long["X-averaged negative electrode active material volume fraction"].entries
Epsilon_p_s_cycled=sol_long["X-averaged positive electrode active material volume fraction"].entries
cycle_time=sol_long.summary_variables['Time [s]'],
Vt_t = sol_long["Terminal voltage [V]"].entries,

# LLI_SEI_mol=sol_long["Loss of lithium to SEI [mol]"].entries,
# LLI_plating_mol=sol_long["Loss of lithium to lithium plating [mol]"].entries,

# %%
from scipy.io import savemat

ident=""
mdic = {
    "x100"+ident: x100, "y100"+ident:y100, "x0"+ident:x0,"y0"+ident:y0,"Cap"+ident:Cap,
        "LoC_SEI_summ"+ident:LoC_SEI_summ,
        "LAM_P"+ident:LAM_P,"LAM_N"+ident:LAM_N,"C_Neg"+ident:C_Neg,"C_pos"+ident:C_pos,
        "LLI"+ident:LLI,"cycle_num"+ident:cycle_num,
        "t"+ident:t,"LoC_SEI"+ident:LoC_SEI,"N_SoC"+ident:N_SoC,"P_SoC"+ident:P_SoC,
        "Q"+ident:Q, "I"+ident:I,    
#         "ECM_whole_res":ECM_whole_res,"ECM_sum_res":ECM_sum_res,
#         "ECM_sum_res_change":ECM_sum_res_change,"cycle_time":cycle_time 
        "Epsilon_n_s_cycled"+ident:Epsilon_n_s_cycled,
        "Epsilon_p_s_cycled"+ident:Epsilon_p_s_cycled,
        "cycle_time":cycle_time, "Vt_t":Vt_t,
        "LLI_SEI_mol":LLI_SEI_mol,
        "LLI_plating_mol":LLI_plating_mol,
        "LLI_mol":LLI_mol,
        "LLI_Side_mol":LLI_Side_mol
    
       }
savemat("Andrew152002__experiment24_Dissolution_Apr18.mat",mdic)

# %%
spm.variables.search("Lithium")
