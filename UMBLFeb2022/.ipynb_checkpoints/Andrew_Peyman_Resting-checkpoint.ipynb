# %%
import pybamm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
import dfols
import signal
from scipy.integrate import solve_ivp
from scipy.fft import fft, fftfreq, fftshift
from scipy.signal import savgol_filter
from scipy.signal import find_peaks
from scipy import interpolate
from stopit import threading_timeoutable as timeoutable
import os, sys
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath("__file__"))))
from stopit import threading_timeoutable as timeoutable
from batfuns import *
plt.rcParams = set_rc_params(plt.rcParams)
eSOH_DIR = f"F:/Git Hub rep/PyBaMM/UMBLFeb2022/data/esoh/"
oCV_DIR = f"F:/Git Hub rep/PyBaMM/UMBLFeb2022/data/ocv/"
fig_DIR = "../figures/figures_fit/"
res_DIR = "../data/results_fit/"
# %matplotlib widget

# %%
parameter_values = pybamm.ParameterValues(chemistry=pybamm.parameter_sets.Andrew2022)

parameter_values.update(
    {
        # mechanical properties
        "Positive electrode Poisson's ratio": 0.3,
        "Positive electrode Young's modulus [Pa]": 375e9,
        "Positive electrode reference concentration for free of deformation [mol.m-3]": 0,
        "Positive electrode partial molar volume [m3.mol-1]": -7.28e-7,
        "Positive electrode volume change": nmc_volume_change_mohtat,
        # Loss of active materials (LAM) model
        "Positive electrode LAM constant exponential term": 2,
        "Positive electrode critical stress [Pa]": 375e6,
        # mechanical properties
        "Negative electrode Poisson's ratio": 0.2,
        "Negative electrode Young's modulus [Pa]": 15e9,
        "Negative electrode reference concentration for free of deformation [mol.m-3]": 0,
        "Negative electrode partial molar volume [m3.mol-1]": 3.1e-6,
        "Negative electrode volume change": graphite_volume_change_mohtat,
        # Loss of active materials (LAM) model
        "Negative electrode LAM constant exponential term": 2,
        "Negative electrode critical stress [Pa]": 60e6,
        # Other
        "Cell thermal expansion coefficient [m.K-1]": 1.48E-6,
        "Lower voltage cut-off [V]": 3.0,
        # Initializing Particle Concentration
        # "Initial concentration in negative electrode [mol.m-3]": x100*parameter_values["Maximum concentration in negative electrode [mol.m-3]"],
        # "Initial concentration in positive electrode [mol.m-3]": y100*parameter_values["Maximum concentration in positive electrode [mol.m-3]"]
    },
    check_already_exists=False,
)

# %%
parameter_values.search("plating")
# Out:
# Exchange-current density for plating [A.m-2]	<function plating_exchange_current_density_Mohtat2020 at 0x0000025136B47E50>
# Li plating open-circuit potential [V]	0.05
# Lithium plating kinetic rate constant [m.s-1]	1e-09
# Lithium plating transfer coefficient	0.65

# %%
spm = pybamm.lithium_ion.SPM(
    {
        "SEI": "ec reaction limited",
        # "loss of active material": ("stress-driven","none"),
        "loss of active material": "stress-driven",
        # "stress-induced diffusion": "true",
        "lithium plating": "irreversible",
        "calculate discharge energy":"true"
    }
)

# %%
# spm.print_parameter_info()
param=spm.param
parameter_values.update(
    {
"Electrode width [m]":0.1,
#     "Maximum concentration in negative electrode [mol.m-3]":30000,
"Nominal cell capacity [A.h]":2.5,
"Maximum concentration in positive electrode [mol.m-3]":37500
        
    }
)

# %%
cell = 152002
cell_no,dfe,dfe_0,dfo_0,N,N_0 = load_data(cell,eSOH_DIR,oCV_DIR)
eps_n_data,eps_p_data,c_rate_c,c_rate_d,dis_set,Temp,SOC_0 = init_exp(cell_no,dfe,spm,parameter_values)
# Temp
# cell_no,dfe,N,dfo_0 = load_data_calendar(cell,eSOH_DIR,oCV_DIR)
# eps_n_data,eps_p_data,SOC_0,Temp = init_exp_calendar(cell_no,dfe,param,parameter_values)
Temp=45

# %%
Created_Drive = pd.read_csv(r"F:\Stefanapolu application\CRC\Drive Cycle\Created_Drive_2_5Ah.csv", comment="#", header=None).to_numpy()


# pybamm.set_logging_level("WARNING")
experiment_Driveonly = pybamm.Experiment( #Created_ DRC-DRC
    [
        ("Discharge to 3.7 V",
        )

    ]*500,
    drive_cycles={"Creeted_Drive": Created_Drive},
    termination="60% capacity",
#     cccv_handling="ode",
)

eps_n_data
# Out:
# 0.6571914969631569

# %%
# parameter_values = get_parameter_values()
parameter_values.update(
    {
        "Negative electrode active material volume fraction": eps_n_data,
        "Positive electrode active material volume fraction": eps_p_data,
        "Initial temperature [K]": 273.15+Temp,
        "Ambient temperature [K]": 273.15+Temp,
        "Positive electrode LAM constant proportional term [s-1]": 8.3747149e-08,#1.27152e-07
        "Negative electrode LAM constant proportional term [s-1]": 9.078886e-08,#1.27272e-06
        "Positive electrode LAM constant exponential term": 1.02,
        "Negative electrode LAM constant exponential term": 1.02,
        "SEI kinetic rate constant [m.s-1]": 4.17385539e-16, #4.60788219e-16, 1.08494281e-16 , 
        "EC diffusivity [m2.s-1]": 1.79830186e-18, #4.56607447e-19,8.30909086e-19,
        "SEI growth activation energy [J.mol-1]": 6.18700763e+03, #1.87422275e+04,1.58777981e+04,
        "Lithium plating kinetic rate constant [m.s-1]": 0,
        "Initial inner SEI thickness [m]": 0e-09,
        "Initial outer SEI thickness [m]": 5e-09,
        "SEI resistivity [Ohm.m]": 30000.0,
        "Lithium plating kinetic rate constant [m.s-1]": 4.50936e-10
    },
    check_already_exists=False,
)

# %%
pybamm.set_logging_level("NOTICE")

sim_long_Andrew_DriveOnly = pybamm.Simulation(spm, experiment=experiment_Driveonly, parameter_values=parameter_values, 
                            solver=pybamm.CasadiSolver("safe",
                            rtol=1e-6, 
                            atol=1e-6,
                            dt_max=10,
                                                      ))
sol_long_Andrew_DriveOnly = sim_long_Andrew_DriveOnly .solve(initial_soc=1, save_at_cycles=20  )
# Out:
# 2023-02-16 12:26:54.318 - [NOTICE] callbacks.on_cycle_start(174): Cycle 1/500 (20.071 ms elapsed) --------------------
# 2023-02-16 12:26:54.319 - [NOTICE] callbacks.on_step_start(182): Cycle 1/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:26:58.385 - [NOTICE] callbacks.on_step_start(182): Cycle 1/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:26:58.770 - [NOTICE] callbacks.on_step_start(182): Cycle 1/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:27:00.142 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.468 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:27:00.143 - [NOTICE] callbacks.on_cycle_start(174): Cycle 2/500 (5.846 s elapsed) --------------------
# 2023-02-16 12:27:00.144 - [NOTICE] callbacks.on_step_start(182): Cycle 2/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:27:03.481 - [NOTICE] callbacks.on_step_start(182): Cycle 2/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:27:03.720 - [NOTICE] callbacks.on_step_start(182): Cycle 2/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:27:04.708 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.468 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:27:04.709 - [NOTICE] callbacks.on_cycle_start(174): Cycle 3/500 (10.411 s elapsed) --------------------
# 2023-02-16 12:27:04.710 - [NOTICE] callbacks.on_step_start(182): Cycle 3/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:27:08.048 - [NOTICE] callbacks.on_step_start(182): Cycle 3/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:27:08.286 - [NOTICE] callbacks.on_step_start(182): Cycle 3/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:27:09.256 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.467 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:27:09.257 - [NOTICE] callbacks.on_cycle_start(174): Cycle 4/500 (14.959 s elapsed) --------------------
# 2023-02-16 12:27:09.258 - [NOTICE] callbacks.on_step_start(182): Cycle 4/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:27:12.698 - [NOTICE] callbacks.on_step_start(182): Cycle 4/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:27:12.943 - [NOTICE] callbacks.on_step_start(182): Cycle 4/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:27:13.949 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.467 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:27:13.950 - [NOTICE] callbacks.on_cycle_start(174): Cycle 5/500 (19.652 s elapsed) --------------------
# 2023-02-16 12:27:13.951 - [NOTICE] callbacks.on_step_start(182): Cycle 5/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:27:17.314 - [NOTICE] callbacks.on_step_start(182): Cycle 5/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:27:17.553 - [NOTICE] callbacks.on_step_start(182): Cycle 5/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:27:18.533 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.466 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:27:18.534 - [NOTICE] callbacks.on_cycle_start(174): Cycle 6/500 (24.236 s elapsed) --------------------
# 2023-02-16 12:27:18.534 - [NOTICE] callbacks.on_step_start(182): Cycle 6/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:27:22.060 - [NOTICE] callbacks.on_step_start(182): Cycle 6/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:27:22.348 - [NOTICE] callbacks.on_step_start(182): Cycle 6/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:27:23.318 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.466 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:27:23.319 - [NOTICE] callbacks.on_cycle_start(174): Cycle 7/500 (29.021 s elapsed) --------------------
# 2023-02-16 12:27:23.320 - [NOTICE] callbacks.on_step_start(182): Cycle 7/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:27:26.743 - [NOTICE] callbacks.on_step_start(182): Cycle 7/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:27:26.981 - [NOTICE] callbacks.on_step_start(182): Cycle 7/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:27:27.951 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.465 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:27:27.952 - [NOTICE] callbacks.on_cycle_start(174): Cycle 8/500 (33.654 s elapsed) --------------------
# 2023-02-16 12:27:27.953 - [NOTICE] callbacks.on_step_start(182): Cycle 8/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:27:31.304 - [NOTICE] callbacks.on_step_start(182): Cycle 8/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:27:31.548 - [NOTICE] callbacks.on_step_start(182): Cycle 8/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:27:32.525 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.465 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:27:32.526 - [NOTICE] callbacks.on_cycle_start(174): Cycle 9/500 (38.228 s elapsed) --------------------
# 2023-02-16 12:27:32.527 - [NOTICE] callbacks.on_step_start(182): Cycle 9/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:27:35.916 - [NOTICE] callbacks.on_step_start(182): Cycle 9/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:27:36.153 - [NOTICE] callbacks.on_step_start(182): Cycle 9/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:27:37.133 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.464 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:27:37.133 - [NOTICE] callbacks.on_cycle_start(174): Cycle 10/500 (42.836 s elapsed) --------------------
# 2023-02-16 12:27:37.134 - [NOTICE] callbacks.on_step_start(182): Cycle 10/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:27:40.886 - [NOTICE] callbacks.on_step_start(182): Cycle 10/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:27:41.246 - [NOTICE] callbacks.on_step_start(182): Cycle 10/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:27:42.428 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.464 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:27:42.428 - [NOTICE] callbacks.on_cycle_start(174): Cycle 11/500 (48.131 s elapsed) --------------------
# 2023-02-16 12:27:42.428 - [NOTICE] callbacks.on_step_start(182): Cycle 11/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:27:45.752 - [NOTICE] callbacks.on_step_start(182): Cycle 11/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:27:46.001 - [NOTICE] callbacks.on_step_start(182): Cycle 11/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:27:46.950 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.463 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:27:46.950 - [NOTICE] callbacks.on_cycle_start(174): Cycle 12/500 (52.655 s elapsed) --------------------
# 2023-02-16 12:27:46.950 - [NOTICE] callbacks.on_step_start(182): Cycle 12/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:27:50.294 - [NOTICE] callbacks.on_step_start(182): Cycle 12/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:27:50.519 - [NOTICE] callbacks.on_step_start(182): Cycle 12/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:27:51.476 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.463 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:27:51.476 - [NOTICE] callbacks.on_cycle_start(174): Cycle 13/500 (57.183 s elapsed) --------------------
# 2023-02-16 12:27:51.476 - [NOTICE] callbacks.on_step_start(182): Cycle 13/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:27:54.783 - [NOTICE] callbacks.on_step_start(182): Cycle 13/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:27:55.024 - [NOTICE] callbacks.on_step_start(182): Cycle 13/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:27:56.044 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.462 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:27:56.044 - [NOTICE] callbacks.on_cycle_start(174): Cycle 14/500 (1 minute, 2 seconds elapsed) --------------------
# 2023-02-16 12:27:56.044 - [NOTICE] callbacks.on_step_start(182): Cycle 14/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:27:59.739 - [NOTICE] callbacks.on_step_start(182): Cycle 14/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:27:59.992 - [NOTICE] callbacks.on_step_start(182): Cycle 14/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:28:01.010 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.462 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:28:01.011 - [NOTICE] callbacks.on_cycle_start(174): Cycle 15/500 (1 minute, 7 seconds elapsed) --------------------
# 2023-02-16 12:28:01.012 - [NOTICE] callbacks.on_step_start(182): Cycle 15/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:28:04.688 - [NOTICE] callbacks.on_step_start(182): Cycle 15/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:28:04.931 - [NOTICE] callbacks.on_step_start(182): Cycle 15/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:28:05.978 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.461 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:28:05.980 - [NOTICE] callbacks.on_cycle_start(174): Cycle 16/500 (1 minute, 12 seconds elapsed) --------------------
# 2023-02-16 12:28:05.982 - [NOTICE] callbacks.on_step_start(182): Cycle 16/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:28:10.263 - [NOTICE] callbacks.on_step_start(182): Cycle 16/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:28:10.591 - [NOTICE] callbacks.on_step_start(182): Cycle 16/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:28:11.793 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.461 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:28:11.794 - [NOTICE] callbacks.on_cycle_start(174): Cycle 17/500 (1 minute, 17 seconds elapsed) --------------------
# 2023-02-16 12:28:11.795 - [NOTICE] callbacks.on_step_start(182): Cycle 17/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:28:15.557 - [NOTICE] callbacks.on_step_start(182): Cycle 17/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:28:15.789 - [NOTICE] callbacks.on_step_start(182): Cycle 17/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:28:16.757 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.460 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:28:16.757 - [NOTICE] callbacks.on_cycle_start(174): Cycle 18/500 (1 minute, 22 seconds elapsed) --------------------
# 2023-02-16 12:28:16.767 - [NOTICE] callbacks.on_step_start(182): Cycle 18/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:28:20.552 - [NOTICE] callbacks.on_step_start(182): Cycle 18/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:28:20.831 - [NOTICE] callbacks.on_step_start(182): Cycle 18/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:28:21.801 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.460 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:28:21.801 - [NOTICE] callbacks.on_cycle_start(174): Cycle 19/500 (1 minute, 28 seconds elapsed) --------------------
# 2023-02-16 12:28:21.801 - [NOTICE] callbacks.on_step_start(182): Cycle 19/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:28:25.273 - [NOTICE] callbacks.on_step_start(182): Cycle 19/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:28:25.526 - [NOTICE] callbacks.on_step_start(182): Cycle 19/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:28:26.559 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.459 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:28:26.561 - [NOTICE] callbacks.on_cycle_start(174): Cycle 20/500 (1 minute, 32 seconds elapsed) --------------------
# 2023-02-16 12:28:26.562 - [NOTICE] callbacks.on_step_start(182): Cycle 20/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:28:30.107 - [NOTICE] callbacks.on_step_start(182): Cycle 20/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:28:30.415 - [NOTICE] callbacks.on_step_start(182): Cycle 20/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:28:31.413 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.459 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:28:31.413 - [NOTICE] callbacks.on_cycle_start(174): Cycle 21/500 (1 minute, 37 seconds elapsed) --------------------
# 2023-02-16 12:28:31.413 - [NOTICE] callbacks.on_step_start(182): Cycle 21/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:28:34.829 - [NOTICE] callbacks.on_step_start(182): Cycle 21/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:28:35.067 - [NOTICE] callbacks.on_step_start(182): Cycle 21/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:28:36.047 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.458 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:28:36.048 - [NOTICE] callbacks.on_cycle_start(174): Cycle 22/500 (1 minute, 42 seconds elapsed) --------------------
# 2023-02-16 12:28:36.049 - [NOTICE] callbacks.on_step_start(182): Cycle 22/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:28:39.453 - [NOTICE] callbacks.on_step_start(182): Cycle 22/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:28:39.697 - [NOTICE] callbacks.on_step_start(182): Cycle 22/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:28:40.706 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.458 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:28:40.707 - [NOTICE] callbacks.on_cycle_start(174): Cycle 23/500 (1 minute, 46 seconds elapsed) --------------------
# 2023-02-16 12:28:40.708 - [NOTICE] callbacks.on_step_start(182): Cycle 23/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:28:44.745 - [NOTICE] callbacks.on_step_start(182): Cycle 23/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:28:45.028 - [NOTICE] callbacks.on_step_start(182): Cycle 23/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:28:46.079 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.457 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:28:46.080 - [NOTICE] callbacks.on_cycle_start(174): Cycle 24/500 (1 minute, 52 seconds elapsed) --------------------
# 2023-02-16 12:28:46.081 - [NOTICE] callbacks.on_step_start(182): Cycle 24/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:28:50.367 - [NOTICE] callbacks.on_step_start(182): Cycle 24/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:28:50.747 - [NOTICE] callbacks.on_step_start(182): Cycle 24/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:28:52.200 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.457 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:28:52.203 - [NOTICE] callbacks.on_cycle_start(174): Cycle 25/500 (1 minute, 58 seconds elapsed) --------------------
# 2023-02-16 12:28:52.204 - [NOTICE] callbacks.on_step_start(182): Cycle 25/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:28:56.727 - [NOTICE] callbacks.on_step_start(182): Cycle 25/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:28:57.127 - [NOTICE] callbacks.on_step_start(182): Cycle 25/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:28:58.326 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.456 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:28:58.328 - [NOTICE] callbacks.on_cycle_start(174): Cycle 26/500 (2 minutes, 4 seconds elapsed) --------------------
# 2023-02-16 12:28:58.329 - [NOTICE] callbacks.on_step_start(182): Cycle 26/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:29:02.204 - [NOTICE] callbacks.on_step_start(182): Cycle 26/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:29:02.464 - [NOTICE] callbacks.on_step_start(182): Cycle 26/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:29:03.440 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.456 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:29:03.450 - [NOTICE] callbacks.on_cycle_start(174): Cycle 27/500 (2 minutes, 9 seconds elapsed) --------------------
# 2023-02-16 12:29:03.450 - [NOTICE] callbacks.on_step_start(182): Cycle 27/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:29:07.187 - [NOTICE] callbacks.on_step_start(182): Cycle 27/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:29:07.431 - [NOTICE] callbacks.on_step_start(182): Cycle 27/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:29:08.385 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.455 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:29:08.385 - [NOTICE] callbacks.on_cycle_start(174): Cycle 28/500 (2 minutes, 14 seconds elapsed) --------------------
# 2023-02-16 12:29:08.385 - [NOTICE] callbacks.on_step_start(182): Cycle 28/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:29:11.945 - [NOTICE] callbacks.on_step_start(182): Cycle 28/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:29:12.195 - [NOTICE] callbacks.on_step_start(182): Cycle 28/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:29:13.178 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.455 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:29:13.178 - [NOTICE] callbacks.on_cycle_start(174): Cycle 29/500 (2 minutes, 19 seconds elapsed) --------------------
# 2023-02-16 12:29:13.178 - [NOTICE] callbacks.on_step_start(182): Cycle 29/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:29:17.055 - [NOTICE] callbacks.on_step_start(182): Cycle 29/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:29:17.290 - [NOTICE] callbacks.on_step_start(182): Cycle 29/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:29:18.311 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.454 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:29:18.313 - [NOTICE] callbacks.on_cycle_start(174): Cycle 30/500 (2 minutes, 24 seconds elapsed) --------------------
# 2023-02-16 12:29:18.313 - [NOTICE] callbacks.on_step_start(182): Cycle 30/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:29:21.722 - [NOTICE] callbacks.on_step_start(182): Cycle 30/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:29:21.964 - [NOTICE] callbacks.on_step_start(182): Cycle 30/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:29:22.914 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.454 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:29:22.915 - [NOTICE] callbacks.on_cycle_start(174): Cycle 31/500 (2 minutes, 29 seconds elapsed) --------------------
# 2023-02-16 12:29:22.915 - [NOTICE] callbacks.on_step_start(182): Cycle 31/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:29:26.352 - [NOTICE] callbacks.on_step_start(182): Cycle 31/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:29:26.612 - [NOTICE] callbacks.on_step_start(182): Cycle 31/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:29:27.560 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.453 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:29:27.560 - [NOTICE] callbacks.on_cycle_start(174): Cycle 32/500 (2 minutes, 33 seconds elapsed) --------------------
# 2023-02-16 12:29:27.560 - [NOTICE] callbacks.on_step_start(182): Cycle 32/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:29:31.017 - [NOTICE] callbacks.on_step_start(182): Cycle 32/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:29:31.251 - [NOTICE] callbacks.on_step_start(182): Cycle 32/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:29:32.206 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.453 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:29:32.206 - [NOTICE] callbacks.on_cycle_start(174): Cycle 33/500 (2 minutes, 38 seconds elapsed) --------------------
# 2023-02-16 12:29:32.206 - [NOTICE] callbacks.on_step_start(182): Cycle 33/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:29:35.476 - [NOTICE] callbacks.on_step_start(182): Cycle 33/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:29:35.716 - [NOTICE] callbacks.on_step_start(182): Cycle 33/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:29:36.668 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.452 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:29:36.668 - [NOTICE] callbacks.on_cycle_start(174): Cycle 34/500 (2 minutes, 42 seconds elapsed) --------------------
# 2023-02-16 12:29:36.668 - [NOTICE] callbacks.on_step_start(182): Cycle 34/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:29:40.102 - [NOTICE] callbacks.on_step_start(182): Cycle 34/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:29:40.372 - [NOTICE] callbacks.on_step_start(182): Cycle 34/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:29:41.422 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.452 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:29:41.423 - [NOTICE] callbacks.on_cycle_start(174): Cycle 35/500 (2 minutes, 47 seconds elapsed) --------------------
# 2023-02-16 12:29:41.423 - [NOTICE] callbacks.on_step_start(182): Cycle 35/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:29:45.143 - [NOTICE] callbacks.on_step_start(182): Cycle 35/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:29:45.405 - [NOTICE] callbacks.on_step_start(182): Cycle 35/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:29:46.389 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.451 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:29:46.391 - [NOTICE] callbacks.on_cycle_start(174): Cycle 36/500 (2 minutes, 52 seconds elapsed) --------------------
# 2023-02-16 12:29:46.391 - [NOTICE] callbacks.on_step_start(182): Cycle 36/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:29:50.315 - [NOTICE] callbacks.on_step_start(182): Cycle 36/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:29:50.655 - [NOTICE] callbacks.on_step_start(182): Cycle 36/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:29:51.839 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.451 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:29:51.840 - [NOTICE] callbacks.on_cycle_start(174): Cycle 37/500 (2 minutes, 58 seconds elapsed) --------------------
# 2023-02-16 12:29:51.841 - [NOTICE] callbacks.on_step_start(182): Cycle 37/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:29:56.813 - [NOTICE] callbacks.on_step_start(182): Cycle 37/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:29:57.270 - [NOTICE] callbacks.on_step_start(182): Cycle 37/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:29:58.387 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.450 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:29:58.394 - [NOTICE] callbacks.on_cycle_start(174): Cycle 38/500 (3 minutes, 4 seconds elapsed) --------------------
# 2023-02-16 12:29:58.394 - [NOTICE] callbacks.on_step_start(182): Cycle 38/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:30:02.057 - [NOTICE] callbacks.on_step_start(182): Cycle 38/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:30:02.304 - [NOTICE] callbacks.on_step_start(182): Cycle 38/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:30:03.288 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.450 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:30:03.290 - [NOTICE] callbacks.on_cycle_start(174): Cycle 39/500 (3 minutes, 9 seconds elapsed) --------------------
# 2023-02-16 12:30:03.290 - [NOTICE] callbacks.on_step_start(182): Cycle 39/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:30:06.767 - [NOTICE] callbacks.on_step_start(182): Cycle 39/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:30:07.015 - [NOTICE] callbacks.on_step_start(182): Cycle 39/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:30:07.969 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.449 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:30:07.969 - [NOTICE] callbacks.on_cycle_start(174): Cycle 40/500 (3 minutes, 14 seconds elapsed) --------------------
# 2023-02-16 12:30:07.969 - [NOTICE] callbacks.on_step_start(182): Cycle 40/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:30:11.785 - [NOTICE] callbacks.on_step_start(182): Cycle 40/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:30:12.048 - [NOTICE] callbacks.on_step_start(182): Cycle 40/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:30:13.110 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.449 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:30:13.111 - [NOTICE] callbacks.on_cycle_start(174): Cycle 41/500 (3 minutes, 19 seconds elapsed) --------------------
# 2023-02-16 12:30:13.112 - [NOTICE] callbacks.on_step_start(182): Cycle 41/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:30:17.207 - [NOTICE] callbacks.on_step_start(182): Cycle 41/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:30:17.517 - [NOTICE] callbacks.on_step_start(182): Cycle 41/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:30:18.689 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.448 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:30:18.690 - [NOTICE] callbacks.on_cycle_start(174): Cycle 42/500 (3 minutes, 24 seconds elapsed) --------------------
# 2023-02-16 12:30:18.690 - [NOTICE] callbacks.on_step_start(182): Cycle 42/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:30:22.637 - [NOTICE] callbacks.on_step_start(182): Cycle 42/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:30:22.885 - [NOTICE] callbacks.on_step_start(182): Cycle 42/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:30:23.884 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.448 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:30:23.884 - [NOTICE] callbacks.on_cycle_start(174): Cycle 43/500 (3 minutes, 30 seconds elapsed) --------------------
# 2023-02-16 12:30:23.894 - [NOTICE] callbacks.on_step_start(182): Cycle 43/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:30:27.379 - [NOTICE] callbacks.on_step_start(182): Cycle 43/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:30:27.618 - [NOTICE] callbacks.on_step_start(182): Cycle 43/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:30:28.631 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.447 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:30:28.632 - [NOTICE] callbacks.on_cycle_start(174): Cycle 44/500 (3 minutes, 34 seconds elapsed) --------------------
# 2023-02-16 12:30:28.633 - [NOTICE] callbacks.on_step_start(182): Cycle 44/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:30:32.436 - [NOTICE] callbacks.on_step_start(182): Cycle 44/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:30:32.685 - [NOTICE] callbacks.on_step_start(182): Cycle 44/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:30:33.649 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.447 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:30:33.650 - [NOTICE] callbacks.on_cycle_start(174): Cycle 45/500 (3 minutes, 39 seconds elapsed) --------------------
# 2023-02-16 12:30:33.651 - [NOTICE] callbacks.on_step_start(182): Cycle 45/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:30:37.451 - [NOTICE] callbacks.on_step_start(182): Cycle 45/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:30:37.700 - [NOTICE] callbacks.on_step_start(182): Cycle 45/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:30:38.704 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.446 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:30:38.705 - [NOTICE] callbacks.on_cycle_start(174): Cycle 46/500 (3 minutes, 44 seconds elapsed) --------------------
# 2023-02-16 12:30:38.705 - [NOTICE] callbacks.on_step_start(182): Cycle 46/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:30:42.169 - [NOTICE] callbacks.on_step_start(182): Cycle 46/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:30:42.405 - [NOTICE] callbacks.on_step_start(182): Cycle 46/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:30:43.365 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.446 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:30:43.375 - [NOTICE] callbacks.on_cycle_start(174): Cycle 47/500 (3 minutes, 49 seconds elapsed) --------------------
# 2023-02-16 12:30:43.375 - [NOTICE] callbacks.on_step_start(182): Cycle 47/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:30:46.630 - [NOTICE] callbacks.on_step_start(182): Cycle 47/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:30:46.869 - [NOTICE] callbacks.on_step_start(182): Cycle 47/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:30:47.851 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.446 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:30:47.852 - [NOTICE] callbacks.on_cycle_start(174): Cycle 48/500 (3 minutes, 54 seconds elapsed) --------------------
# 2023-02-16 12:30:47.853 - [NOTICE] callbacks.on_step_start(182): Cycle 48/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:30:51.293 - [NOTICE] callbacks.on_step_start(182): Cycle 48/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:30:51.530 - [NOTICE] callbacks.on_step_start(182): Cycle 48/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:30:52.519 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.445 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:30:52.529 - [NOTICE] callbacks.on_cycle_start(174): Cycle 49/500 (3 minutes, 58 seconds elapsed) --------------------
# 2023-02-16 12:30:52.529 - [NOTICE] callbacks.on_step_start(182): Cycle 49/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:30:55.803 - [NOTICE] callbacks.on_step_start(182): Cycle 49/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:30:56.047 - [NOTICE] callbacks.on_step_start(182): Cycle 49/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:30:57.043 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.445 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:30:57.043 - [NOTICE] callbacks.on_cycle_start(174): Cycle 50/500 (4 minutes, 3 seconds elapsed) --------------------
# 2023-02-16 12:30:57.043 - [NOTICE] callbacks.on_step_start(182): Cycle 50/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:31:00.352 - [NOTICE] callbacks.on_step_start(182): Cycle 50/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:31:00.593 - [NOTICE] callbacks.on_step_start(182): Cycle 50/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:31:01.597 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.444 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:31:01.598 - [NOTICE] callbacks.on_cycle_start(174): Cycle 51/500 (4 minutes, 7 seconds elapsed) --------------------
# 2023-02-16 12:31:01.599 - [NOTICE] callbacks.on_step_start(182): Cycle 51/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:31:04.935 - [NOTICE] callbacks.on_step_start(182): Cycle 51/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:31:05.174 - [NOTICE] callbacks.on_step_start(182): Cycle 51/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:31:06.155 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.444 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:31:06.155 - [NOTICE] callbacks.on_cycle_start(174): Cycle 52/500 (4 minutes, 12 seconds elapsed) --------------------
# 2023-02-16 12:31:06.155 - [NOTICE] callbacks.on_step_start(182): Cycle 52/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:31:09.449 - [NOTICE] callbacks.on_step_start(182): Cycle 52/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:31:09.694 - [NOTICE] callbacks.on_step_start(182): Cycle 52/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:31:10.643 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.443 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:31:10.643 - [NOTICE] callbacks.on_cycle_start(174): Cycle 53/500 (4 minutes, 16 seconds elapsed) --------------------
# 2023-02-16 12:31:10.643 - [NOTICE] callbacks.on_step_start(182): Cycle 53/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:31:13.916 - [NOTICE] callbacks.on_step_start(182): Cycle 53/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:31:14.178 - [NOTICE] callbacks.on_step_start(182): Cycle 53/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:31:15.177 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.443 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:31:15.177 - [NOTICE] callbacks.on_cycle_start(174): Cycle 54/500 (4 minutes, 21 seconds elapsed) --------------------
# 2023-02-16 12:31:15.187 - [NOTICE] callbacks.on_step_start(182): Cycle 54/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:31:18.961 - [NOTICE] callbacks.on_step_start(182): Cycle 54/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:31:19.195 - [NOTICE] callbacks.on_step_start(182): Cycle 54/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:31:20.134 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.442 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:31:20.134 - [NOTICE] callbacks.on_cycle_start(174): Cycle 55/500 (4 minutes, 26 seconds elapsed) --------------------
# 2023-02-16 12:31:20.134 - [NOTICE] callbacks.on_step_start(182): Cycle 55/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:31:23.477 - [NOTICE] callbacks.on_step_start(182): Cycle 55/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:31:23.711 - [NOTICE] callbacks.on_step_start(182): Cycle 55/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:31:24.660 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.442 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:31:24.660 - [NOTICE] callbacks.on_cycle_start(174): Cycle 56/500 (4 minutes, 30 seconds elapsed) --------------------
# 2023-02-16 12:31:24.660 - [NOTICE] callbacks.on_step_start(182): Cycle 56/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:31:27.949 - [NOTICE] callbacks.on_step_start(182): Cycle 56/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:31:28.178 - [NOTICE] callbacks.on_step_start(182): Cycle 56/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:31:29.131 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.441 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:31:29.131 - [NOTICE] callbacks.on_cycle_start(174): Cycle 57/500 (4 minutes, 35 seconds elapsed) --------------------
# 2023-02-16 12:31:29.131 - [NOTICE] callbacks.on_step_start(182): Cycle 57/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:31:32.541 - [NOTICE] callbacks.on_step_start(182): Cycle 57/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:31:32.769 - [NOTICE] callbacks.on_step_start(182): Cycle 57/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:31:33.721 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.441 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:31:33.731 - [NOTICE] callbacks.on_cycle_start(174): Cycle 58/500 (4 minutes, 39 seconds elapsed) --------------------
# 2023-02-16 12:31:33.731 - [NOTICE] callbacks.on_step_start(182): Cycle 58/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:31:37.154 - [NOTICE] callbacks.on_step_start(182): Cycle 58/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:31:37.380 - [NOTICE] callbacks.on_step_start(182): Cycle 58/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:31:38.337 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.440 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:31:38.337 - [NOTICE] callbacks.on_cycle_start(174): Cycle 59/500 (4 minutes, 44 seconds elapsed) --------------------
# 2023-02-16 12:31:38.337 - [NOTICE] callbacks.on_step_start(182): Cycle 59/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:31:41.607 - [NOTICE] callbacks.on_step_start(182): Cycle 59/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:31:41.842 - [NOTICE] callbacks.on_step_start(182): Cycle 59/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:31:42.780 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.440 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:31:42.780 - [NOTICE] callbacks.on_cycle_start(174): Cycle 60/500 (4 minutes, 48 seconds elapsed) --------------------
# 2023-02-16 12:31:42.780 - [NOTICE] callbacks.on_step_start(182): Cycle 60/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:31:46.061 - [NOTICE] callbacks.on_step_start(182): Cycle 60/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:31:46.294 - [NOTICE] callbacks.on_step_start(182): Cycle 60/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:31:47.237 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.439 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:31:47.237 - [NOTICE] callbacks.on_cycle_start(174): Cycle 61/500 (4 minutes, 53 seconds elapsed) --------------------
# 2023-02-16 12:31:47.237 - [NOTICE] callbacks.on_step_start(182): Cycle 61/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:31:50.709 - [NOTICE] callbacks.on_step_start(182): Cycle 61/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:31:50.940 - [NOTICE] callbacks.on_step_start(182): Cycle 61/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:31:51.880 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.439 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:31:51.880 - [NOTICE] callbacks.on_cycle_start(174): Cycle 62/500 (4 minutes, 58 seconds elapsed) --------------------
# 2023-02-16 12:31:51.880 - [NOTICE] callbacks.on_step_start(182): Cycle 62/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:31:55.146 - [NOTICE] callbacks.on_step_start(182): Cycle 62/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:31:55.387 - [NOTICE] callbacks.on_step_start(182): Cycle 62/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:31:56.323 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.438 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:31:56.323 - [NOTICE] callbacks.on_cycle_start(174): Cycle 63/500 (5 minutes, 2 seconds elapsed) --------------------
# 2023-02-16 12:31:56.323 - [NOTICE] callbacks.on_step_start(182): Cycle 63/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:31:59.623 - [NOTICE] callbacks.on_step_start(182): Cycle 63/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:31:59.852 - [NOTICE] callbacks.on_step_start(182): Cycle 63/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:32:00.804 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.438 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:32:00.804 - [NOTICE] callbacks.on_cycle_start(174): Cycle 64/500 (5 minutes, 7 seconds elapsed) --------------------
# 2023-02-16 12:32:00.804 - [NOTICE] callbacks.on_step_start(182): Cycle 64/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:32:04.075 - [NOTICE] callbacks.on_step_start(182): Cycle 64/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:32:04.304 - [NOTICE] callbacks.on_step_start(182): Cycle 64/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:32:05.257 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.437 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:32:05.257 - [NOTICE] callbacks.on_cycle_start(174): Cycle 65/500 (5 minutes, 11 seconds elapsed) --------------------
# 2023-02-16 12:32:05.257 - [NOTICE] callbacks.on_step_start(182): Cycle 65/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:32:08.538 - [NOTICE] callbacks.on_step_start(182): Cycle 65/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:32:08.783 - [NOTICE] callbacks.on_step_start(182): Cycle 65/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:32:09.732 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.437 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:32:09.733 - [NOTICE] callbacks.on_cycle_start(174): Cycle 66/500 (5 minutes, 15 seconds elapsed) --------------------
# 2023-02-16 12:32:09.734 - [NOTICE] callbacks.on_step_start(182): Cycle 66/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:32:12.984 - [NOTICE] callbacks.on_step_start(182): Cycle 66/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:32:13.224 - [NOTICE] callbacks.on_step_start(182): Cycle 66/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:32:14.202 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.436 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:32:14.202 - [NOTICE] callbacks.on_cycle_start(174): Cycle 67/500 (5 minutes, 20 seconds elapsed) --------------------
# 2023-02-16 12:32:14.202 - [NOTICE] callbacks.on_step_start(182): Cycle 67/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:32:17.439 - [NOTICE] callbacks.on_step_start(182): Cycle 67/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:32:17.678 - [NOTICE] callbacks.on_step_start(182): Cycle 67/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:32:18.628 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.436 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:32:18.628 - [NOTICE] callbacks.on_cycle_start(174): Cycle 68/500 (5 minutes, 24 seconds elapsed) --------------------
# 2023-02-16 12:32:18.628 - [NOTICE] callbacks.on_step_start(182): Cycle 68/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:32:22.061 - [NOTICE] callbacks.on_step_start(182): Cycle 68/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:32:22.293 - [NOTICE] callbacks.on_step_start(182): Cycle 68/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:32:23.253 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.435 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:32:23.253 - [NOTICE] callbacks.on_cycle_start(174): Cycle 69/500 (5 minutes, 29 seconds elapsed) --------------------
# 2023-02-16 12:32:23.253 - [NOTICE] callbacks.on_step_start(182): Cycle 69/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:32:26.485 - [NOTICE] callbacks.on_step_start(182): Cycle 69/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:32:26.709 - [NOTICE] callbacks.on_step_start(182): Cycle 69/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:32:27.671 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.435 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:32:27.671 - [NOTICE] callbacks.on_cycle_start(174): Cycle 70/500 (5 minutes, 33 seconds elapsed) --------------------
# 2023-02-16 12:32:27.671 - [NOTICE] callbacks.on_step_start(182): Cycle 70/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:32:31.047 - [NOTICE] callbacks.on_step_start(182): Cycle 70/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:32:31.285 - [NOTICE] callbacks.on_step_start(182): Cycle 70/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:32:32.230 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.434 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:32:32.230 - [NOTICE] callbacks.on_cycle_start(174): Cycle 71/500 (5 minutes, 38 seconds elapsed) --------------------
# 2023-02-16 12:32:32.230 - [NOTICE] callbacks.on_step_start(182): Cycle 71/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:32:35.465 - [NOTICE] callbacks.on_step_start(182): Cycle 71/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:32:35.708 - [NOTICE] callbacks.on_step_start(182): Cycle 71/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:32:36.657 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.434 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:32:36.657 - [NOTICE] callbacks.on_cycle_start(174): Cycle 72/500 (5 minutes, 42 seconds elapsed) --------------------
# 2023-02-16 12:32:36.657 - [NOTICE] callbacks.on_step_start(182): Cycle 72/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:32:39.909 - [NOTICE] callbacks.on_step_start(182): Cycle 72/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:32:40.136 - [NOTICE] callbacks.on_step_start(182): Cycle 72/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:32:41.069 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.433 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:32:41.079 - [NOTICE] callbacks.on_cycle_start(174): Cycle 73/500 (5 minutes, 47 seconds elapsed) --------------------
# 2023-02-16 12:32:41.079 - [NOTICE] callbacks.on_step_start(182): Cycle 73/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:32:44.318 - [NOTICE] callbacks.on_step_start(182): Cycle 73/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:32:44.545 - [NOTICE] callbacks.on_step_start(182): Cycle 73/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:32:45.496 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.433 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:32:45.496 - [NOTICE] callbacks.on_cycle_start(174): Cycle 74/500 (5 minutes, 51 seconds elapsed) --------------------
# 2023-02-16 12:32:45.496 - [NOTICE] callbacks.on_step_start(182): Cycle 74/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:32:48.725 - [NOTICE] callbacks.on_step_start(182): Cycle 74/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:32:49.148 - [NOTICE] callbacks.on_step_start(182): Cycle 74/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:32:50.086 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.432 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:32:50.087 - [NOTICE] callbacks.on_cycle_start(174): Cycle 75/500 (5 minutes, 56 seconds elapsed) --------------------
# 2023-02-16 12:32:50.088 - [NOTICE] callbacks.on_step_start(182): Cycle 75/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:32:53.349 - [NOTICE] callbacks.on_step_start(182): Cycle 75/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:32:53.574 - [NOTICE] callbacks.on_step_start(182): Cycle 75/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:32:54.520 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.432 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:32:54.520 - [NOTICE] callbacks.on_cycle_start(174): Cycle 76/500 (6 minutes, 0 seconds elapsed) --------------------
# 2023-02-16 12:32:54.520 - [NOTICE] callbacks.on_step_start(182): Cycle 76/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:32:57.740 - [NOTICE] callbacks.on_step_start(182): Cycle 76/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:32:57.966 - [NOTICE] callbacks.on_step_start(182): Cycle 76/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:32:58.900 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.431 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:32:58.900 - [NOTICE] callbacks.on_cycle_start(174): Cycle 77/500 (6 minutes, 5 seconds elapsed) --------------------
# 2023-02-16 12:32:58.900 - [NOTICE] callbacks.on_step_start(182): Cycle 77/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:33:02.150 - [NOTICE] callbacks.on_step_start(182): Cycle 77/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:33:02.400 - [NOTICE] callbacks.on_step_start(182): Cycle 77/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:33:03.351 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.431 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:33:03.351 - [NOTICE] callbacks.on_cycle_start(174): Cycle 78/500 (6 minutes, 9 seconds elapsed) --------------------
# 2023-02-16 12:33:03.351 - [NOTICE] callbacks.on_step_start(182): Cycle 78/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:33:06.554 - [NOTICE] callbacks.on_step_start(182): Cycle 78/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:33:06.790 - [NOTICE] callbacks.on_step_start(182): Cycle 78/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:33:07.729 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.430 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:33:07.739 - [NOTICE] callbacks.on_cycle_start(174): Cycle 79/500 (6 minutes, 13 seconds elapsed) --------------------
# ...
# 2023-02-16 12:41:12.558 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.378 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:41:12.559 - [NOTICE] callbacks.on_cycle_start(174): Cycle 188/500 (14 minutes, 18 seconds elapsed) --------------------
# 2023-02-16 12:41:12.560 - [NOTICE] callbacks.on_step_start(182): Cycle 188/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:41:15.652 - [NOTICE] callbacks.on_step_start(182): Cycle 188/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:41:15.871 - [NOTICE] callbacks.on_step_start(182): Cycle 188/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:41:16.817 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.378 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:41:16.819 - [NOTICE] callbacks.on_cycle_start(174): Cycle 189/500 (14 minutes, 23 seconds elapsed) --------------------
# 2023-02-16 12:41:16.819 - [NOTICE] callbacks.on_step_start(182): Cycle 189/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:41:19.881 - [NOTICE] callbacks.on_step_start(182): Cycle 189/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:41:20.104 - [NOTICE] callbacks.on_step_start(182): Cycle 189/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:41:21.044 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.377 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:41:21.044 - [NOTICE] callbacks.on_cycle_start(174): Cycle 190/500 (14 minutes, 27 seconds elapsed) --------------------
# 2023-02-16 12:41:21.044 - [NOTICE] callbacks.on_step_start(182): Cycle 190/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:41:24.108 - [NOTICE] callbacks.on_step_start(182): Cycle 190/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:41:24.318 - [NOTICE] callbacks.on_step_start(182): Cycle 190/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:41:25.266 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.377 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:41:25.266 - [NOTICE] callbacks.on_cycle_start(174): Cycle 191/500 (14 minutes, 31 seconds elapsed) --------------------
# 2023-02-16 12:41:25.266 - [NOTICE] callbacks.on_step_start(182): Cycle 191/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:41:28.554 - [NOTICE] callbacks.on_step_start(182): Cycle 191/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:41:28.762 - [NOTICE] callbacks.on_step_start(182): Cycle 191/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:41:29.715 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.376 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:41:29.716 - [NOTICE] callbacks.on_cycle_start(174): Cycle 192/500 (14 minutes, 35 seconds elapsed) --------------------
# 2023-02-16 12:41:29.717 - [NOTICE] callbacks.on_step_start(182): Cycle 192/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:41:32.761 - [NOTICE] callbacks.on_step_start(182): Cycle 192/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:41:32.987 - [NOTICE] callbacks.on_step_start(182): Cycle 192/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:41:33.924 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.376 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:41:33.924 - [NOTICE] callbacks.on_cycle_start(174): Cycle 193/500 (14 minutes, 40 seconds elapsed) --------------------
# 2023-02-16 12:41:33.924 - [NOTICE] callbacks.on_step_start(182): Cycle 193/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:41:36.940 - [NOTICE] callbacks.on_step_start(182): Cycle 193/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:41:37.157 - [NOTICE] callbacks.on_step_start(182): Cycle 193/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:41:38.096 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.375 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:41:38.106 - [NOTICE] callbacks.on_cycle_start(174): Cycle 194/500 (14 minutes, 44 seconds elapsed) --------------------
# 2023-02-16 12:41:38.106 - [NOTICE] callbacks.on_step_start(182): Cycle 194/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:41:41.130 - [NOTICE] callbacks.on_step_start(182): Cycle 194/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:41:41.349 - [NOTICE] callbacks.on_step_start(182): Cycle 194/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:41:42.310 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.375 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:41:42.310 - [NOTICE] callbacks.on_cycle_start(174): Cycle 195/500 (14 minutes, 48 seconds elapsed) --------------------
# 2023-02-16 12:41:42.310 - [NOTICE] callbacks.on_step_start(182): Cycle 195/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:41:45.413 - [NOTICE] callbacks.on_step_start(182): Cycle 195/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:41:45.631 - [NOTICE] callbacks.on_step_start(182): Cycle 195/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:41:46.582 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.374 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:41:46.582 - [NOTICE] callbacks.on_cycle_start(174): Cycle 196/500 (14 minutes, 52 seconds elapsed) --------------------
# 2023-02-16 12:41:46.582 - [NOTICE] callbacks.on_step_start(182): Cycle 196/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:41:49.652 - [NOTICE] callbacks.on_step_start(182): Cycle 196/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:41:49.862 - [NOTICE] callbacks.on_step_start(182): Cycle 196/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:41:50.855 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.374 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:41:50.856 - [NOTICE] callbacks.on_cycle_start(174): Cycle 197/500 (14 minutes, 57 seconds elapsed) --------------------
# 2023-02-16 12:41:50.857 - [NOTICE] callbacks.on_step_start(182): Cycle 197/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:41:53.931 - [NOTICE] callbacks.on_step_start(182): Cycle 197/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:41:54.152 - [NOTICE] callbacks.on_step_start(182): Cycle 197/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:41:55.092 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.373 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:41:55.103 - [NOTICE] callbacks.on_cycle_start(174): Cycle 198/500 (15 minutes, 1 second elapsed) --------------------
# 2023-02-16 12:41:55.104 - [NOTICE] callbacks.on_step_start(182): Cycle 198/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:41:58.134 - [NOTICE] callbacks.on_step_start(182): Cycle 198/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:41:58.357 - [NOTICE] callbacks.on_step_start(182): Cycle 198/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:41:59.306 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.373 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:41:59.306 - [NOTICE] callbacks.on_cycle_start(174): Cycle 199/500 (15 minutes, 5 seconds elapsed) --------------------
# 2023-02-16 12:41:59.306 - [NOTICE] callbacks.on_step_start(182): Cycle 199/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:42:02.644 - [NOTICE] callbacks.on_step_start(182): Cycle 199/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:42:02.858 - [NOTICE] callbacks.on_step_start(182): Cycle 199/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:42:03.801 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.372 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:42:03.801 - [NOTICE] callbacks.on_cycle_start(174): Cycle 200/500 (15 minutes, 10 seconds elapsed) --------------------
# 2023-02-16 12:42:03.811 - [NOTICE] callbacks.on_step_start(182): Cycle 200/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:42:06.842 - [NOTICE] callbacks.on_step_start(182): Cycle 200/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:42:07.050 - [NOTICE] callbacks.on_step_start(182): Cycle 200/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:42:08.002 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.372 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:42:08.003 - [NOTICE] callbacks.on_cycle_start(174): Cycle 201/500 (15 minutes, 14 seconds elapsed) --------------------
# 2023-02-16 12:42:08.004 - [NOTICE] callbacks.on_step_start(182): Cycle 201/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:42:11.032 - [NOTICE] callbacks.on_step_start(182): Cycle 201/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:42:11.250 - [NOTICE] callbacks.on_step_start(182): Cycle 201/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:42:12.198 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.372 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:42:12.198 - [NOTICE] callbacks.on_cycle_start(174): Cycle 202/500 (15 minutes, 18 seconds elapsed) --------------------
# 2023-02-16 12:42:12.198 - [NOTICE] callbacks.on_step_start(182): Cycle 202/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:42:15.327 - [NOTICE] callbacks.on_step_start(182): Cycle 202/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:42:15.545 - [NOTICE] callbacks.on_step_start(182): Cycle 202/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:42:16.490 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.371 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:42:16.500 - [NOTICE] callbacks.on_cycle_start(174): Cycle 203/500 (15 minutes, 22 seconds elapsed) --------------------
# 2023-02-16 12:42:16.500 - [NOTICE] callbacks.on_step_start(182): Cycle 203/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:42:19.675 - [NOTICE] callbacks.on_step_start(182): Cycle 203/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:42:19.880 - [NOTICE] callbacks.on_step_start(182): Cycle 203/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:42:20.843 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.371 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:42:20.843 - [NOTICE] callbacks.on_cycle_start(174): Cycle 204/500 (15 minutes, 27 seconds elapsed) --------------------
# 2023-02-16 12:42:20.843 - [NOTICE] callbacks.on_step_start(182): Cycle 204/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:42:23.880 - [NOTICE] callbacks.on_step_start(182): Cycle 204/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:42:24.090 - [NOTICE] callbacks.on_step_start(182): Cycle 204/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:42:25.031 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.370 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:42:25.031 - [NOTICE] callbacks.on_cycle_start(174): Cycle 205/500 (15 minutes, 31 seconds elapsed) --------------------
# 2023-02-16 12:42:25.031 - [NOTICE] callbacks.on_step_start(182): Cycle 205/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:42:28.078 - [NOTICE] callbacks.on_step_start(182): Cycle 205/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:42:28.290 - [NOTICE] callbacks.on_step_start(182): Cycle 205/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:42:29.242 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.370 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:42:29.244 - [NOTICE] callbacks.on_cycle_start(174): Cycle 206/500 (15 minutes, 35 seconds elapsed) --------------------
# 2023-02-16 12:42:29.244 - [NOTICE] callbacks.on_step_start(182): Cycle 206/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:42:32.292 - [NOTICE] callbacks.on_step_start(182): Cycle 206/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:42:32.501 - [NOTICE] callbacks.on_step_start(182): Cycle 206/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:42:33.459 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.369 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:42:33.459 - [NOTICE] callbacks.on_cycle_start(174): Cycle 207/500 (15 minutes, 39 seconds elapsed) --------------------
# 2023-02-16 12:42:33.459 - [NOTICE] callbacks.on_step_start(182): Cycle 207/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:42:36.472 - [NOTICE] callbacks.on_step_start(182): Cycle 207/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:42:36.690 - [NOTICE] callbacks.on_step_start(182): Cycle 207/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:42:37.641 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.369 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:42:37.643 - [NOTICE] callbacks.on_cycle_start(174): Cycle 208/500 (15 minutes, 43 seconds elapsed) --------------------
# 2023-02-16 12:42:37.643 - [NOTICE] callbacks.on_step_start(182): Cycle 208/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:42:40.936 - [NOTICE] callbacks.on_step_start(182): Cycle 208/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:42:41.152 - [NOTICE] callbacks.on_step_start(182): Cycle 208/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:42:42.089 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.368 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:42:42.089 - [NOTICE] callbacks.on_cycle_start(174): Cycle 209/500 (15 minutes, 48 seconds elapsed) --------------------
# 2023-02-16 12:42:42.089 - [NOTICE] callbacks.on_step_start(182): Cycle 209/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:42:45.137 - [NOTICE] callbacks.on_step_start(182): Cycle 209/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:42:45.346 - [NOTICE] callbacks.on_step_start(182): Cycle 209/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:42:46.299 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.368 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:42:46.299 - [NOTICE] callbacks.on_cycle_start(174): Cycle 210/500 (15 minutes, 52 seconds elapsed) --------------------
# 2023-02-16 12:42:46.299 - [NOTICE] callbacks.on_step_start(182): Cycle 210/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:42:49.435 - [NOTICE] callbacks.on_step_start(182): Cycle 210/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:42:49.678 - [NOTICE] callbacks.on_step_start(182): Cycle 210/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:42:50.674 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.367 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:42:50.675 - [NOTICE] callbacks.on_cycle_start(174): Cycle 211/500 (15 minutes, 56 seconds elapsed) --------------------
# 2023-02-16 12:42:50.676 - [NOTICE] callbacks.on_step_start(182): Cycle 211/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:42:53.959 - [NOTICE] callbacks.on_step_start(182): Cycle 211/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:42:54.171 - [NOTICE] callbacks.on_step_start(182): Cycle 211/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:42:55.177 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.367 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:42:55.177 - [NOTICE] callbacks.on_cycle_start(174): Cycle 212/500 (16 minutes, 1 second elapsed) --------------------
# 2023-02-16 12:42:55.177 - [NOTICE] callbacks.on_step_start(182): Cycle 212/500, step 1/3: Run Creeted_Drive (A) for 2 hours
# 2023-02-16 12:42:58.236 - [NOTICE] callbacks.on_step_start(182): Cycle 212/500, step 2/3: Charge at C/4 until 4.2V
# 2023-02-16 12:42:58.455 - [NOTICE] callbacks.on_step_start(182): Cycle 212/500, step 3/3: Hold at 4.2V until C/10
# 2023-02-16 12:42:59.428 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.366 Ah (originally 2.468 Ah, will stop at 1.481 Ah)
# 2023-02-16 12:42:59.428 - [NOTICE] callbacks.on_cycle_start(174): Cycle 213/500 (16 minutes, 5 seconds elapsed) --------------------
# 2023-02-16 12:42:59.428 - [NOTICE] callbacks.on_step_start(182): Cycle 213/500, step 1/3: Run Creeted_Drive (A) for 2 hours

# %%
pybamm.plot_summary_variables(sol_long_Andrew_DriveOnly)

# %%
sim_long_Andrew_DriveOnly.plot(
    [
#         "Negative particle surface concentration [mol.m-3]",
#,
        "Total lithium in particles [mol]",

        "Terminal voltage [V]",
#         "X-averaged cell temperature",
        "Negative electrode SOC",
        "Positive electrode SOC",
        "Throughput capacity [A.h]"



        
    ]
)

# %%
# ADdFEWF

# %%
parameter_values_peyman = pybamm.ParameterValues(chemistry=pybamm.parameter_sets.Mohtat2020)

parameter_values_peyman.update(
    {
        # mechanical properties
        "Positive electrode Poisson's ratio": 0.3,
        "Positive electrode Young's modulus [Pa]": 375e9,
        "Positive electrode reference concentration for free of deformation [mol.m-3]": 0,
        "Positive electrode partial molar volume [m3.mol-1]": -7.28e-7,
        "Positive electrode volume change": nmc_volume_change_mohtat,
        # Loss of active materials (LAM) model
        "Positive electrode LAM constant exponential term": 2,
        "Positive electrode critical stress [Pa]": 375e6,
        # mechanical properties
        "Negative electrode Poisson's ratio": 0.2,
        "Negative electrode Young's modulus [Pa]": 15e9,
        "Negative electrode reference concentration for free of deformation [mol.m-3]": 0,
        "Negative electrode partial molar volume [m3.mol-1]": 3.1e-6,
        "Negative electrode volume change": graphite_volume_change_mohtat,
        # Loss of active materials (LAM) model
        "Negative electrode LAM constant exponential term": 2,
        "Negative electrode critical stress [Pa]": 60e6,
        # Other
        "Cell thermal expansion coefficient [m.K-1]": 1.48E-6,
        "Lower voltage cut-off [V]": 3.0,
        # Initializing Particle Concentration
        # "Initial concentration in negative electrode [mol.m-3]": x100*parameter_values["Maximum concentration in negative electrode [mol.m-3]"],
        # "Initial concentration in positive electrode [mol.m-3]": y100*parameter_values["Maximum concentration in positive electrode [mol.m-3]"]
    },
    check_already_exists=False,
)

# %%
spm_peyman = pybamm.lithium_ion.SPM(
    {
        "SEI": "ec reaction limited",
        # "loss of active material": ("stress-driven","none"),
        "loss of active material": "stress-driven",
        # "stress-induced diffusion": "true",
        "lithium plating": "irreversible",
        "calculate discharge energy":"true"
    }
)

# %%
# spm.print_parameter_info()
param_peyman=spm_peyman.param
# parameter_values_peyman.update(
#     {
# "Electrode width [m]":0.205,
# #     "Maximum concentration in negative electrode [mol.m-3]":30000,
# "Nominal cell capacity [A.h]":2.5,
# "Maximum concentration in positive electrode [mol.m-3]":37500
        
#     }
# )
parameter_values_peyman.search("maximum")

# %%
cell = 1
cell_no,dfe,dfe_0,dfo_0,N,N_0 = load_data(cell,eSOH_DIR,oCV_DIR)
eps_n_data,eps_p_data,c_rate_c,c_rate_d,dis_set,Temp,SOC_0 = init_exp(cell_no,dfe,spm_peyman,parameter_values_peyman)
# Temp
# cell_no,dfe,N,dfo_0 = load_data_calendar(cell,eSOH_DIR,oCV_DIR)
# eps_n_data,eps_p_data,SOC_0,Temp = init_exp_calendar(cell_no,dfe,param,parameter_values)
Temp

# %%
par_val = {}
# Previous i.e. tuning mech sim sep and then Li plating
par_val[0]=[1.2715e-07,1.2727e-06,1.1992,1.353e-9]
# Using only C/5 and 1.5C Cycling aging, cost function with Cn,Cp,x100,y0
par_val[1]=[1.4819e-07,1.5114e-06,1.2484,1.4732e-09]
# Using only C/5 and 1.5C Cycling aging, cost function with Cn,Cp,C,LLI(%)
par_val[2]=[1.4493e-07,1.3608e-06,1.199,1.2138e-09]
# Using C/5, 1.5C and mixed c-rate (Ch:C/5, Dh:1.5C) Cycling aging, cost function with Cn,Cp,x100,y0
par_val[3]=[1.043e-07,1.036e-06,1.208,1.6045e-09]
# Using C/5, 1.5C and mixed c-rate (Ch:C/5, Dh:1.5C) Cycling aging, cost function with Cn,Cp,C,LLI(%)
par_val[4]=[8.755e-08,8.572e-07,1.135,1.5788e-09]
# Using C/5, 1.5C and mixed c-rate (Ch:C/5, Dh:1.5C) Cycling aging, cost function with Cn,Cp,C,LLI(%) another initial condition
par_val[5]=[8.7698e-08,8.5848e-07,1.1354,1.5778e-09]


sno = 5

# %%
parameter_values_peyman.update(
    {
#         "Positive electrode LAM constant proportional term [s-1]":8.755e-8,   #2.5112e-07, #Using Sravan's new fit Dec27 2022
#         "Negative electrode LAM constant proportional term [s-1]":8.572e-7, #2.4741e-06,
#         "Positive electrode LAM constant exponential term":1.135, #1.1942,
#         "Negative electrode LAM constant exponential term":1.135,# 1.1942,
        "Positive electrode LAM constant proportional term [s-1]": par_val[sno][0],
        "Negative electrode LAM constant proportional term [s-1]": par_val[sno][1],
        "Positive electrode LAM constant exponential term": par_val[sno][2],
        "Negative electrode LAM constant exponential term": par_val[sno][2],
        "Negative electrode active material volume fraction": eps_n_data,
        "Positive electrode active material volume fraction": eps_p_data,
        "Initial temperature [K]": 273.15+Temp,
        "Ambient temperature [K]": 273.15+Temp,
        "SEI kinetic rate constant [m.s-1]": 1.08494281e-16,
        "EC diffusivity [m2.s-1]": 8.30909086e-19,
        "SEI growth activation energy [J.mol-1]": 1.58777981e+04,
        
        "Lithium plating kinetic rate constant [m.s-1]": par_val[sno][3],
        # "SEI kinetic rate constant [m.s-1]": 1.6827e-16,
        # "EC diffusivity [m2.s-1]": 2e-18,
        # "SEI growth activation energy [J.mol-1]": 0,
        
        "Upper voltage cut-off [V]":4.2,
        "SEI resistivity [Ohm.m]":30000.0
        
        
    },
    check_already_exists=False,
)

# %%
Created_Drive_peyman = pd.read_csv(r"F:\Stefanapolu application\CRC\Drive Cycle\Created_Drive.csv", comment="#", header=None).to_numpy()
# pybamm.set_logging_level("WARNING")
experiment_Driveonly_peyman = pybamm.Experiment( #Created_ DRC-DRC
    [
        ("Run Creeted_Drive_peyman (A) for 2 hours",
         "Charge at C/4 until 4.2V",
         "Hold at 4.2V until C/10",  # needs fixing : last step +this step =2.5 hrs
 
        )

    ]*500,
    drive_cycles={"Creeted_Drive_peyman": Created_Drive_peyman},
    termination="60% capacity",
#     cccv_handling="ode",
)

eps_n_data

# %%
sim_long_peyman_DriveOnly = pybamm.Simulation(spm_peyman, experiment=experiment_Driveonly_peyman, parameter_values=parameter_values_peyman, 
                            solver=pybamm.CasadiSolver("safe",
                            rtol=1e-6, 
                            atol=1e-6,
                            dt_max=10,
                                                      ))
sol_long_peyman_DriveOnly = sim_long_peyman_DriveOnly .solve(initial_soc=1, save_at_cycles=20  )

# %%
pybamm.plot_summary_variables(sol_long_peyman_DriveOnly)

# %%
sim_long_peyman_DriveOnly.plot(
    [
#         "Negative particle surface concentration [mol.m-3]",
#,
        "Total lithium in particles [mol]",

        "Terminal voltage [V]",
#         "X-averaged cell temperature",
        "Negative electrode SOC",
        "Positive electrode SOC",
        "Throughput capacity [A.h]"



        
    ]
)
