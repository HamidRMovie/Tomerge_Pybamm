# %%
import pybamm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
import dfols
import signal
from scipy.integrate import solve_ivp
from scipy.fft import fft, fftfreq, fftshift
from scipy.signal import savgol_filter
from scipy.signal import find_peaks
from scipy import interpolate
from stopit import threading_timeoutable as timeoutable
import os, sys
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath("__file__"))))
from batfuns import *
plt.rcParams = set_rc_params(plt.rcParams)

eSOH_DIR = r"F:/Git Hub rep/CRC/neew/PyBaMM/Untitled Folder/data/esoh/"
oCV_DIR = r"F:/Git Hub rep/CRC/neew/PyBaMM/Untitled Folder/data/ocv/"
fig_DIR = "../figures/figures_fit/"
res_DIR = "../data/results_fit/"
# %matplotlib widget

from scipy.io import savemat

# %%
## Added from old vrsion

# %%
parameter_values = get_parameter_values()

# %%
parameter_values.search("sei res")
# Out:
# SEI resistivity [Ohm.m]	200000.0

# %%
spm = pybamm.lithium_ion.SPM(
    {
        "SEI": "ec reaction limited",
        "loss of active material": "stress-driven",
        "lithium plating": "irreversible",        
    }
)
# spm.print_parameter_info()
param=spm.param

# %%
cell = 1

# %%
cell_no,dfe,dfe_0,dfo_0,N,N_0 = load_data(cell,eSOH_DIR,oCV_DIR)
eps_n_data,eps_p_data,c_rate_c,c_rate_d,dis_set,Temp,SOC_0 = init_exp(cell_no,dfe,spm,parameter_values)
print(Temp)
# Out:
# 25

# %%
# pybamm.set_logging_level("WARNING")
pybamm.set_logging_level("NOTICE")


# drive_cycle = pd.read_csv(r"F:\Stefanapolu application\CRC\Drive Cycle\US06_default_5Ah.csv", comment="#", header=None).to_numpy()
# drive_cycle = pd.read_csv(r"F:\Stefanapolu application\CRC\Drive Cycle\US06_default_5A_norgen10_min.csv", comment="#", header=None).to_numpy()

# drive_cycle2 = pd.read_csv(r"F:\Stefanapolu application\CRC\Drive Cycle\US06_GM_5Ah.csv", comment="#", header=None).to_numpy()
drive_cycle_OEM1 = pd.read_csv(r"F:\Stefanapolu application\CRC\Drive Cycle\US06_GM_5Ah_norgen10_min.csv", comment="#", header=None).to_numpy()
Created_Drive = pd.read_csv(r"F:\Stefanapolu application\CRC\Drive Cycle\Created_Drive.csv", comment="#", header=None).to_numpy()

# experiment = pybamm.Experiment( # defult D.C. DRC-DRC *1.25
#     [
#         ("Run US06 (A) for 1 hours",
#          "Rest for 5 minutes",
#          "Discharge at C/4 for 1 hours", # should be P/4 
#          "Rest for 5 minutes",
#          "Charge at C/4 until 4.2V",
#          "Hold at 4.2V for .9 hours",  # needs fixing : last step +this step =2.5 hrs
#          "Rest for 20 minutes", 
#          # Home
#          "Run US06 (A) for 1 hours",
#          "Rest for 5 minutes",
#          "Discharge at C/4 for 1 hours", # should be P/4 
#          "Rest for 5 minutes",
#          "Charge at C/8 until 4.2V",
#           "Hold at 4.2V for 1.9 hours",  # needs fixing : last step +this step =2.5 hrs
#          "Rest for 20 minutes",     
#         )

#     ]*700,
#     drive_cycles={"US06": drive_cycle},
#     termination="50% capacity",
# #     cccv_handling="ode",
# )

# experiment2 = pybamm.Experiment( #lab cycling
#     [
#         ("Discharge at "+c_rate_d+dis_set,
#          "Rest for 5 min",
#          "Charge at "+c_rate_c+" until 4.2V", 
#          "Hold at 4.2V until C/50")
#     ] *2,
#     # ] *40,
#     termination="50% capacity",
# #     cccv_handling="ode",
# )

## GM_DCRDCR
experiment3 = pybamm.Experiment( #GM_ DRC-DRC
    [
        ("Run US06_OEM1 (A) for 1 hours",
         "Rest for 5 minutes",
         "Discharge at C/4 for 1 hours", # should be P/4 
         "Rest for 5 minutes",
         "Charge at C/4 until 4.2V",
         "Hold at 4.2V for .6 hours",  # needs fixing : last step +this step =2.5 hrs
         "Rest for 20 minutes", 
         # Home
         "Run US06_OEM1 (A) for 1 hours",
         "Rest for 5 minutes",
         "Discharge at C/4 for 1 hours", # should be P/4 
         "Rest for 5 minutes",
         "Charge at C/8 until 4.2V",
          "Hold at 4.2V for 1 hours",  # needs fixing : last step +this step =4.5 hrs
         "Rest for 20 minutes",     
        )

    ]*700,
    drive_cycles={"US06_OEM1": drive_cycle_OEM1},
    termination="50% capacity",
#     cccv_handling="ode",
)

experiment4 = pybamm.Experiment( #Gm-RCRC
    [
        ("Run US06_OEM1 (A) for 1 hours",
         "Rest for 5 minutes",
         "Rest for 1 hours", # should be P/4 
         "Rest for 5 minutes",
         "Charge at C/4 until 4.2V",
         "Hold at 4.2V for 1.6 hours",  # needs fixing : last step +this step =2.5 hrs
         "Rest for 20 minutes", 
         # Home
         "Run US06_OEM1 (A) for 1 hours",
         "Rest for 5 minutes",
         "Rest for 1 hours", # should be P/4 
         "Rest for 5 minutes",
         "Charge at C/8 until 4.2V",
          "Hold at 4.2V for 3.1 hours",  # needs fixing : last step +this step =4.5 hrs
         "Rest for 20 minutes",     
        )

    ]*1000,
    drive_cycles={"US06_OEM1": drive_cycle_OEM1},
    termination="50% capacity",
#     cccv_handling="ode",
)

# %%
# experiment5 = pybamm.Experiment( # defult D.C. RC-RC
#     [
#         ("Run US06 (A) for 1 hours",
#          "Rest for 5 minutes",
#          "Rest for 1 hours", # should be P/4 
#          "Rest for 5 minutes",
#          "Charge at C/4 until 4.2V",
#          "Hold at 4.2V for 1.8 hours",  # needs fixing : last step +this step =2.5 hrs
#          "Rest for 20 minutes", 
#          # Home
#          "Run US06 (A) for 1 hours",
#          "Rest for 5 minutes",
#          "Rest for 1 hours", # should be P/4 
#          "Rest for 5 minutes",
#          "Charge at C/8 until 4.2V",
#           "Hold at 4.2V for 3.7 hours",  # needs fixing : last step +this step =4.5 hrs
#          "Rest for 20 minutes",     
#         )

#     ]*1000,
#     drive_cycles={"US06": drive_cycle},
#     termination="50% capacity",
# #     cccv_handling="ode",
# )

# experiment7 = pybamm.Experiment( #Gm-CRCR
#     [
#         ("Run US06_GM_5Ah (A) for 1 hours",
#          "Rest for 5 minutes",
#          "Charge at C/4 until 4.2V",
#          "Hold at 4.2V for 1.6 hours",  # needs fixing : last step +this step =2.5 hrs        
#          "Rest for 5 minutes",
#          "Rest for 1 hours", # should be P/4 
#          "Rest for 20 minutes", 
#          # Home
#          "Run US06_GM_5Ah (A) for 1 hours",
#          "Rest for 5 minutes",
#          "Rest for 5 minutes",
#          "Charge at C/8 until 4.2V",
#          "Hold at 4.2V for 3.1 hours",  # needs fixing : last step +this step =4.5 hrs
#          "Rest for 1 hours", # should be P/4 
#          "Rest for 20 minutes",     
#         )

#     ]*1000,
#     drive_cycles={"US06_GM_5Ah": drive_cycle2},
#     termination="50% capacity",
# #     cccv_handling="ode",
# )

# experiment8 = pybamm.Experiment( # defult D.C. CR-CR
#     [
#         ("Run US06 (A) for 1 hours",
#          "Rest for 5 minutes",
#          "Charge at C/4 until 4.2V",
#          "Hold at 4.2V for 1.8 hours",  # needs fixing : last step +this step =2.5 hrs         
#          "Rest for 1 hours", # should be P/4 
#          "Rest for 5 minutes",
#          "Rest for 20 minutes", 
#          # Home
#          "Run US06 (A) for 1 hours",
#          "Rest for 5 minutes",
#          "Charge at C/8 until 4.2V",
#          "Hold at 4.2V for 3.7 hours",  # needs fixing : last step +this step =4.5 hrs         
#          "Rest for 1 hours", # should be P/4 
#          "Rest for 5 minutes",
#          "Rest for 20 minutes",     
#         )

#     ]*1000,
#     drive_cycles={"US06": drive_cycle},
#     termination="50% capacity",
# #     cccv_handling="ode",
# )
# experiment10 = pybamm.Experiment( # defult D.C. CR-CR
#     [
#         (
#          "Rest for 12 hours",     
#         )

#     ]*1000,
#     termination="50% capacity",
# #     cccv_handling="ode",
# )

# experiment6 = pybamm.Experiment( # defult D.C. DRC-DRC *1.25 with power
#     [
#         ("Run US06 (A) for 1 hours",
#          "Rest for 5 minutes",
#          #"Discharge at C/4 for 1 hours", # should be P/4 
#          "Discharge at 5.25 W for 1 hours", # ~~~ 
#          "Rest for 5 minutes",
#          "Charge at C/4 until 4.2V",
#          "Hold at 4.2V for .75 hours",  # needs fixing : last step +this step =2.5 hrs
#          "Rest for 20 minutes", 
#          # Home
#          "Run US06 (A) for 1 hours",
#          "Rest for 5 minutes",
#          #"Discharge at C/4 for 1 hours", # should be P/4 
#          "Discharge at 5.25 W for 1 hours", # ~~~
#          "Rest for 5 minutes",
#          "Charge at C/8 until 4.2V",
#           "Hold at 4.2V for 1.75 hours",  # needs fixing : last step +this step =2.5 hrs
#          "Rest for 20 minutes",     
#         )

#     ]*520,
#     drive_cycles={"US06": drive_cycle},
#     termination="50% capacity",
# #     cccv_handling="ode",
# )

# %%
# parameter_values = get_parameter_values()

par_val = {}
# Previous i.e. tuning mech sim sep and then Li plating
par_val[0]=[1.2715e-07,1.2727e-06,1.1992,1.353e-9]
# Using only C/5 and 1.5C Cycling aging, cost function with Cn,Cp,x100,y0
par_val[1]=[1.4819e-07,1.5114e-06,1.2484,1.4732e-09]
# Using only C/5 and 1.5C Cycling aging, cost function with Cn,Cp,C,LLI(%)
par_val[2]=[1.4493e-07,1.3608e-06,1.199,1.2138e-09]
# Using C/5, 1.5C and mixed c-rate (Ch:C/5, Dh:1.5C) Cycling aging, cost function with Cn,Cp,x100,y0
par_val[3]=[1.043e-07,1.036e-06,1.208,1.6045e-09]
# Using C/5, 1.5C and mixed c-rate (Ch:C/5, Dh:1.5C) Cycling aging, cost function with Cn,Cp,C,LLI(%)
par_val[4]=[8.755e-08,8.572e-07,1.135,1.5788e-09]
# Using C/5, 1.5C and mixed c-rate (Ch:C/5, Dh:1.5C) Cycling aging, cost function with Cn,Cp,C,LLI(%) another initial condition
par_val[5]=[8.7698e-08,8.5848e-07,1.1354,1.5778e-09]


sno = 5

# %%
parameter_values.update(
    {
#         "Positive electrode LAM constant proportional term [s-1]":8.755e-8,   #2.5112e-07, #Using Sravan's new fit Dec27 2022
#         "Negative electrode LAM constant proportional term [s-1]":8.572e-7, #2.4741e-06,
#         "Positive electrode LAM constant exponential term":1.135, #1.1942,
#         "Negative electrode LAM constant exponential term":1.135,# 1.1942,
        "Positive electrode LAM constant proportional term [s-1]": par_val[sno][0],
        "Negative electrode LAM constant proportional term [s-1]": par_val[sno][1],
        "Positive electrode LAM constant exponential term": par_val[sno][2],
        "Negative electrode LAM constant exponential term": par_val[sno][2],
        "Negative electrode active material volume fraction": eps_n_data,
        "Positive electrode active material volume fraction": eps_p_data,
        "Initial temperature [K]": 273.15+Temp,
        "Ambient temperature [K]": 273.15+Temp,
        "SEI kinetic rate constant [m.s-1]": 1.08494281e-16,
        "EC diffusivity [m2.s-1]": 8.30909086e-19,
        "SEI growth activation energy [J.mol-1]": 1.58777981e+04,
        
        "Lithium plating kinetic rate constant [m.s-1]": par_val[sno][3],
        # "SEI kinetic rate constant [m.s-1]": 1.6827e-16,
        # "EC diffusivity [m2.s-1]": 2e-18,
        # "SEI growth activation energy [J.mol-1]": 0,
        
        "Upper voltage cut-off [V]":4.2,
        "SEI resistivity [Ohm.m]":30000.0
        
        
    },
    check_already_exists=False,
)

# %%
# all_sumvars_dict1 = cycle_adaptive_simulation(spm, parameter_values, experiment,SOC_0, save_at_cycles=1)

# %%
sim_long = pybamm.Simulation(spm, experiment=experiment4, parameter_values=parameter_values, 
                            solver=pybamm.CasadiSolver("safe",
                            rtol=1e-6, 
                            atol=1e-6,
                            dt_max=10,
                                                      ))
sol_long = sim_long.solve(initial_soc=1, save_at_cycles=10  )
# sol_long = sim_long.solve(save_at_cycles=1  )
# Out:
# 2023-01-27 14:49:36.986 - [NOTICE] callbacks.on_cycle_start(174): Cycle 1/1000 (17.499 ms elapsed) --------------------
# 2023-01-27 14:49:36.986 - [NOTICE] callbacks.on_step_start(182): Cycle 1/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:49:39.154 - [NOTICE] callbacks.on_step_start(182): Cycle 1/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 14:49:39.234 - [NOTICE] callbacks.on_step_start(182): Cycle 1/1000, step 3/14: Rest for 1 hours
# 2023-01-27 14:49:39.317 - [NOTICE] callbacks.on_step_start(182): Cycle 1/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 14:49:39.333 - [NOTICE] callbacks.on_step_start(182): Cycle 1/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 14:49:39.557 - [NOTICE] callbacks.on_step_start(182): Cycle 1/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 14:49:40.181 - [NOTICE] callbacks.on_step_start(182): Cycle 1/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 14:49:40.227 - [NOTICE] callbacks.on_step_start(182): Cycle 1/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:49:41.649 - [NOTICE] callbacks.on_step_start(182): Cycle 1/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 14:49:41.674 - [NOTICE] callbacks.on_step_start(182): Cycle 1/1000, step 10/14: Rest for 1 hours
# 2023-01-27 14:49:41.762 - [NOTICE] callbacks.on_step_start(182): Cycle 1/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 14:49:41.773 - [NOTICE] callbacks.on_step_start(182): Cycle 1/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 14:49:42.099 - [NOTICE] callbacks.on_step_start(182): Cycle 1/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 14:49:42.877 - [NOTICE] callbacks.on_step_start(182): Cycle 1/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 14:49:44.885 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.862 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 14:49:44.885 - [NOTICE] callbacks.on_cycle_start(174): Cycle 2/1000 (7.916 s elapsed) --------------------
# 2023-01-27 14:49:44.885 - [NOTICE] callbacks.on_step_start(182): Cycle 2/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:49:46.338 - [NOTICE] callbacks.on_step_start(182): Cycle 2/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 14:49:46.353 - [NOTICE] callbacks.on_step_start(182): Cycle 2/1000, step 3/14: Rest for 1 hours
# 2023-01-27 14:49:46.435 - [NOTICE] callbacks.on_step_start(182): Cycle 2/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 14:49:46.452 - [NOTICE] callbacks.on_step_start(182): Cycle 2/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 14:49:46.575 - [NOTICE] callbacks.on_step_start(182): Cycle 2/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 14:49:47.018 - [NOTICE] callbacks.on_step_start(182): Cycle 2/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 14:49:47.083 - [NOTICE] callbacks.on_step_start(182): Cycle 2/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:49:48.700 - [NOTICE] callbacks.on_step_start(182): Cycle 2/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 14:49:48.723 - [NOTICE] callbacks.on_step_start(182): Cycle 2/1000, step 10/14: Rest for 1 hours
# 2023-01-27 14:49:48.804 - [NOTICE] callbacks.on_step_start(182): Cycle 2/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 14:49:48.822 - [NOTICE] callbacks.on_step_start(182): Cycle 2/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 14:49:49.062 - [NOTICE] callbacks.on_step_start(182): Cycle 2/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 14:49:49.872 - [NOTICE] callbacks.on_step_start(182): Cycle 2/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 14:49:51.720 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.860 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 14:49:51.720 - [NOTICE] callbacks.on_cycle_start(174): Cycle 3/1000 (14.750 s elapsed) --------------------
# 2023-01-27 14:49:51.720 - [NOTICE] callbacks.on_step_start(182): Cycle 3/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:49:53.148 - [NOTICE] callbacks.on_step_start(182): Cycle 3/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 14:49:53.171 - [NOTICE] callbacks.on_step_start(182): Cycle 3/1000, step 3/14: Rest for 1 hours
# 2023-01-27 14:49:53.256 - [NOTICE] callbacks.on_step_start(182): Cycle 3/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 14:49:53.271 - [NOTICE] callbacks.on_step_start(182): Cycle 3/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 14:49:53.402 - [NOTICE] callbacks.on_step_start(182): Cycle 3/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 14:49:53.807 - [NOTICE] callbacks.on_step_start(182): Cycle 3/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 14:49:53.850 - [NOTICE] callbacks.on_step_start(182): Cycle 3/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:49:55.275 - [NOTICE] callbacks.on_step_start(182): Cycle 3/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 14:49:55.292 - [NOTICE] callbacks.on_step_start(182): Cycle 3/1000, step 10/14: Rest for 1 hours
# 2023-01-27 14:49:55.377 - [NOTICE] callbacks.on_step_start(182): Cycle 3/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 14:49:55.390 - [NOTICE] callbacks.on_step_start(182): Cycle 3/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 14:49:55.625 - [NOTICE] callbacks.on_step_start(182): Cycle 3/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 14:49:56.404 - [NOTICE] callbacks.on_step_start(182): Cycle 3/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 14:49:58.252 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.858 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 14:49:58.252 - [NOTICE] callbacks.on_cycle_start(174): Cycle 4/1000 (21.285 s elapsed) --------------------
# 2023-01-27 14:49:58.252 - [NOTICE] callbacks.on_step_start(182): Cycle 4/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:49:59.696 - [NOTICE] callbacks.on_step_start(182): Cycle 4/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 14:49:59.716 - [NOTICE] callbacks.on_step_start(182): Cycle 4/1000, step 3/14: Rest for 1 hours
# 2023-01-27 14:49:59.806 - [NOTICE] callbacks.on_step_start(182): Cycle 4/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 14:49:59.816 - [NOTICE] callbacks.on_step_start(182): Cycle 4/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 14:50:00.095 - [NOTICE] callbacks.on_step_start(182): Cycle 4/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 14:50:00.509 - [NOTICE] callbacks.on_step_start(182): Cycle 4/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 14:50:00.550 - [NOTICE] callbacks.on_step_start(182): Cycle 4/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:50:01.957 - [NOTICE] callbacks.on_step_start(182): Cycle 4/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 14:50:01.983 - [NOTICE] callbacks.on_step_start(182): Cycle 4/1000, step 10/14: Rest for 1 hours
# 2023-01-27 14:50:02.069 - [NOTICE] callbacks.on_step_start(182): Cycle 4/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 14:50:02.080 - [NOTICE] callbacks.on_step_start(182): Cycle 4/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 14:50:02.313 - [NOTICE] callbacks.on_step_start(182): Cycle 4/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 14:50:03.085 - [NOTICE] callbacks.on_step_start(182): Cycle 4/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 14:50:04.902 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.855 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 14:50:04.902 - [NOTICE] callbacks.on_cycle_start(174): Cycle 5/1000 (27.939 s elapsed) --------------------
# 2023-01-27 14:50:04.902 - [NOTICE] callbacks.on_step_start(182): Cycle 5/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:50:06.334 - [NOTICE] callbacks.on_step_start(182): Cycle 5/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 14:50:06.350 - [NOTICE] callbacks.on_step_start(182): Cycle 5/1000, step 3/14: Rest for 1 hours
# 2023-01-27 14:50:06.431 - [NOTICE] callbacks.on_step_start(182): Cycle 5/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 14:50:06.448 - [NOTICE] callbacks.on_step_start(182): Cycle 5/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 14:50:06.573 - [NOTICE] callbacks.on_step_start(182): Cycle 5/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 14:50:06.979 - [NOTICE] callbacks.on_step_start(182): Cycle 5/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 14:50:07.024 - [NOTICE] callbacks.on_step_start(182): Cycle 5/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:50:08.436 - [NOTICE] callbacks.on_step_start(182): Cycle 5/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 14:50:08.462 - [NOTICE] callbacks.on_step_start(182): Cycle 5/1000, step 10/14: Rest for 1 hours
# 2023-01-27 14:50:08.544 - [NOTICE] callbacks.on_step_start(182): Cycle 5/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 14:50:08.555 - [NOTICE] callbacks.on_step_start(182): Cycle 5/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 14:50:08.786 - [NOTICE] callbacks.on_step_start(182): Cycle 5/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 14:50:09.550 - [NOTICE] callbacks.on_step_start(182): Cycle 5/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 14:50:11.346 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.853 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 14:50:11.346 - [NOTICE] callbacks.on_cycle_start(174): Cycle 6/1000 (34.383 s elapsed) --------------------
# 2023-01-27 14:50:11.356 - [NOTICE] callbacks.on_step_start(182): Cycle 6/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:50:12.793 - [NOTICE] callbacks.on_step_start(182): Cycle 6/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 14:50:12.810 - [NOTICE] callbacks.on_step_start(182): Cycle 6/1000, step 3/14: Rest for 1 hours
# 2023-01-27 14:50:12.889 - [NOTICE] callbacks.on_step_start(182): Cycle 6/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 14:50:12.904 - [NOTICE] callbacks.on_step_start(182): Cycle 6/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 14:50:13.033 - [NOTICE] callbacks.on_step_start(182): Cycle 6/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 14:50:13.434 - [NOTICE] callbacks.on_step_start(182): Cycle 6/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 14:50:13.477 - [NOTICE] callbacks.on_step_start(182): Cycle 6/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:50:14.916 - [NOTICE] callbacks.on_step_start(182): Cycle 6/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 14:50:14.933 - [NOTICE] callbacks.on_step_start(182): Cycle 6/1000, step 10/14: Rest for 1 hours
# 2023-01-27 14:50:15.016 - [NOTICE] callbacks.on_step_start(182): Cycle 6/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 14:50:15.033 - [NOTICE] callbacks.on_step_start(182): Cycle 6/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 14:50:15.269 - [NOTICE] callbacks.on_step_start(182): Cycle 6/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 14:50:16.035 - [NOTICE] callbacks.on_step_start(182): Cycle 6/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 14:50:17.826 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.851 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 14:50:17.826 - [NOTICE] callbacks.on_cycle_start(174): Cycle 7/1000 (40.860 s elapsed) --------------------
# 2023-01-27 14:50:17.826 - [NOTICE] callbacks.on_step_start(182): Cycle 7/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:50:19.279 - [NOTICE] callbacks.on_step_start(182): Cycle 7/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 14:50:19.296 - [NOTICE] callbacks.on_step_start(182): Cycle 7/1000, step 3/14: Rest for 1 hours
# 2023-01-27 14:50:19.369 - [NOTICE] callbacks.on_step_start(182): Cycle 7/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 14:50:19.388 - [NOTICE] callbacks.on_step_start(182): Cycle 7/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 14:50:19.509 - [NOTICE] callbacks.on_step_start(182): Cycle 7/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 14:50:19.903 - [NOTICE] callbacks.on_step_start(182): Cycle 7/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 14:50:19.952 - [NOTICE] callbacks.on_step_start(182): Cycle 7/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:50:21.387 - [NOTICE] callbacks.on_step_start(182): Cycle 7/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 14:50:21.407 - [NOTICE] callbacks.on_step_start(182): Cycle 7/1000, step 10/14: Rest for 1 hours
# 2023-01-27 14:50:21.476 - [NOTICE] callbacks.on_step_start(182): Cycle 7/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 14:50:21.496 - [NOTICE] callbacks.on_step_start(182): Cycle 7/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 14:50:21.733 - [NOTICE] callbacks.on_step_start(182): Cycle 7/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 14:50:22.485 - [NOTICE] callbacks.on_step_start(182): Cycle 7/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 14:50:24.288 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.849 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 14:50:24.288 - [NOTICE] callbacks.on_cycle_start(174): Cycle 8/1000 (47.322 s elapsed) --------------------
# 2023-01-27 14:50:24.288 - [NOTICE] callbacks.on_step_start(182): Cycle 8/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:50:25.720 - [NOTICE] callbacks.on_step_start(182): Cycle 8/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 14:50:25.740 - [NOTICE] callbacks.on_step_start(182): Cycle 8/1000, step 3/14: Rest for 1 hours
# 2023-01-27 14:50:25.818 - [NOTICE] callbacks.on_step_start(182): Cycle 8/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 14:50:25.837 - [NOTICE] callbacks.on_step_start(182): Cycle 8/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 14:50:25.962 - [NOTICE] callbacks.on_step_start(182): Cycle 8/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 14:50:26.360 - [NOTICE] callbacks.on_step_start(182): Cycle 8/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 14:50:26.402 - [NOTICE] callbacks.on_step_start(182): Cycle 8/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:50:27.839 - [NOTICE] callbacks.on_step_start(182): Cycle 8/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 14:50:27.861 - [NOTICE] callbacks.on_step_start(182): Cycle 8/1000, step 10/14: Rest for 1 hours
# 2023-01-27 14:50:28.119 - [NOTICE] callbacks.on_step_start(182): Cycle 8/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 14:50:28.130 - [NOTICE] callbacks.on_step_start(182): Cycle 8/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 14:50:28.353 - [NOTICE] callbacks.on_step_start(182): Cycle 8/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 14:50:29.114 - [NOTICE] callbacks.on_step_start(182): Cycle 8/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 14:50:30.919 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.846 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 14:50:30.929 - [NOTICE] callbacks.on_cycle_start(174): Cycle 9/1000 (53.958 s elapsed) --------------------
# 2023-01-27 14:50:30.929 - [NOTICE] callbacks.on_step_start(182): Cycle 9/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:50:32.369 - [NOTICE] callbacks.on_step_start(182): Cycle 9/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 14:50:32.390 - [NOTICE] callbacks.on_step_start(182): Cycle 9/1000, step 3/14: Rest for 1 hours
# 2023-01-27 14:50:32.464 - [NOTICE] callbacks.on_step_start(182): Cycle 9/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 14:50:32.480 - [NOTICE] callbacks.on_step_start(182): Cycle 9/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 14:50:32.598 - [NOTICE] callbacks.on_step_start(182): Cycle 9/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 14:50:33.005 - [NOTICE] callbacks.on_step_start(182): Cycle 9/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 14:50:33.045 - [NOTICE] callbacks.on_step_start(182): Cycle 9/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:50:34.455 - [NOTICE] callbacks.on_step_start(182): Cycle 9/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 14:50:34.474 - [NOTICE] callbacks.on_step_start(182): Cycle 9/1000, step 10/14: Rest for 1 hours
# 2023-01-27 14:50:34.548 - [NOTICE] callbacks.on_step_start(182): Cycle 9/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 14:50:34.563 - [NOTICE] callbacks.on_step_start(182): Cycle 9/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 14:50:34.803 - [NOTICE] callbacks.on_step_start(182): Cycle 9/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 14:50:35.554 - [NOTICE] callbacks.on_step_start(182): Cycle 9/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 14:50:37.349 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.844 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 14:50:37.349 - [NOTICE] callbacks.on_cycle_start(174): Cycle 10/1000 (1 minute, 0 seconds elapsed) --------------------
# 2023-01-27 14:50:37.349 - [NOTICE] callbacks.on_step_start(182): Cycle 10/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:50:38.769 - [NOTICE] callbacks.on_step_start(182): Cycle 10/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 14:50:38.796 - [NOTICE] callbacks.on_step_start(182): Cycle 10/1000, step 3/14: Rest for 1 hours
# 2023-01-27 14:50:38.867 - [NOTICE] callbacks.on_step_start(182): Cycle 10/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 14:50:38.886 - [NOTICE] callbacks.on_step_start(182): Cycle 10/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 14:50:39.007 - [NOTICE] callbacks.on_step_start(182): Cycle 10/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 14:50:39.411 - [NOTICE] callbacks.on_step_start(182): Cycle 10/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 14:50:39.445 - [NOTICE] callbacks.on_step_start(182): Cycle 10/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:50:40.849 - [NOTICE] callbacks.on_step_start(182): Cycle 10/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 14:50:40.873 - [NOTICE] callbacks.on_step_start(182): Cycle 10/1000, step 10/14: Rest for 1 hours
# 2023-01-27 14:50:40.951 - [NOTICE] callbacks.on_step_start(182): Cycle 10/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 14:50:40.962 - [NOTICE] callbacks.on_step_start(182): Cycle 10/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 14:50:41.192 - [NOTICE] callbacks.on_step_start(182): Cycle 10/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 14:50:41.958 - [NOTICE] callbacks.on_step_start(182): Cycle 10/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 14:50:43.749 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.842 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 14:50:43.749 - [NOTICE] callbacks.on_cycle_start(174): Cycle 11/1000 (1 minute, 7 seconds elapsed) --------------------
# 2023-01-27 14:50:43.749 - [NOTICE] callbacks.on_step_start(182): Cycle 11/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:50:45.167 - [NOTICE] callbacks.on_step_start(182): Cycle 11/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 14:50:45.185 - [NOTICE] callbacks.on_step_start(182): Cycle 11/1000, step 3/14: Rest for 1 hours
# 2023-01-27 14:50:45.253 - [NOTICE] callbacks.on_step_start(182): Cycle 11/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 14:50:45.272 - [NOTICE] callbacks.on_step_start(182): Cycle 11/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 14:50:45.394 - [NOTICE] callbacks.on_step_start(182): Cycle 11/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 14:50:45.793 - [NOTICE] callbacks.on_step_start(182): Cycle 11/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 14:50:45.828 - [NOTICE] callbacks.on_step_start(182): Cycle 11/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:50:47.261 - [NOTICE] callbacks.on_step_start(182): Cycle 11/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 14:50:47.284 - [NOTICE] callbacks.on_step_start(182): Cycle 11/1000, step 10/14: Rest for 1 hours
# 2023-01-27 14:50:47.354 - [NOTICE] callbacks.on_step_start(182): Cycle 11/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 14:50:47.373 - [NOTICE] callbacks.on_step_start(182): Cycle 11/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 14:50:47.605 - [NOTICE] callbacks.on_step_start(182): Cycle 11/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 14:50:48.373 - [NOTICE] callbacks.on_step_start(182): Cycle 11/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 14:50:50.180 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.839 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 14:50:50.180 - [NOTICE] callbacks.on_cycle_start(174): Cycle 12/1000 (1 minute, 13 seconds elapsed) --------------------
# 2023-01-27 14:50:50.180 - [NOTICE] callbacks.on_step_start(182): Cycle 12/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:50:51.639 - [NOTICE] callbacks.on_step_start(182): Cycle 12/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 14:50:51.662 - [NOTICE] callbacks.on_step_start(182): Cycle 12/1000, step 3/14: Rest for 1 hours
# 2023-01-27 14:50:51.736 - [NOTICE] callbacks.on_step_start(182): Cycle 12/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 14:50:51.752 - [NOTICE] callbacks.on_step_start(182): Cycle 12/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 14:50:51.873 - [NOTICE] callbacks.on_step_start(182): Cycle 12/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 14:50:52.274 - [NOTICE] callbacks.on_step_start(182): Cycle 12/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 14:50:52.309 - [NOTICE] callbacks.on_step_start(182): Cycle 12/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:50:53.721 - [NOTICE] callbacks.on_step_start(182): Cycle 12/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 14:50:53.746 - [NOTICE] callbacks.on_step_start(182): Cycle 12/1000, step 10/14: Rest for 1 hours
# 2023-01-27 14:50:53.823 - [NOTICE] callbacks.on_step_start(182): Cycle 12/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 14:50:53.837 - [NOTICE] callbacks.on_step_start(182): Cycle 12/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 14:50:54.067 - [NOTICE] callbacks.on_step_start(182): Cycle 12/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 14:50:54.835 - [NOTICE] callbacks.on_step_start(182): Cycle 12/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 14:50:56.634 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.837 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 14:50:56.634 - [NOTICE] callbacks.on_cycle_start(174): Cycle 13/1000 (1 minute, 20 seconds elapsed) --------------------
# 2023-01-27 14:50:56.634 - [NOTICE] callbacks.on_step_start(182): Cycle 13/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:50:58.241 - [NOTICE] callbacks.on_step_start(182): Cycle 13/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 14:50:58.259 - [NOTICE] callbacks.on_step_start(182): Cycle 13/1000, step 3/14: Rest for 1 hours
# 2023-01-27 14:50:58.342 - [NOTICE] callbacks.on_step_start(182): Cycle 13/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 14:50:58.352 - [NOTICE] callbacks.on_step_start(182): Cycle 13/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 14:50:58.465 - [NOTICE] callbacks.on_step_start(182): Cycle 13/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 14:50:58.876 - [NOTICE] callbacks.on_step_start(182): Cycle 13/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 14:50:58.914 - [NOTICE] callbacks.on_step_start(182): Cycle 13/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:51:00.360 - [NOTICE] callbacks.on_step_start(182): Cycle 13/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 14:51:00.386 - [NOTICE] callbacks.on_step_start(182): Cycle 13/1000, step 10/14: Rest for 1 hours
# 2023-01-27 14:51:00.469 - [NOTICE] callbacks.on_step_start(182): Cycle 13/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 14:51:00.480 - [NOTICE] callbacks.on_step_start(182): Cycle 13/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 14:51:00.707 - [NOTICE] callbacks.on_step_start(182): Cycle 13/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 14:51:01.467 - [NOTICE] callbacks.on_step_start(182): Cycle 13/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 14:51:03.300 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.835 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 14:51:03.300 - [NOTICE] callbacks.on_cycle_start(174): Cycle 14/1000 (1 minute, 26 seconds elapsed) --------------------
# 2023-01-27 14:51:03.300 - [NOTICE] callbacks.on_step_start(182): Cycle 14/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:51:04.737 - [NOTICE] callbacks.on_step_start(182): Cycle 14/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 14:51:04.756 - [NOTICE] callbacks.on_step_start(182): Cycle 14/1000, step 3/14: Rest for 1 hours
# 2023-01-27 14:51:04.828 - [NOTICE] callbacks.on_step_start(182): Cycle 14/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 14:51:04.844 - [NOTICE] callbacks.on_step_start(182): Cycle 14/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 14:51:04.969 - [NOTICE] callbacks.on_step_start(182): Cycle 14/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 14:51:05.386 - [NOTICE] callbacks.on_step_start(182): Cycle 14/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 14:51:05.422 - [NOTICE] callbacks.on_step_start(182): Cycle 14/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:51:06.843 - [NOTICE] callbacks.on_step_start(182): Cycle 14/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 14:51:06.864 - [NOTICE] callbacks.on_step_start(182): Cycle 14/1000, step 10/14: Rest for 1 hours
# 2023-01-27 14:51:06.936 - [NOTICE] callbacks.on_step_start(182): Cycle 14/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 14:51:06.956 - [NOTICE] callbacks.on_step_start(182): Cycle 14/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 14:51:07.189 - [NOTICE] callbacks.on_step_start(182): Cycle 14/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 14:51:07.947 - [NOTICE] callbacks.on_step_start(182): Cycle 14/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 14:51:09.777 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.832 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 14:51:09.777 - [NOTICE] callbacks.on_cycle_start(174): Cycle 15/1000 (1 minute, 33 seconds elapsed) --------------------
# 2023-01-27 14:51:09.777 - [NOTICE] callbacks.on_step_start(182): Cycle 15/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:51:11.212 - [NOTICE] callbacks.on_step_start(182): Cycle 15/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 14:51:11.235 - [NOTICE] callbacks.on_step_start(182): Cycle 15/1000, step 3/14: Rest for 1 hours
# 2023-01-27 14:51:11.304 - [NOTICE] callbacks.on_step_start(182): Cycle 15/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 14:51:11.325 - [NOTICE] callbacks.on_step_start(182): Cycle 15/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 14:51:11.448 - [NOTICE] callbacks.on_step_start(182): Cycle 15/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 14:51:11.852 - [NOTICE] callbacks.on_step_start(182): Cycle 15/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 14:51:11.887 - [NOTICE] callbacks.on_step_start(182): Cycle 15/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:51:13.296 - [NOTICE] callbacks.on_step_start(182): Cycle 15/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 14:51:13.321 - [NOTICE] callbacks.on_step_start(182): Cycle 15/1000, step 10/14: Rest for 1 hours
# 2023-01-27 14:51:13.399 - [NOTICE] callbacks.on_step_start(182): Cycle 15/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 14:51:13.411 - [NOTICE] callbacks.on_step_start(182): Cycle 15/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 14:51:13.633 - [NOTICE] callbacks.on_step_start(182): Cycle 15/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 14:51:14.410 - [NOTICE] callbacks.on_step_start(182): Cycle 15/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 14:51:16.287 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.830 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 14:51:16.287 - [NOTICE] callbacks.on_cycle_start(174): Cycle 16/1000 (1 minute, 39 seconds elapsed) --------------------
# 2023-01-27 14:51:16.287 - [NOTICE] callbacks.on_step_start(182): Cycle 16/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:51:17.708 - [NOTICE] callbacks.on_step_start(182): Cycle 16/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 14:51:17.733 - [NOTICE] callbacks.on_step_start(182): Cycle 16/1000, step 3/14: Rest for 1 hours
# 2023-01-27 14:51:17.810 - [NOTICE] callbacks.on_step_start(182): Cycle 16/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 14:51:17.822 - [NOTICE] callbacks.on_step_start(182): Cycle 16/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 14:51:17.941 - [NOTICE] callbacks.on_step_start(182): Cycle 16/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 14:51:18.351 - [NOTICE] callbacks.on_step_start(182): Cycle 16/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 14:51:18.387 - [NOTICE] callbacks.on_step_start(182): Cycle 16/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:51:19.818 - [NOTICE] callbacks.on_step_start(182): Cycle 16/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 14:51:19.842 - [NOTICE] callbacks.on_step_start(182): Cycle 16/1000, step 10/14: Rest for 1 hours
# 2023-01-27 14:51:19.919 - [NOTICE] callbacks.on_step_start(182): Cycle 16/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 14:51:19.933 - [NOTICE] callbacks.on_step_start(182): Cycle 16/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 14:51:20.163 - [NOTICE] callbacks.on_step_start(182): Cycle 16/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 14:51:20.930 - [NOTICE] callbacks.on_step_start(182): Cycle 16/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 14:51:22.760 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.828 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 14:51:22.760 - [NOTICE] callbacks.on_cycle_start(174): Cycle 17/1000 (1 minute, 46 seconds elapsed) --------------------
# 2023-01-27 14:51:22.760 - [NOTICE] callbacks.on_step_start(182): Cycle 17/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:51:24.187 - [NOTICE] callbacks.on_step_start(182): Cycle 17/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 14:51:24.212 - [NOTICE] callbacks.on_step_start(182): Cycle 17/1000, step 3/14: Rest for 1 hours
# 2023-01-27 14:51:24.287 - [NOTICE] callbacks.on_step_start(182): Cycle 17/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 14:51:24.300 - [NOTICE] callbacks.on_step_start(182): Cycle 17/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 14:51:24.430 - [NOTICE] callbacks.on_step_start(182): Cycle 17/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 14:51:24.834 - [NOTICE] callbacks.on_step_start(182): Cycle 17/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 14:51:24.878 - [NOTICE] callbacks.on_step_start(182): Cycle 17/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:51:26.328 - [NOTICE] callbacks.on_step_start(182): Cycle 17/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 14:51:26.347 - [NOTICE] callbacks.on_step_start(182): Cycle 17/1000, step 10/14: Rest for 1 hours
# 2023-01-27 14:51:26.431 - [NOTICE] callbacks.on_step_start(182): Cycle 17/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 14:51:26.443 - [NOTICE] callbacks.on_step_start(182): Cycle 17/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 14:51:26.912 - [NOTICE] callbacks.on_step_start(182): Cycle 17/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 14:51:27.835 - [NOTICE] callbacks.on_step_start(182): Cycle 17/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 14:51:29.839 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.825 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 14:51:29.840 - [NOTICE] callbacks.on_cycle_start(174): Cycle 18/1000 (1 minute, 53 seconds elapsed) --------------------
# 2023-01-27 14:51:29.841 - [NOTICE] callbacks.on_step_start(182): Cycle 18/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:51:31.337 - [NOTICE] callbacks.on_step_start(182): Cycle 18/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 14:51:31.357 - [NOTICE] callbacks.on_step_start(182): Cycle 18/1000, step 3/14: Rest for 1 hours
# 2023-01-27 14:51:31.431 - [NOTICE] callbacks.on_step_start(182): Cycle 18/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 14:51:31.447 - [NOTICE] callbacks.on_step_start(182): Cycle 18/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 14:51:31.572 - [NOTICE] callbacks.on_step_start(182): Cycle 18/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 14:51:31.970 - [NOTICE] callbacks.on_step_start(182): Cycle 18/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 14:51:32.009 - [NOTICE] callbacks.on_step_start(182): Cycle 18/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:51:33.449 - [NOTICE] callbacks.on_step_start(182): Cycle 18/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 14:51:33.468 - [NOTICE] callbacks.on_step_start(182): Cycle 18/1000, step 10/14: Rest for 1 hours
# 2023-01-27 14:51:33.542 - [NOTICE] callbacks.on_step_start(182): Cycle 18/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 14:51:33.559 - [NOTICE] callbacks.on_step_start(182): Cycle 18/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 14:51:33.779 - [NOTICE] callbacks.on_step_start(182): Cycle 18/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 14:51:34.540 - [NOTICE] callbacks.on_step_start(182): Cycle 18/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 14:51:36.406 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.823 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 14:51:36.406 - [NOTICE] callbacks.on_cycle_start(174): Cycle 19/1000 (1 minute, 59 seconds elapsed) --------------------
# 2023-01-27 14:51:36.406 - [NOTICE] callbacks.on_step_start(182): Cycle 19/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:51:37.846 - [NOTICE] callbacks.on_step_start(182): Cycle 19/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 14:51:37.873 - [NOTICE] callbacks.on_step_start(182): Cycle 19/1000, step 3/14: Rest for 1 hours
# 2023-01-27 14:51:37.947 - [NOTICE] callbacks.on_step_start(182): Cycle 19/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 14:51:37.964 - [NOTICE] callbacks.on_step_start(182): Cycle 19/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 14:51:38.084 - [NOTICE] callbacks.on_step_start(182): Cycle 19/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 14:51:38.541 - [NOTICE] callbacks.on_step_start(182): Cycle 19/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 14:51:38.584 - [NOTICE] callbacks.on_step_start(182): Cycle 19/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:51:40.007 - [NOTICE] callbacks.on_step_start(182): Cycle 19/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 14:51:40.033 - [NOTICE] callbacks.on_step_start(182): Cycle 19/1000, step 10/14: Rest for 1 hours
# 2023-01-27 14:51:40.107 - [NOTICE] callbacks.on_step_start(182): Cycle 19/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 14:51:40.122 - [NOTICE] callbacks.on_step_start(182): Cycle 19/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 14:51:40.354 - [NOTICE] callbacks.on_step_start(182): Cycle 19/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 14:51:41.112 - [NOTICE] callbacks.on_step_start(182): Cycle 19/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 14:51:42.957 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.820 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 14:51:42.957 - [NOTICE] callbacks.on_cycle_start(174): Cycle 20/1000 (2 minutes, 6 seconds elapsed) --------------------
# 2023-01-27 14:51:42.957 - [NOTICE] callbacks.on_step_start(182): Cycle 20/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:51:44.394 - [NOTICE] callbacks.on_step_start(182): Cycle 20/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 14:51:44.419 - [NOTICE] callbacks.on_step_start(182): Cycle 20/1000, step 3/14: Rest for 1 hours
# 2023-01-27 14:51:44.496 - [NOTICE] callbacks.on_step_start(182): Cycle 20/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 14:51:44.508 - [NOTICE] callbacks.on_step_start(182): Cycle 20/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 14:51:44.626 - [NOTICE] callbacks.on_step_start(182): Cycle 20/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 14:51:45.031 - [NOTICE] callbacks.on_step_start(182): Cycle 20/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 14:51:45.073 - [NOTICE] callbacks.on_step_start(182): Cycle 20/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:51:46.507 - [NOTICE] callbacks.on_step_start(182): Cycle 20/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 14:51:46.533 - [NOTICE] callbacks.on_step_start(182): Cycle 20/1000, step 10/14: Rest for 1 hours
# 2023-01-27 14:51:46.610 - [NOTICE] callbacks.on_step_start(182): Cycle 20/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 14:51:46.624 - [NOTICE] callbacks.on_step_start(182): Cycle 20/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 14:51:46.853 - [NOTICE] callbacks.on_step_start(182): Cycle 20/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 14:51:47.619 - [NOTICE] callbacks.on_step_start(182): Cycle 20/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 14:51:49.475 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.818 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 14:51:49.475 - [NOTICE] callbacks.on_cycle_start(174): Cycle 21/1000 (2 minutes, 13 seconds elapsed) --------------------
# 2023-01-27 14:51:49.475 - [NOTICE] callbacks.on_step_start(182): Cycle 21/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:51:50.946 - [NOTICE] callbacks.on_step_start(182): Cycle 21/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 14:51:50.966 - [NOTICE] callbacks.on_step_start(182): Cycle 21/1000, step 3/14: Rest for 1 hours
# 2023-01-27 14:51:51.045 - [NOTICE] callbacks.on_step_start(182): Cycle 21/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 14:51:51.057 - [NOTICE] callbacks.on_step_start(182): Cycle 21/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 14:51:51.176 - [NOTICE] callbacks.on_step_start(182): Cycle 21/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 14:51:51.582 - [NOTICE] callbacks.on_step_start(182): Cycle 21/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 14:51:51.620 - [NOTICE] callbacks.on_step_start(182): Cycle 21/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:51:53.088 - [NOTICE] callbacks.on_step_start(182): Cycle 21/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 14:51:53.115 - [NOTICE] callbacks.on_step_start(182): Cycle 21/1000, step 10/14: Rest for 1 hours
# 2023-01-27 14:51:53.246 - [NOTICE] callbacks.on_step_start(182): Cycle 21/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 14:51:53.270 - [NOTICE] callbacks.on_step_start(182): Cycle 21/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 14:51:53.726 - [NOTICE] callbacks.on_step_start(182): Cycle 21/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 14:51:54.782 - [NOTICE] callbacks.on_step_start(182): Cycle 21/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 14:51:56.610 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.816 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 14:51:56.610 - [NOTICE] callbacks.on_cycle_start(174): Cycle 22/1000 (2 minutes, 20 seconds elapsed) --------------------
# 2023-01-27 14:51:56.610 - [NOTICE] callbacks.on_step_start(182): Cycle 22/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:51:58.076 - [NOTICE] callbacks.on_step_start(182): Cycle 22/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 14:51:58.086 - [NOTICE] callbacks.on_step_start(182): Cycle 22/1000, step 3/14: Rest for 1 hours
# 2023-01-27 14:51:58.169 - [NOTICE] callbacks.on_step_start(182): Cycle 22/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 14:51:58.181 - [NOTICE] callbacks.on_step_start(182): Cycle 22/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 14:51:58.301 - [NOTICE] callbacks.on_step_start(182): Cycle 22/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 14:51:58.709 - [NOTICE] callbacks.on_step_start(182): Cycle 22/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 14:51:58.745 - [NOTICE] callbacks.on_step_start(182): Cycle 22/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:52:00.405 - [NOTICE] callbacks.on_step_start(182): Cycle 22/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 14:52:00.431 - [NOTICE] callbacks.on_step_start(182): Cycle 22/1000, step 10/14: Rest for 1 hours
# 2023-01-27 14:52:00.502 - [NOTICE] callbacks.on_step_start(182): Cycle 22/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 14:52:00.522 - [NOTICE] callbacks.on_step_start(182): Cycle 22/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 14:52:00.750 - [NOTICE] callbacks.on_step_start(182): Cycle 22/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 14:52:01.501 - [NOTICE] callbacks.on_step_start(182): Cycle 22/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 14:52:03.327 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.813 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 14:52:03.327 - [NOTICE] callbacks.on_cycle_start(174): Cycle 23/1000 (2 minutes, 26 seconds elapsed) --------------------
# 2023-01-27 14:52:03.327 - [NOTICE] callbacks.on_step_start(182): Cycle 23/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:52:04.748 - [NOTICE] callbacks.on_step_start(182): Cycle 23/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 14:52:04.766 - [NOTICE] callbacks.on_step_start(182): Cycle 23/1000, step 3/14: Rest for 1 hours
# 2023-01-27 14:52:04.846 - [NOTICE] callbacks.on_step_start(182): Cycle 23/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 14:52:04.858 - [NOTICE] callbacks.on_step_start(182): Cycle 23/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 14:52:04.977 - [NOTICE] callbacks.on_step_start(182): Cycle 23/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 14:52:05.386 - [NOTICE] callbacks.on_step_start(182): Cycle 23/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 14:52:05.421 - [NOTICE] callbacks.on_step_start(182): Cycle 23/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:52:06.839 - [NOTICE] callbacks.on_step_start(182): Cycle 23/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 14:52:06.866 - [NOTICE] callbacks.on_step_start(182): Cycle 23/1000, step 10/14: Rest for 1 hours
# 2023-01-27 14:52:06.944 - [NOTICE] callbacks.on_step_start(182): Cycle 23/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 14:52:06.957 - [NOTICE] callbacks.on_step_start(182): Cycle 23/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 14:52:07.185 - [NOTICE] callbacks.on_step_start(182): Cycle 23/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 14:52:07.952 - [NOTICE] callbacks.on_step_start(182): Cycle 23/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 14:52:09.736 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.811 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 14:52:09.736 - [NOTICE] callbacks.on_cycle_start(174): Cycle 24/1000 (2 minutes, 33 seconds elapsed) --------------------
# 2023-01-27 14:52:09.736 - [NOTICE] callbacks.on_step_start(182): Cycle 24/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:52:11.146 - [NOTICE] callbacks.on_step_start(182): Cycle 24/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 14:52:11.162 - [NOTICE] callbacks.on_step_start(182): Cycle 24/1000, step 3/14: Rest for 1 hours
# 2023-01-27 14:52:11.242 - [NOTICE] callbacks.on_step_start(182): Cycle 24/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 14:52:11.256 - [NOTICE] callbacks.on_step_start(182): Cycle 24/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 14:52:11.375 - [NOTICE] callbacks.on_step_start(182): Cycle 24/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 14:52:11.781 - [NOTICE] callbacks.on_step_start(182): Cycle 24/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 14:52:11.822 - [NOTICE] callbacks.on_step_start(182): Cycle 24/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:52:13.222 - [NOTICE] callbacks.on_step_start(182): Cycle 24/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 14:52:13.247 - [NOTICE] callbacks.on_step_start(182): Cycle 24/1000, step 10/14: Rest for 1 hours
# 2023-01-27 14:52:13.317 - [NOTICE] callbacks.on_step_start(182): Cycle 24/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 14:52:13.337 - [NOTICE] callbacks.on_step_start(182): Cycle 24/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 14:52:13.562 - [NOTICE] callbacks.on_step_start(182): Cycle 24/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 14:52:14.322 - [NOTICE] callbacks.on_step_start(182): Cycle 24/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 14:52:16.117 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.808 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 14:52:16.117 - [NOTICE] callbacks.on_cycle_start(174): Cycle 25/1000 (2 minutes, 39 seconds elapsed) --------------------
# 2023-01-27 14:52:16.117 - [NOTICE] callbacks.on_step_start(182): Cycle 25/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:52:17.525 - [NOTICE] callbacks.on_step_start(182): Cycle 25/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 14:52:17.550 - [NOTICE] callbacks.on_step_start(182): Cycle 25/1000, step 3/14: Rest for 1 hours
# 2023-01-27 14:52:17.625 - [NOTICE] callbacks.on_step_start(182): Cycle 25/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 14:52:17.639 - [NOTICE] callbacks.on_step_start(182): Cycle 25/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 14:52:17.757 - [NOTICE] callbacks.on_step_start(182): Cycle 25/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 14:52:18.164 - [NOTICE] callbacks.on_step_start(182): Cycle 25/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 14:52:18.197 - [NOTICE] callbacks.on_step_start(182): Cycle 25/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:52:19.603 - [NOTICE] callbacks.on_step_start(182): Cycle 25/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 14:52:19.625 - [NOTICE] callbacks.on_step_start(182): Cycle 25/1000, step 10/14: Rest for 1 hours
# 2023-01-27 14:52:19.705 - [NOTICE] callbacks.on_step_start(182): Cycle 25/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 14:52:19.717 - [NOTICE] callbacks.on_step_start(182): Cycle 25/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 14:52:19.942 - [NOTICE] callbacks.on_step_start(182): Cycle 25/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 14:52:20.688 - [NOTICE] callbacks.on_step_start(182): Cycle 25/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 14:52:22.486 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.806 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 14:52:22.486 - [NOTICE] callbacks.on_cycle_start(174): Cycle 26/1000 (2 minutes, 46 seconds elapsed) --------------------
# 2023-01-27 14:52:22.486 - [NOTICE] callbacks.on_step_start(182): Cycle 26/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:52:23.924 - [NOTICE] callbacks.on_step_start(182): Cycle 26/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 14:52:23.943 - [NOTICE] callbacks.on_step_start(182): Cycle 26/1000, step 3/14: Rest for 1 hours
# 2023-01-27 14:52:24.014 - [NOTICE] callbacks.on_step_start(182): Cycle 26/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 14:52:24.033 - [NOTICE] callbacks.on_step_start(182): Cycle 26/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 14:52:24.155 - [NOTICE] callbacks.on_step_start(182): Cycle 26/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 14:52:24.553 - [NOTICE] callbacks.on_step_start(182): Cycle 26/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 14:52:24.595 - [NOTICE] callbacks.on_step_start(182): Cycle 26/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 14:52:26.126 - [NOTICE] callbacks.on_step_start(182): Cycle 26/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 14:52:26.146 - [NOTICE] callbacks.on_step_start(182): Cycle 26/1000, step 10/14: Rest for 1 hours
# 2023-01-27 14:52:26.232 - [NOTICE] callbacks.on_step_start(182): Cycle 26/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 14:52:26.242 - [NOTICE] callbacks.on_step_start(182): Cycle 26/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 14:52:26.473 - [NOTICE] callbacks.on_step_start(182): Cycle 26/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 14:52:27.231 - [NOTICE] callbacks.on_step_start(182): Cycle 26/1000, step 14/14: Rest for 20 minutes
# ...
# 2023-01-27 16:28:25.070 - [NOTICE] callbacks.on_step_start(182): Cycle 897/1000, step 10/14: Rest for 1 hours
# 2023-01-27 16:28:25.148 - [NOTICE] callbacks.on_step_start(182): Cycle 897/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 16:28:25.161 - [NOTICE] callbacks.on_step_start(182): Cycle 897/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 16:28:25.386 - [NOTICE] callbacks.on_step_start(182): Cycle 897/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 16:28:26.154 - [NOTICE] callbacks.on_step_start(182): Cycle 897/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 16:28:27.958 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.453 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 16:28:27.958 - [NOTICE] callbacks.on_cycle_start(174): Cycle 898/1000 (1 hour, 38 minutes, 51 seconds elapsed) --------------------
# 2023-01-27 16:28:27.958 - [NOTICE] callbacks.on_step_start(182): Cycle 898/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 16:28:29.465 - [NOTICE] callbacks.on_step_start(182): Cycle 898/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 16:28:29.490 - [NOTICE] callbacks.on_step_start(182): Cycle 898/1000, step 3/14: Rest for 1 hours
# 2023-01-27 16:28:29.563 - [NOTICE] callbacks.on_step_start(182): Cycle 898/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 16:28:29.582 - [NOTICE] callbacks.on_step_start(182): Cycle 898/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 16:28:29.702 - [NOTICE] callbacks.on_step_start(182): Cycle 898/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 16:28:30.100 - [NOTICE] callbacks.on_step_start(182): Cycle 898/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 16:28:30.144 - [NOTICE] callbacks.on_step_start(182): Cycle 898/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 16:28:31.659 - [NOTICE] callbacks.on_step_start(182): Cycle 898/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 16:28:31.684 - [NOTICE] callbacks.on_step_start(182): Cycle 898/1000, step 10/14: Rest for 1 hours
# 2023-01-27 16:28:31.764 - [NOTICE] callbacks.on_step_start(182): Cycle 898/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 16:28:31.775 - [NOTICE] callbacks.on_step_start(182): Cycle 898/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 16:28:31.997 - [NOTICE] callbacks.on_step_start(182): Cycle 898/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 16:28:32.759 - [NOTICE] callbacks.on_step_start(182): Cycle 898/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 16:28:34.549 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.450 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 16:28:34.559 - [NOTICE] callbacks.on_cycle_start(174): Cycle 899/1000 (1 hour, 38 minutes, 58 seconds elapsed) --------------------
# 2023-01-27 16:28:34.559 - [NOTICE] callbacks.on_step_start(182): Cycle 899/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 16:28:37.492 - [NOTICE] callbacks.on_step_start(182): Cycle 899/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 16:28:37.513 - [NOTICE] callbacks.on_step_start(182): Cycle 899/1000, step 3/14: Rest for 1 hours
# 2023-01-27 16:28:37.585 - [NOTICE] callbacks.on_step_start(182): Cycle 899/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 16:28:37.603 - [NOTICE] callbacks.on_step_start(182): Cycle 899/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 16:28:37.716 - [NOTICE] callbacks.on_step_start(182): Cycle 899/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 16:28:38.120 - [NOTICE] callbacks.on_step_start(182): Cycle 899/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 16:28:38.157 - [NOTICE] callbacks.on_step_start(182): Cycle 899/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 16:28:39.657 - [NOTICE] callbacks.on_step_start(182): Cycle 899/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 16:28:39.679 - [NOTICE] callbacks.on_step_start(182): Cycle 899/1000, step 10/14: Rest for 1 hours
# 2023-01-27 16:28:39.756 - [NOTICE] callbacks.on_step_start(182): Cycle 899/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 16:28:39.771 - [NOTICE] callbacks.on_step_start(182): Cycle 899/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 16:28:39.997 - [NOTICE] callbacks.on_step_start(182): Cycle 899/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 16:28:40.754 - [NOTICE] callbacks.on_step_start(182): Cycle 899/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 16:28:42.587 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.447 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 16:28:42.597 - [NOTICE] callbacks.on_cycle_start(174): Cycle 900/1000 (1 hour, 39 minutes, 6 seconds elapsed) --------------------
# 2023-01-27 16:28:42.597 - [NOTICE] callbacks.on_step_start(182): Cycle 900/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 16:28:44.110 - [NOTICE] callbacks.on_step_start(182): Cycle 900/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 16:28:44.136 - [NOTICE] callbacks.on_step_start(182): Cycle 900/1000, step 3/14: Rest for 1 hours
# 2023-01-27 16:28:44.212 - [NOTICE] callbacks.on_step_start(182): Cycle 900/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 16:28:44.229 - [NOTICE] callbacks.on_step_start(182): Cycle 900/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 16:28:44.349 - [NOTICE] callbacks.on_step_start(182): Cycle 900/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 16:28:44.756 - [NOTICE] callbacks.on_step_start(182): Cycle 900/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 16:28:44.790 - [NOTICE] callbacks.on_step_start(182): Cycle 900/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 16:28:46.280 - [NOTICE] callbacks.on_step_start(182): Cycle 900/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 16:28:46.298 - [NOTICE] callbacks.on_step_start(182): Cycle 900/1000, step 10/14: Rest for 1 hours
# 2023-01-27 16:28:46.372 - [NOTICE] callbacks.on_step_start(182): Cycle 900/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 16:28:46.389 - [NOTICE] callbacks.on_step_start(182): Cycle 900/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 16:28:46.609 - [NOTICE] callbacks.on_step_start(182): Cycle 900/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 16:28:47.373 - [NOTICE] callbacks.on_step_start(182): Cycle 900/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 16:28:49.274 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.444 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 16:28:49.274 - [NOTICE] callbacks.on_cycle_start(174): Cycle 901/1000 (1 hour, 39 minutes, 12 seconds elapsed) --------------------
# 2023-01-27 16:28:49.274 - [NOTICE] callbacks.on_step_start(182): Cycle 901/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 16:28:50.775 - [NOTICE] callbacks.on_step_start(182): Cycle 901/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 16:28:50.796 - [NOTICE] callbacks.on_step_start(182): Cycle 901/1000, step 3/14: Rest for 1 hours
# 2023-01-27 16:28:50.879 - [NOTICE] callbacks.on_step_start(182): Cycle 901/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 16:28:50.890 - [NOTICE] callbacks.on_step_start(182): Cycle 901/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 16:28:51.014 - [NOTICE] callbacks.on_step_start(182): Cycle 901/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 16:28:51.426 - [NOTICE] callbacks.on_step_start(182): Cycle 901/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 16:28:51.460 - [NOTICE] callbacks.on_step_start(182): Cycle 901/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 16:28:52.977 - [NOTICE] callbacks.on_step_start(182): Cycle 901/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 16:28:53.001 - [NOTICE] callbacks.on_step_start(182): Cycle 901/1000, step 10/14: Rest for 1 hours
# 2023-01-27 16:28:53.076 - [NOTICE] callbacks.on_step_start(182): Cycle 901/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 16:28:53.092 - [NOTICE] callbacks.on_step_start(182): Cycle 901/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 16:28:53.320 - [NOTICE] callbacks.on_step_start(182): Cycle 901/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 16:28:54.084 - [NOTICE] callbacks.on_step_start(182): Cycle 901/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 16:28:55.913 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.441 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 16:28:55.913 - [NOTICE] callbacks.on_cycle_start(174): Cycle 902/1000 (1 hour, 39 minutes, 19 seconds elapsed) --------------------
# 2023-01-27 16:28:55.913 - [NOTICE] callbacks.on_step_start(182): Cycle 902/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 16:28:57.441 - [NOTICE] callbacks.on_step_start(182): Cycle 902/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 16:28:57.459 - [NOTICE] callbacks.on_step_start(182): Cycle 902/1000, step 3/14: Rest for 1 hours
# 2023-01-27 16:28:57.534 - [NOTICE] callbacks.on_step_start(182): Cycle 902/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 16:28:57.549 - [NOTICE] callbacks.on_step_start(182): Cycle 902/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 16:28:57.665 - [NOTICE] callbacks.on_step_start(182): Cycle 902/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 16:28:58.074 - [NOTICE] callbacks.on_step_start(182): Cycle 902/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 16:28:58.111 - [NOTICE] callbacks.on_step_start(182): Cycle 902/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 16:28:59.598 - [NOTICE] callbacks.on_step_start(182): Cycle 902/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 16:28:59.620 - [NOTICE] callbacks.on_step_start(182): Cycle 902/1000, step 10/14: Rest for 1 hours
# 2023-01-27 16:28:59.692 - [NOTICE] callbacks.on_step_start(182): Cycle 902/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 16:28:59.714 - [NOTICE] callbacks.on_step_start(182): Cycle 902/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 16:28:59.939 - [NOTICE] callbacks.on_step_start(182): Cycle 902/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 16:29:00.694 - [NOTICE] callbacks.on_step_start(182): Cycle 902/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 16:29:02.524 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.438 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 16:29:02.524 - [NOTICE] callbacks.on_cycle_start(174): Cycle 903/1000 (1 hour, 39 minutes, 26 seconds elapsed) --------------------
# 2023-01-27 16:29:02.534 - [NOTICE] callbacks.on_step_start(182): Cycle 903/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 16:29:04.064 - [NOTICE] callbacks.on_step_start(182): Cycle 903/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 16:29:04.085 - [NOTICE] callbacks.on_step_start(182): Cycle 903/1000, step 3/14: Rest for 1 hours
# 2023-01-27 16:29:04.161 - [NOTICE] callbacks.on_step_start(182): Cycle 903/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 16:29:04.175 - [NOTICE] callbacks.on_step_start(182): Cycle 903/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 16:29:04.296 - [NOTICE] callbacks.on_step_start(182): Cycle 903/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 16:29:04.694 - [NOTICE] callbacks.on_step_start(182): Cycle 903/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 16:29:04.732 - [NOTICE] callbacks.on_step_start(182): Cycle 903/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 16:29:06.320 - [NOTICE] callbacks.on_step_start(182): Cycle 903/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 16:29:06.337 - [NOTICE] callbacks.on_step_start(182): Cycle 903/1000, step 10/14: Rest for 1 hours
# 2023-01-27 16:29:06.427 - [NOTICE] callbacks.on_step_start(182): Cycle 903/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 16:29:06.438 - [NOTICE] callbacks.on_step_start(182): Cycle 903/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 16:29:06.690 - [NOTICE] callbacks.on_step_start(182): Cycle 903/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 16:29:07.533 - [NOTICE] callbacks.on_step_start(182): Cycle 903/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 16:29:09.429 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.435 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 16:29:09.430 - [NOTICE] callbacks.on_cycle_start(174): Cycle 904/1000 (1 hour, 39 minutes, 32 seconds elapsed) --------------------
# 2023-01-27 16:29:09.431 - [NOTICE] callbacks.on_step_start(182): Cycle 904/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 16:29:11.083 - [NOTICE] callbacks.on_step_start(182): Cycle 904/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 16:29:11.099 - [NOTICE] callbacks.on_step_start(182): Cycle 904/1000, step 3/14: Rest for 1 hours
# 2023-01-27 16:29:11.184 - [NOTICE] callbacks.on_step_start(182): Cycle 904/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 16:29:11.195 - [NOTICE] callbacks.on_step_start(182): Cycle 904/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 16:29:11.330 - [NOTICE] callbacks.on_step_start(182): Cycle 904/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 16:29:11.769 - [NOTICE] callbacks.on_step_start(182): Cycle 904/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 16:29:11.806 - [NOTICE] callbacks.on_step_start(182): Cycle 904/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 16:29:13.344 - [NOTICE] callbacks.on_step_start(182): Cycle 904/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 16:29:13.364 - [NOTICE] callbacks.on_step_start(182): Cycle 904/1000, step 10/14: Rest for 1 hours
# 2023-01-27 16:29:13.440 - [NOTICE] callbacks.on_step_start(182): Cycle 904/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 16:29:13.455 - [NOTICE] callbacks.on_step_start(182): Cycle 904/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 16:29:13.700 - [NOTICE] callbacks.on_step_start(182): Cycle 904/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 16:29:14.494 - [NOTICE] callbacks.on_step_start(182): Cycle 904/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 16:29:16.328 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 2.432 Ah (originally 4.862 Ah, will stop at 2.431 Ah)
# 2023-01-27 16:29:16.328 - [NOTICE] callbacks.on_cycle_start(174): Cycle 905/1000 (1 hour, 39 minutes, 39 seconds elapsed) --------------------
# 2023-01-27 16:29:16.328 - [NOTICE] callbacks.on_step_start(182): Cycle 905/1000, step 1/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 16:29:17.878 - [NOTICE] callbacks.on_step_start(182): Cycle 905/1000, step 2/14: Rest for 5 minutes
# 2023-01-27 16:29:17.895 - [NOTICE] callbacks.on_step_start(182): Cycle 905/1000, step 3/14: Rest for 1 hours
# 2023-01-27 16:29:17.975 - [NOTICE] callbacks.on_step_start(182): Cycle 905/1000, step 4/14: Rest for 5 minutes
# 2023-01-27 16:29:17.986 - [NOTICE] callbacks.on_step_start(182): Cycle 905/1000, step 5/14: Charge at C/4 until 4.2V
# 2023-01-27 16:29:18.104 - [NOTICE] callbacks.on_step_start(182): Cycle 905/1000, step 6/14: Hold at 4.2V for 1.6 hours
# 2023-01-27 16:29:18.509 - [NOTICE] callbacks.on_step_start(182): Cycle 905/1000, step 7/14: Rest for 20 minutes
# 2023-01-27 16:29:18.553 - [NOTICE] callbacks.on_step_start(182): Cycle 905/1000, step 8/14: Run US06_OEM1 (A) for 1 hours
# 2023-01-27 16:29:20.074 - [NOTICE] callbacks.on_step_start(182): Cycle 905/1000, step 9/14: Rest for 5 minutes
# 2023-01-27 16:29:20.094 - [NOTICE] callbacks.on_step_start(182): Cycle 905/1000, step 10/14: Rest for 1 hours
# 2023-01-27 16:29:20.172 - [NOTICE] callbacks.on_step_start(182): Cycle 905/1000, step 11/14: Rest for 5 minutes
# 2023-01-27 16:29:20.189 - [NOTICE] callbacks.on_step_start(182): Cycle 905/1000, step 12/14: Charge at C/8 until 4.2V
# 2023-01-27 16:29:20.421 - [NOTICE] callbacks.on_step_start(182): Cycle 905/1000, step 13/14: Hold at 4.2V for 3.1 hours
# 2023-01-27 16:29:21.172 - [NOTICE] callbacks.on_step_start(182): Cycle 905/1000, step 14/14: Rest for 20 minutes
# 2023-01-27 16:29:23.023 - [NOTICE] callbacks.on_cycle_end(201): Stopping experiment since capacity (2.429 Ah) is below stopping capacity (2.431 Ah).
# 2023-01-27 16:29:23.056 - [NOTICE] callbacks.on_experiment_end(222): Finish experiment simulation, took 1 hour, 39 minutes, 46 seconds

# %%
qwrqwf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 qwrqwf
#
# NameError: name 'qwrqwf' is not defined

# %%
# saved_state530=sol_long.last_state

# %%
# sol_long.save_data(filename="exp3_svaed530", to_format='pickle')

# %%
# spm.set_initial_conditions_from(saved_state530)

# %%
# parameter_values.update({
#         "Lower voltage cut-off [V]":2.8,
# })
# sim_long2 = pybamm.Simulation(spm, experiment=experiment3, parameter_values=parameter_values, 
#                             solver=pybamm.CasadiSolver("safe",
#                             rtol=1e-10, 
#                             atol=1e-10,
#                             dt_max=.01,
#                                                       ))
# sol_long2 = sim_long2.solve( save_at_cycles=1)

# %%
pybamm.plot_summary_variables(sol_long)

# %%
spm.variables.search("lithium")

# %%
sim_long.plot(
    [
#         "Negative particle surface concentration [mol.m-3]",
#         "Electrolyte concentration [mol.m-3]",
#         "Positive particle surface concentration [mol.m-3]",
        "Current [A]",
#         "Negative electrode potential [V]",
#         "Electrolyte potential [V]",
#         "Positive electrode potential [V]",
        "Terminal voltage [V]",
#         "X-averaged cell temperature",
        "Negative electrode SOC",
        "Positive electrode SOC",
#         "SEI thickness [m]",
        "Loss of capacity to SEI [A.h]",
        "Negative electrode capacity [A.h]",
        "Positive electrode capacity [A.h]",
        "Discharge capacity [A.h]",
        "X-averaged negative electrode active material volume fraction",
        "X-averaged negative particle surface concentration [mol.m-3]",
        "Loss of lithium to SEI on cracks [mol]",
        "Loss of lithium to lithium plating [mol]",
        "Loss of lithium to SEI [mol]",
        "Total lithium lost [mol]",
        "Total lithium in particles [mol]",
        "Total lithium lost to side reactions [mol]",
        "Loss of lithium inventory [%]"


    ]
)

# %%
sol_long["Total lithium in particles [mol]"].entries
# sol_long["Terminal voltage [V]"].entries
# sol_long.summary_variables["Total lithium lost to side reactions [mol]"]

# sol_long["Loss of lithium inventory [%]"].entries

# %%
sol_long.save("experiment4_jan27")

# %%
type(sol_long.summary_variables[list(sol_long.summary_variables.keys())[1]])

# %%
# mdic={}
# for i in range (1):
# # range(len(sol_long.summary_variables)):
# #     stringing=''.join([list(sol_long.summary_variables.keys())[i]])
#     mdic={f"{i}": sol_long.summary_variables[list(sol_long.summary_variables.keys())[i]]}
# savemat("summary",mdic)

# %%
x100=sol_long.summary_variables["x_100"]
y100=sol_long.summary_variables["y_100"]
x0=sol_long.summary_variables["x_0"]
y0=sol_long.summary_variables["y_0"]
Cap=sol_long.summary_variables["Capacity [A.h]"]
LoC_SEI_summ=sol_long.summary_variables["Loss of capacity to SEI [A.h]"]
LAM_P=sol_long.summary_variables["Loss of active material in positive electrode [%]"]
LAM_N=sol_long.summary_variables["Loss of active material in negative electrode [%]"]
C_Neg=sol_long.summary_variables["C_n"]
C_pos=sol_long.summary_variables["C_p"]
LLI=sol_long.summary_variables["Loss of lithium inventory [%]"]
cycle_num=sol_long.summary_variables["Cycle number"]
t = sol_long["Time [s]"].entries
I = sol_long["Current [A]"].entries
Q = sol_long['Discharge capacity [A.h]'].entries
LoC_SEI = sol_long["Loss of capacity to SEI [A.h]"].entries
N_SoC = sol_long["Negative electrode SOC"].entries
P_SoC = sol_long["Positive electrode SOC"].entries
Epsilon_n_s_cycled=sol_long["X-averaged negative electrode active material volume fraction"].entries
Epsilon_p_s_cycled=sol_long["X-averaged positive electrode active material volume fraction"].entries

# ECM_res=sol_long.summary_variables["Local ECM resistance [Ohm]"]

# ECM_whole_res=sol_long["Local ECM resistance [Ohm]"].entries
# ECM_sum_res=sol_long.summary_variables["Local ECM resistance [Ohm]"]
# ECM_sum_res_change=sol_long.summary_variables['Change in local ECM resistance [Ohm]']

cycle_time=sol_long.summary_variables['Time [s]'],
Vt_t = sol_long["Terminal voltage [V]"].entries,

LLI_SEI_mol=sol_long["Loss of lithium to SEI [mol]"].entries,
LLI_plating_mol=sol_long["Loss of lithium to lithium plating [mol]"].entries,



# exp = 30e6*sol_0["Cell thickness change [m]"].entries
# exp_n = 30e6*sol_0["Negative Electrode thickness change [m]"].entries
# exp_p = 30e6*sol_0["Positive Electrode thickness change [m]"].entries
# ee_p = sol_0["X-averaged positive electrode porosity"].entries
# ee_n = sol_0["X-averaged negative electrode porosity"].entries
# ee_s = sol_0["X-averaged separator porosity"].entries
# j_n = sol_0["X-averaged negative electrode total interfacial current density [A.m-2]"].entries
# j_p = sol_0["X-averaged positive electrode total interfacial current density [A.m-2]"].entries

# x = sol_0["x [m]"].entries
# c_e_0 = sol_0["Electrolyte concentration [mol.m-3]"].entries

# %%
ident=""
mdic = {
    "x100"+ident: x100, "y100"+ident:y100, "x0"+ident:x0,"y0"+ident:y0,"Cap"+ident:Cap,
        "LoC_SEI_summ"+ident:LoC_SEI_summ,
        "LAM_P"+ident:LAM_P,"LAM_N"+ident:LAM_N,"C_Neg"+ident:C_Neg,"C_pos"+ident:C_pos,
        "LLI"+ident:LLI,"cycle_num"+ident:cycle_num,
        "t"+ident:t,"LoC_SEI"+ident:LoC_SEI,"N_SoC"+ident:N_SoC,"P_SoC"+ident:P_SoC,
        "Q"+ident:Q, "I"+ident:I,    
#         "ECM_whole_res":ECM_whole_res,"ECM_sum_res":ECM_sum_res,
#         "ECM_sum_res_change":ECM_sum_res_change,"cycle_time":cycle_time 
        "Epsilon_n_s_cycled"+ident:Epsilon_n_s_cycled,
        "Epsilon_p_s_cycled"+ident:Epsilon_p_s_cycled,
        "cycle_time":cycle_time, "Vt_t":Vt_t,
        "LLI_SEI_mol":LLI_SEI_mol,
        "LLI_plating_mol":LLI_plating_mol,
    
       }
savemat("experiment4_jan27.mat",mdic)

# %%
# print(x100)

# %%
# import csv
# with open(r"F:\Git Hub rep\CRC\neew\PyBaMM\Untitled Folder\whatever.csv", 'w') as f:
#     # create the csv writer
#     writer = csv.writer(f)

# write a row to the csv file
# i=1
# for lines in sol_long.all_summary_variables:
# #     writer.writerow(words)
#     i=i+1
#     savemat(f'{i:02d}', lines)

# %%
type(x100)

# %%
sol_long.variables.search("loss")

# %%
# plt.plot(sol_long["Time [s]"].entries[1:15133], sol_long["Current [A]"].entries[1:15133])

# %%
# plt.plot(sol_long["Time [s]"].entries[1:15133], sol_long["Terminal voltage [V]"].entries[1:15133])

# %%
 plt.plot(sol_long["Time [s]"].entries, 1-sol_long["Discharge capacity [A.h]"].entries/5)

# %%
sol_long.summary_variables

# %%
spm.param.n.prim
