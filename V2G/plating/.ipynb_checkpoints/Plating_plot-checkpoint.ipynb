# %%
import pybamm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
import dfols
import signal
from scipy.integrate import solve_ivp
from scipy.fft import fft, fftfreq, fftshift
from scipy.signal import savgol_filter
from scipy.signal import find_peaks
from scipy import interpolate, integrate
from stopit import threading_timeoutable as timeoutable
import os, sys
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath("__file__"))))
from batfuns import *
plt.rcParams = set_rc_params(plt.rcParams)
import winsound

eSOH_DIR = "../V2G/data/esoh/"
oCV_DIR = "../V2G/data/ocv/"
cyc_DIR = "../V2G/data/cycling/"
fig_DIR = "../V2G/figures/figures_fit/"
res_DIR = "../V2G/data/results_fit/"
# %matplotlib widget

# %%
parameter_values = get_parameter_values()

# %%
parameter_values.search("rad")
# Out:
# Negative particle radius [m]	1e-05
# Positive particle radius [m]	3.5e-06

# %%
spm = pybamm.lithium_ion.SPM(
    {
        "SEI": "ec reaction limited",
        "loss of active material": "stress-driven",
        "lithium plating": "irreversible",
    }
)
# spm.print_parameter_info()
param=spm.param

# %%
cell = 1
sno = 1
sim_des = f'cond{sno}'

# %%
cell_no,dfe,dfe_0,dfo_0,N,N_0 = load_data(cell,eSOH_DIR,oCV_DIR)
eps_n_data,eps_p_data,c_rate_c,c_rate_d,dis_set,Temp,SOC_0 = init_exp(cell_no,dfe,spm,parameter_values)
print(Temp)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 cell_no,dfe,dfe_0,dfo_0,N,N_0 = load_data(cell,eSOH_DIR,oCV_DIR)
#       2 eps_n_data,eps_p_data,c_rate_c,c_rate_d,dis_set,Temp,SOC_0 = init_exp(cell_no,dfe,spm,parameter_values)
#       3 print(Temp)
#
# File F:\Git Hub rep\PyBaMM\V2G\batfuns.py:480, in load_data(cell, eSOH_DIR, oCV_DIR)
#     478 param = pybamm.LithiumIonParameters()
#     479 cell_no = f'{cell:02d}'
# --> 480 dfe=pd.read_csv(eSOH_DIR+"aging_param_cell_"+cell_no+".csv")
#     481 dfe_0=pd.read_csv(eSOH_DIR+"aging_param_cell_"+cell_no+".csv")
#     482 dfo_0=pd.read_csv(oCV_DIR+"ocv_data_cell_"+cell_no+".csv")
#
# File F:\Git Hub rep\PyBaMM\.tox\windows-dev\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File F:\Git Hub rep\PyBaMM\.tox\windows-dev\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File F:\Git Hub rep\PyBaMM\.tox\windows-dev\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File F:\Git Hub rep\PyBaMM\.tox\windows-dev\lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File F:\Git Hub rep\PyBaMM\.tox\windows-dev\lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File F:\Git Hub rep\PyBaMM\.tox\windows-dev\lib\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File F:\Git Hub rep\PyBaMM\.tox\windows-dev\lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../V2G/data/esoh/aging_param_cell_01.csv'

# %%
pybamm.set_logging_level("NOTICE")
# pybamm.set_logging_level("NOTICE")
experiment = pybamm.Experiment(
    [
        ("Discharge at "+c_rate_d+dis_set,
         "Rest for 5 min",
         "Charge at "+c_rate_c+" until 4.2V", 
         "Hold at 4.2V until C/50")
    ] *dfe.N.iloc[-1],
    # ] *40,
    termination="50% capacity",
#     cccv_handling="ode",
)

# %%
par_val = {}
# Previous i.e. tuning mech sim sep and then Li plating
par_val[0]=[1.2715e-07,1.2727e-06,1.1992,1.353e-9]
# Using only C/5 and 1.5C Cycling aging, cost function with Cn,Cp,x100,y0
par_val[1]=[1.4819e-07,1.5114e-06,1.2484,1.4732e-09]
# Using only C/5 and 1.5C Cycling aging, cost function with Cn,Cp,C,LLI(%)
par_val[2]=[1.4493e-07,1.3608e-06,1.199,1.2138e-09]
# Using C/5, 1.5C and mixed c-rate (Ch:C/5, Dh:1.5C) Cycling aging, cost function with Cn,Cp,x100,y0
par_val[3]=[1.043e-07,1.036e-06,1.208,1.6045e-09]
# Using C/5, 1.5C and mixed c-rate (Ch:C/5, Dh:1.5C) Cycling aging, cost function with Cn,Cp,C,LLI(%)
par_val[4]=[8.755e-08,8.572e-07,1.135,1.5788e-09]
# Using C/5, 1.5C and mixed c-rate (Ch:C/5, Dh:1.5C) Cycling aging, cost function with Cn,Cp,C,LLI(%) another initial condition
par_val[5]=[8.7698e-08,8.5848e-07,1.1354,1.5778e-09]

# %%
parameter_values = get_parameter_values()
parameter_values.update(
    {
        "Negative electrode active material volume fraction": eps_n_data,
        "Positive electrode active material volume fraction": eps_p_data,
        "Initial temperature [K]": 273.15+Temp,
        "Ambient temperature [K]": 273.15+Temp,
        "Positive electrode LAM constant proportional term [s-1]": par_val[sno][0],
        "Negative electrode LAM constant proportional term [s-1]": par_val[sno][1],
        "Positive electrode LAM constant exponential term": par_val[sno][2],
        "Negative electrode LAM constant exponential term": par_val[sno][2],
        "SEI kinetic rate constant [m.s-1]":  4.60788219e-16, #1.08494281e-16 , 
        "EC diffusivity [m2.s-1]": 4.56607447e-19,#8.30909086e-19,
        "SEI growth activation energy [J.mol-1]": 1.87422275e+04,#1.58777981e+04,
        "Lithium plating kinetic rate constant [m.s-1]": par_val[sno][3],
        # "SEI kinetic rate constant [m.s-1]": 1.6827e-16,
        # "EC diffusivity [m2.s-1]": 2e-18,
        # "SEI growth activation energy [J.mol-1]": 0,
    },
    check_already_exists=False,
)

# %%
# all_sumvars_dict = cycle_adaptive_simulation(spm, parameter_values, experiment,SOC_0, save_at_cycles=1)
sim_long = pybamm.Simulation(spm, experiment=experiment, parameter_values=parameter_values, 
                            solver=pybamm.CasadiSolver("safe"))
sol_long = sim_long.solve(initial_soc=SOC_0, save_at_cycles=1  )
# Out:
# 2023-01-05 11:34:33.850 - [NOTICE] callbacks.on_cycle_start(174): Cycle 1/287 (19.110 ms elapsed) --------------------
# 2023-01-05 11:34:33.860 - [NOTICE] callbacks.on_step_start(182): Cycle 1/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:34.015 - [NOTICE] callbacks.on_step_start(182): Cycle 1/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:34.104 - [NOTICE] callbacks.on_step_start(182): Cycle 1/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:34.248 - [NOTICE] callbacks.on_step_start(182): Cycle 1/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:34.702 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.847 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:34.703 - [NOTICE] callbacks.on_cycle_start(174): Cycle 2/287 (862.933 ms elapsed) --------------------
# 2023-01-05 11:34:34.704 - [NOTICE] callbacks.on_step_start(182): Cycle 2/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:34.889 - [NOTICE] callbacks.on_step_start(182): Cycle 2/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:34.902 - [NOTICE] callbacks.on_step_start(182): Cycle 2/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:34.953 - [NOTICE] callbacks.on_step_start(182): Cycle 2/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:35.063 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.841 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:35.065 - [NOTICE] callbacks.on_cycle_start(174): Cycle 3/287 (1.224 s elapsed) --------------------
# 2023-01-05 11:34:35.066 - [NOTICE] callbacks.on_step_start(182): Cycle 3/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:35.133 - [NOTICE] callbacks.on_step_start(182): Cycle 3/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:35.148 - [NOTICE] callbacks.on_step_start(182): Cycle 3/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:35.199 - [NOTICE] callbacks.on_step_start(182): Cycle 3/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:35.301 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.836 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:35.301 - [NOTICE] callbacks.on_cycle_start(174): Cycle 4/287 (1.467 s elapsed) --------------------
# 2023-01-05 11:34:35.301 - [NOTICE] callbacks.on_step_start(182): Cycle 4/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:35.361 - [NOTICE] callbacks.on_step_start(182): Cycle 4/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:35.383 - [NOTICE] callbacks.on_step_start(182): Cycle 4/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:35.443 - [NOTICE] callbacks.on_step_start(182): Cycle 4/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:35.553 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.830 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:35.555 - [NOTICE] callbacks.on_cycle_start(174): Cycle 5/287 (1.715 s elapsed) --------------------
# 2023-01-05 11:34:35.556 - [NOTICE] callbacks.on_step_start(182): Cycle 5/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:35.617 - [NOTICE] callbacks.on_step_start(182): Cycle 5/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:35.630 - [NOTICE] callbacks.on_step_start(182): Cycle 5/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:35.682 - [NOTICE] callbacks.on_step_start(182): Cycle 5/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:35.787 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.825 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:35.787 - [NOTICE] callbacks.on_cycle_start(174): Cycle 6/287 (1.953 s elapsed) --------------------
# 2023-01-05 11:34:35.787 - [NOTICE] callbacks.on_step_start(182): Cycle 6/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:35.853 - [NOTICE] callbacks.on_step_start(182): Cycle 6/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:35.867 - [NOTICE] callbacks.on_step_start(182): Cycle 6/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:35.922 - [NOTICE] callbacks.on_step_start(182): Cycle 6/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:36.030 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.819 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:36.031 - [NOTICE] callbacks.on_cycle_start(174): Cycle 7/287 (2.191 s elapsed) --------------------
# 2023-01-05 11:34:36.032 - [NOTICE] callbacks.on_step_start(182): Cycle 7/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:36.094 - [NOTICE] callbacks.on_step_start(182): Cycle 7/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:36.107 - [NOTICE] callbacks.on_step_start(182): Cycle 7/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:36.160 - [NOTICE] callbacks.on_step_start(182): Cycle 7/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:36.264 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.813 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:36.265 - [NOTICE] callbacks.on_cycle_start(174): Cycle 8/287 (2.424 s elapsed) --------------------
# 2023-01-05 11:34:36.265 - [NOTICE] callbacks.on_step_start(182): Cycle 8/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:36.331 - [NOTICE] callbacks.on_step_start(182): Cycle 8/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:36.344 - [NOTICE] callbacks.on_step_start(182): Cycle 8/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:36.403 - [NOTICE] callbacks.on_step_start(182): Cycle 8/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:36.500 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.807 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:36.500 - [NOTICE] callbacks.on_cycle_start(174): Cycle 9/287 (2.667 s elapsed) --------------------
# 2023-01-05 11:34:36.500 - [NOTICE] callbacks.on_step_start(182): Cycle 9/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:36.576 - [NOTICE] callbacks.on_step_start(182): Cycle 9/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:36.588 - [NOTICE] callbacks.on_step_start(182): Cycle 9/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:36.642 - [NOTICE] callbacks.on_step_start(182): Cycle 9/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:36.746 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.802 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:36.748 - [NOTICE] callbacks.on_cycle_start(174): Cycle 10/287 (2.907 s elapsed) --------------------
# 2023-01-05 11:34:36.748 - [NOTICE] callbacks.on_step_start(182): Cycle 10/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:36.811 - [NOTICE] callbacks.on_step_start(182): Cycle 10/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:36.824 - [NOTICE] callbacks.on_step_start(182): Cycle 10/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:36.879 - [NOTICE] callbacks.on_step_start(182): Cycle 10/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:36.992 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.796 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:36.994 - [NOTICE] callbacks.on_cycle_start(174): Cycle 11/287 (3.153 s elapsed) --------------------
# 2023-01-05 11:34:36.994 - [NOTICE] callbacks.on_step_start(182): Cycle 11/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:37.058 - [NOTICE] callbacks.on_step_start(182): Cycle 11/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:37.070 - [NOTICE] callbacks.on_step_start(182): Cycle 11/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:37.127 - [NOTICE] callbacks.on_step_start(182): Cycle 11/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:37.229 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.790 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:37.230 - [NOTICE] callbacks.on_cycle_start(174): Cycle 12/287 (3.390 s elapsed) --------------------
# 2023-01-05 11:34:37.232 - [NOTICE] callbacks.on_step_start(182): Cycle 12/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:37.291 - [NOTICE] callbacks.on_step_start(182): Cycle 12/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:37.305 - [NOTICE] callbacks.on_step_start(182): Cycle 12/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:37.361 - [NOTICE] callbacks.on_step_start(182): Cycle 12/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:37.458 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.784 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:37.458 - [NOTICE] callbacks.on_cycle_start(174): Cycle 13/287 (3.625 s elapsed) --------------------
# 2023-01-05 11:34:37.458 - [NOTICE] callbacks.on_step_start(182): Cycle 13/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:37.528 - [NOTICE] callbacks.on_step_start(182): Cycle 13/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:37.539 - [NOTICE] callbacks.on_step_start(182): Cycle 13/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:37.596 - [NOTICE] callbacks.on_step_start(182): Cycle 13/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:37.703 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.778 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:37.713 - [NOTICE] callbacks.on_cycle_start(174): Cycle 14/287 (3.873 s elapsed) --------------------
# 2023-01-05 11:34:37.713 - [NOTICE] callbacks.on_step_start(182): Cycle 14/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:37.778 - [NOTICE] callbacks.on_step_start(182): Cycle 14/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:37.792 - [NOTICE] callbacks.on_step_start(182): Cycle 14/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:37.850 - [NOTICE] callbacks.on_step_start(182): Cycle 14/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:37.962 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.772 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:37.963 - [NOTICE] callbacks.on_cycle_start(174): Cycle 15/287 (4.124 s elapsed) --------------------
# 2023-01-05 11:34:37.965 - [NOTICE] callbacks.on_step_start(182): Cycle 15/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:38.025 - [NOTICE] callbacks.on_step_start(182): Cycle 15/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:38.038 - [NOTICE] callbacks.on_step_start(182): Cycle 15/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:38.091 - [NOTICE] callbacks.on_step_start(182): Cycle 15/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:38.190 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.766 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:38.191 - [NOTICE] callbacks.on_cycle_start(174): Cycle 16/287 (4.350 s elapsed) --------------------
# 2023-01-05 11:34:38.191 - [NOTICE] callbacks.on_step_start(182): Cycle 16/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:38.252 - [NOTICE] callbacks.on_step_start(182): Cycle 16/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:38.264 - [NOTICE] callbacks.on_step_start(182): Cycle 16/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:38.318 - [NOTICE] callbacks.on_step_start(182): Cycle 16/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:38.421 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.760 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:38.421 - [NOTICE] callbacks.on_cycle_start(174): Cycle 17/287 (4.587 s elapsed) --------------------
# 2023-01-05 11:34:38.421 - [NOTICE] callbacks.on_step_start(182): Cycle 17/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:38.488 - [NOTICE] callbacks.on_step_start(182): Cycle 17/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:38.500 - [NOTICE] callbacks.on_step_start(182): Cycle 17/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:38.551 - [NOTICE] callbacks.on_step_start(182): Cycle 17/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:38.647 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.754 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:38.657 - [NOTICE] callbacks.on_cycle_start(174): Cycle 18/287 (4.817 s elapsed) --------------------
# 2023-01-05 11:34:38.657 - [NOTICE] callbacks.on_step_start(182): Cycle 18/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:38.715 - [NOTICE] callbacks.on_step_start(182): Cycle 18/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:38.728 - [NOTICE] callbacks.on_step_start(182): Cycle 18/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:38.781 - [NOTICE] callbacks.on_step_start(182): Cycle 18/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:38.876 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.748 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:38.886 - [NOTICE] callbacks.on_cycle_start(174): Cycle 19/287 (5.045 s elapsed) --------------------
# 2023-01-05 11:34:38.886 - [NOTICE] callbacks.on_step_start(182): Cycle 19/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:38.946 - [NOTICE] callbacks.on_step_start(182): Cycle 19/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:38.960 - [NOTICE] callbacks.on_step_start(182): Cycle 19/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:39.003 - [NOTICE] callbacks.on_step_start(182): Cycle 19/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:39.109 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.742 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:39.109 - [NOTICE] callbacks.on_cycle_start(174): Cycle 20/287 (5.274 s elapsed) --------------------
# 2023-01-05 11:34:39.109 - [NOTICE] callbacks.on_step_start(182): Cycle 20/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:39.171 - [NOTICE] callbacks.on_step_start(182): Cycle 20/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:39.185 - [NOTICE] callbacks.on_step_start(182): Cycle 20/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:39.241 - [NOTICE] callbacks.on_step_start(182): Cycle 20/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:39.344 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.736 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:39.345 - [NOTICE] callbacks.on_cycle_start(174): Cycle 21/287 (5.505 s elapsed) --------------------
# 2023-01-05 11:34:39.345 - [NOTICE] callbacks.on_step_start(182): Cycle 21/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:39.404 - [NOTICE] callbacks.on_step_start(182): Cycle 21/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:39.423 - [NOTICE] callbacks.on_step_start(182): Cycle 21/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:39.478 - [NOTICE] callbacks.on_step_start(182): Cycle 21/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:39.582 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.730 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:39.582 - [NOTICE] callbacks.on_cycle_start(174): Cycle 22/287 (5.743 s elapsed) --------------------
# 2023-01-05 11:34:39.582 - [NOTICE] callbacks.on_step_start(182): Cycle 22/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:39.643 - [NOTICE] callbacks.on_step_start(182): Cycle 22/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:39.656 - [NOTICE] callbacks.on_step_start(182): Cycle 22/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:39.713 - [NOTICE] callbacks.on_step_start(182): Cycle 22/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:39.813 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.724 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:39.813 - [NOTICE] callbacks.on_cycle_start(174): Cycle 23/287 (5.976 s elapsed) --------------------
# 2023-01-05 11:34:39.813 - [NOTICE] callbacks.on_step_start(182): Cycle 23/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:39.876 - [NOTICE] callbacks.on_step_start(182): Cycle 23/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:39.890 - [NOTICE] callbacks.on_step_start(182): Cycle 23/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:39.945 - [NOTICE] callbacks.on_step_start(182): Cycle 23/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:40.038 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.718 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:40.048 - [NOTICE] callbacks.on_cycle_start(174): Cycle 24/287 (6.209 s elapsed) --------------------
# 2023-01-05 11:34:40.048 - [NOTICE] callbacks.on_step_start(182): Cycle 24/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:40.108 - [NOTICE] callbacks.on_step_start(182): Cycle 24/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:40.120 - [NOTICE] callbacks.on_step_start(182): Cycle 24/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:40.175 - [NOTICE] callbacks.on_step_start(182): Cycle 24/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:40.269 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.712 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:40.279 - [NOTICE] callbacks.on_cycle_start(174): Cycle 25/287 (6.439 s elapsed) --------------------
# 2023-01-05 11:34:40.279 - [NOTICE] callbacks.on_step_start(182): Cycle 25/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:40.339 - [NOTICE] callbacks.on_step_start(182): Cycle 25/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:40.355 - [NOTICE] callbacks.on_step_start(182): Cycle 25/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:40.414 - [NOTICE] callbacks.on_step_start(182): Cycle 25/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:40.506 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.706 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:40.516 - [NOTICE] callbacks.on_cycle_start(174): Cycle 26/287 (6.677 s elapsed) --------------------
# 2023-01-05 11:34:40.516 - [NOTICE] callbacks.on_step_start(182): Cycle 26/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:40.571 - [NOTICE] callbacks.on_step_start(182): Cycle 26/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:40.584 - [NOTICE] callbacks.on_step_start(182): Cycle 26/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:40.639 - [NOTICE] callbacks.on_step_start(182): Cycle 26/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:40.735 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.700 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:40.735 - [NOTICE] callbacks.on_cycle_start(174): Cycle 27/287 (6.903 s elapsed) --------------------
# 2023-01-05 11:34:40.735 - [NOTICE] callbacks.on_step_start(182): Cycle 27/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:40.805 - [NOTICE] callbacks.on_step_start(182): Cycle 27/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:40.819 - [NOTICE] callbacks.on_step_start(182): Cycle 27/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:40.878 - [NOTICE] callbacks.on_step_start(182): Cycle 27/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:40.975 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.694 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:40.975 - [NOTICE] callbacks.on_cycle_start(174): Cycle 28/287 (7.145 s elapsed) --------------------
# 2023-01-05 11:34:40.985 - [NOTICE] callbacks.on_step_start(182): Cycle 28/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:41.035 - [NOTICE] callbacks.on_step_start(182): Cycle 28/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:41.048 - [NOTICE] callbacks.on_step_start(182): Cycle 28/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:41.104 - [NOTICE] callbacks.on_step_start(182): Cycle 28/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:41.210 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.688 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:41.211 - [NOTICE] callbacks.on_cycle_start(174): Cycle 29/287 (7.371 s elapsed) --------------------
# 2023-01-05 11:34:41.212 - [NOTICE] callbacks.on_step_start(182): Cycle 29/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:41.266 - [NOTICE] callbacks.on_step_start(182): Cycle 29/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:41.278 - [NOTICE] callbacks.on_step_start(182): Cycle 29/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:41.326 - [NOTICE] callbacks.on_step_start(182): Cycle 29/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:41.431 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.681 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:41.431 - [NOTICE] callbacks.on_cycle_start(174): Cycle 30/287 (7.593 s elapsed) --------------------
# 2023-01-05 11:34:41.431 - [NOTICE] callbacks.on_step_start(182): Cycle 30/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:41.490 - [NOTICE] callbacks.on_step_start(182): Cycle 30/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:41.502 - [NOTICE] callbacks.on_step_start(182): Cycle 30/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:41.550 - [NOTICE] callbacks.on_step_start(182): Cycle 30/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:41.651 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.675 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:41.652 - [NOTICE] callbacks.on_cycle_start(174): Cycle 31/287 (7.812 s elapsed) --------------------
# 2023-01-05 11:34:41.653 - [NOTICE] callbacks.on_step_start(182): Cycle 31/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:41.705 - [NOTICE] callbacks.on_step_start(182): Cycle 31/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:41.718 - [NOTICE] callbacks.on_step_start(182): Cycle 31/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:41.766 - [NOTICE] callbacks.on_step_start(182): Cycle 31/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:41.873 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.669 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:41.873 - [NOTICE] callbacks.on_cycle_start(174): Cycle 32/287 (8.036 s elapsed) --------------------
# 2023-01-05 11:34:41.873 - [NOTICE] callbacks.on_step_start(182): Cycle 32/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:41.929 - [NOTICE] callbacks.on_step_start(182): Cycle 32/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:41.940 - [NOTICE] callbacks.on_step_start(182): Cycle 32/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:41.985 - [NOTICE] callbacks.on_step_start(182): Cycle 32/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:42.081 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.663 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:42.091 - [NOTICE] callbacks.on_cycle_start(174): Cycle 33/287 (8.251 s elapsed) --------------------
# 2023-01-05 11:34:42.091 - [NOTICE] callbacks.on_step_start(182): Cycle 33/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:42.142 - [NOTICE] callbacks.on_step_start(182): Cycle 33/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:42.155 - [NOTICE] callbacks.on_step_start(182): Cycle 33/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:42.200 - [NOTICE] callbacks.on_step_start(182): Cycle 33/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:42.299 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.657 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:42.309 - [NOTICE] callbacks.on_cycle_start(174): Cycle 34/287 (8.469 s elapsed) --------------------
# 2023-01-05 11:34:42.309 - [NOTICE] callbacks.on_step_start(182): Cycle 34/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:42.362 - [NOTICE] callbacks.on_step_start(182): Cycle 34/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:42.381 - [NOTICE] callbacks.on_step_start(182): Cycle 34/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:42.431 - [NOTICE] callbacks.on_step_start(182): Cycle 34/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:42.526 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.651 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:42.536 - [NOTICE] callbacks.on_cycle_start(174): Cycle 35/287 (8.696 s elapsed) --------------------
# 2023-01-05 11:34:42.536 - [NOTICE] callbacks.on_step_start(182): Cycle 35/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:42.587 - [NOTICE] callbacks.on_step_start(182): Cycle 35/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:42.600 - [NOTICE] callbacks.on_step_start(182): Cycle 35/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:42.648 - [NOTICE] callbacks.on_step_start(182): Cycle 35/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:42.751 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.645 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:42.761 - [NOTICE] callbacks.on_cycle_start(174): Cycle 36/287 (8.921 s elapsed) --------------------
# 2023-01-05 11:34:42.761 - [NOTICE] callbacks.on_step_start(182): Cycle 36/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:42.814 - [NOTICE] callbacks.on_step_start(182): Cycle 36/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:42.827 - [NOTICE] callbacks.on_step_start(182): Cycle 36/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:42.876 - [NOTICE] callbacks.on_step_start(182): Cycle 36/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:42.979 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.639 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:42.979 - [NOTICE] callbacks.on_cycle_start(174): Cycle 37/287 (9.147 s elapsed) --------------------
# 2023-01-05 11:34:42.979 - [NOTICE] callbacks.on_step_start(182): Cycle 37/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:43.038 - [NOTICE] callbacks.on_step_start(182): Cycle 37/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:43.049 - [NOTICE] callbacks.on_step_start(182): Cycle 37/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:43.096 - [NOTICE] callbacks.on_step_start(182): Cycle 37/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:43.203 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.632 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:43.203 - [NOTICE] callbacks.on_cycle_start(174): Cycle 38/287 (9.372 s elapsed) --------------------
# 2023-01-05 11:34:43.213 - [NOTICE] callbacks.on_step_start(182): Cycle 38/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:43.268 - [NOTICE] callbacks.on_step_start(182): Cycle 38/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:43.279 - [NOTICE] callbacks.on_step_start(182): Cycle 38/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:43.326 - [NOTICE] callbacks.on_step_start(182): Cycle 38/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:43.441 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.626 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:43.441 - [NOTICE] callbacks.on_cycle_start(174): Cycle 39/287 (9.605 s elapsed) --------------------
# 2023-01-05 11:34:43.441 - [NOTICE] callbacks.on_step_start(182): Cycle 39/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:43.497 - [NOTICE] callbacks.on_step_start(182): Cycle 39/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:43.510 - [NOTICE] callbacks.on_step_start(182): Cycle 39/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:43.556 - [NOTICE] callbacks.on_step_start(182): Cycle 39/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:43.667 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.620 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:43.668 - [NOTICE] callbacks.on_cycle_start(174): Cycle 40/287 (9.828 s elapsed) --------------------
# 2023-01-05 11:34:43.669 - [NOTICE] callbacks.on_step_start(182): Cycle 40/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:43.721 - [NOTICE] callbacks.on_step_start(182): Cycle 40/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:43.735 - [NOTICE] callbacks.on_step_start(182): Cycle 40/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:43.781 - [NOTICE] callbacks.on_step_start(182): Cycle 40/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:43.895 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.614 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:43.897 - [NOTICE] callbacks.on_cycle_start(174): Cycle 41/287 (10.056 s elapsed) --------------------
# 2023-01-05 11:34:43.897 - [NOTICE] callbacks.on_step_start(182): Cycle 41/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:43.957 - [NOTICE] callbacks.on_step_start(182): Cycle 41/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:43.960 - [NOTICE] callbacks.on_step_start(182): Cycle 41/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:44.021 - [NOTICE] callbacks.on_step_start(182): Cycle 41/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:44.128 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.608 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:44.128 - [NOTICE] callbacks.on_cycle_start(174): Cycle 42/287 (10.294 s elapsed) --------------------
# 2023-01-05 11:34:44.128 - [NOTICE] callbacks.on_step_start(182): Cycle 42/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:44.188 - [NOTICE] callbacks.on_step_start(182): Cycle 42/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:44.201 - [NOTICE] callbacks.on_step_start(182): Cycle 42/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:44.247 - [NOTICE] callbacks.on_step_start(182): Cycle 42/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:44.364 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.602 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:44.365 - [NOTICE] callbacks.on_cycle_start(174): Cycle 43/287 (10.525 s elapsed) --------------------
# 2023-01-05 11:34:44.366 - [NOTICE] callbacks.on_step_start(182): Cycle 43/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:44.422 - [NOTICE] callbacks.on_step_start(182): Cycle 43/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:44.433 - [NOTICE] callbacks.on_step_start(182): Cycle 43/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:44.478 - [NOTICE] callbacks.on_step_start(182): Cycle 43/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:44.587 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.596 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:44.587 - [NOTICE] callbacks.on_cycle_start(174): Cycle 44/287 (10.752 s elapsed) --------------------
# 2023-01-05 11:34:44.587 - [NOTICE] callbacks.on_step_start(182): Cycle 44/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:44.645 - [NOTICE] callbacks.on_step_start(182): Cycle 44/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:44.660 - [NOTICE] callbacks.on_step_start(182): Cycle 44/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:44.707 - [NOTICE] callbacks.on_step_start(182): Cycle 44/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:44.835 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.590 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:44.845 - [NOTICE] callbacks.on_cycle_start(174): Cycle 45/287 (11.004 s elapsed) --------------------
# 2023-01-05 11:34:44.845 - [NOTICE] callbacks.on_step_start(182): Cycle 45/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:44.903 - [NOTICE] callbacks.on_step_start(182): Cycle 45/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:44.915 - [NOTICE] callbacks.on_step_start(182): Cycle 45/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:44.964 - [NOTICE] callbacks.on_step_start(182): Cycle 45/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:45.073 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.583 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:45.073 - [NOTICE] callbacks.on_cycle_start(174): Cycle 46/287 (11.236 s elapsed) --------------------
# 2023-01-05 11:34:45.073 - [NOTICE] callbacks.on_step_start(182): Cycle 46/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:45.127 - [NOTICE] callbacks.on_step_start(182): Cycle 46/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:45.140 - [NOTICE] callbacks.on_step_start(182): Cycle 46/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:45.189 - [NOTICE] callbacks.on_step_start(182): Cycle 46/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:45.300 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.577 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:45.301 - [NOTICE] callbacks.on_cycle_start(174): Cycle 47/287 (11.460 s elapsed) --------------------
# 2023-01-05 11:34:45.301 - [NOTICE] callbacks.on_step_start(182): Cycle 47/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:45.359 - [NOTICE] callbacks.on_step_start(182): Cycle 47/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:45.372 - [NOTICE] callbacks.on_step_start(182): Cycle 47/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:45.423 - [NOTICE] callbacks.on_step_start(182): Cycle 47/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:45.525 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.571 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:45.525 - [NOTICE] callbacks.on_cycle_start(174): Cycle 48/287 (11.694 s elapsed) --------------------
# 2023-01-05 11:34:45.535 - [NOTICE] callbacks.on_step_start(182): Cycle 48/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:45.594 - [NOTICE] callbacks.on_step_start(182): Cycle 48/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:45.602 - [NOTICE] callbacks.on_step_start(182): Cycle 48/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:45.659 - [NOTICE] callbacks.on_step_start(182): Cycle 48/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:45.763 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.565 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:45.763 - [NOTICE] callbacks.on_cycle_start(174): Cycle 49/287 (11.930 s elapsed) --------------------
# 2023-01-05 11:34:45.763 - [NOTICE] callbacks.on_step_start(182): Cycle 49/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:45.829 - [NOTICE] callbacks.on_step_start(182): Cycle 49/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:45.836 - [NOTICE] callbacks.on_step_start(182): Cycle 49/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:45.893 - [NOTICE] callbacks.on_step_start(182): Cycle 49/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:45.994 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.559 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:45.994 - [NOTICE] callbacks.on_cycle_start(174): Cycle 50/287 (12.162 s elapsed) --------------------
# 2023-01-05 11:34:45.994 - [NOTICE] callbacks.on_step_start(182): Cycle 50/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:46.063 - [NOTICE] callbacks.on_step_start(182): Cycle 50/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:46.076 - [NOTICE] callbacks.on_step_start(182): Cycle 50/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:46.128 - [NOTICE] callbacks.on_step_start(182): Cycle 50/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:46.228 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.553 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:46.238 - [NOTICE] callbacks.on_cycle_start(174): Cycle 51/287 (12.398 s elapsed) --------------------
# 2023-01-05 11:34:46.238 - [NOTICE] callbacks.on_step_start(182): Cycle 51/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:46.295 - [NOTICE] callbacks.on_step_start(182): Cycle 51/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:46.309 - [NOTICE] callbacks.on_step_start(182): Cycle 51/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:46.356 - [NOTICE] callbacks.on_step_start(182): Cycle 51/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:46.480 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.547 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:46.480 - [NOTICE] callbacks.on_cycle_start(174): Cycle 52/287 (12.642 s elapsed) --------------------
# 2023-01-05 11:34:46.480 - [NOTICE] callbacks.on_step_start(182): Cycle 52/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:46.540 - [NOTICE] callbacks.on_step_start(182): Cycle 52/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:46.553 - [NOTICE] callbacks.on_step_start(182): Cycle 52/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:46.603 - [NOTICE] callbacks.on_step_start(182): Cycle 52/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:46.708 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.541 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:46.708 - [NOTICE] callbacks.on_cycle_start(174): Cycle 53/287 (12.878 s elapsed) --------------------
# 2023-01-05 11:34:46.718 - [NOTICE] callbacks.on_step_start(182): Cycle 53/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:46.775 - [NOTICE] callbacks.on_step_start(182): Cycle 53/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:46.788 - [NOTICE] callbacks.on_step_start(182): Cycle 53/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:46.841 - [NOTICE] callbacks.on_step_start(182): Cycle 53/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:46.942 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.535 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:46.952 - [NOTICE] callbacks.on_cycle_start(174): Cycle 54/287 (13.112 s elapsed) --------------------
# 2023-01-05 11:34:46.952 - [NOTICE] callbacks.on_step_start(182): Cycle 54/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:47.008 - [NOTICE] callbacks.on_step_start(182): Cycle 54/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:47.022 - [NOTICE] callbacks.on_step_start(182): Cycle 54/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:47.082 - [NOTICE] callbacks.on_step_start(182): Cycle 54/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:47.193 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.528 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:47.193 - [NOTICE] callbacks.on_cycle_start(174): Cycle 55/287 (13.359 s elapsed) --------------------
# 2023-01-05 11:34:47.193 - [NOTICE] callbacks.on_step_start(182): Cycle 55/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:47.256 - [NOTICE] callbacks.on_step_start(182): Cycle 55/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:47.268 - [NOTICE] callbacks.on_step_start(182): Cycle 55/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:47.322 - [NOTICE] callbacks.on_step_start(182): Cycle 55/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:47.437 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.522 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:47.438 - [NOTICE] callbacks.on_cycle_start(174): Cycle 56/287 (13.598 s elapsed) --------------------
# 2023-01-05 11:34:47.439 - [NOTICE] callbacks.on_step_start(182): Cycle 56/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:47.493 - [NOTICE] callbacks.on_step_start(182): Cycle 56/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:47.506 - [NOTICE] callbacks.on_step_start(182): Cycle 56/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:47.558 - [NOTICE] callbacks.on_step_start(182): Cycle 56/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:47.662 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.516 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:47.662 - [NOTICE] callbacks.on_cycle_start(174): Cycle 57/287 (13.828 s elapsed) --------------------
# 2023-01-05 11:34:47.662 - [NOTICE] callbacks.on_step_start(182): Cycle 57/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:47.726 - [NOTICE] callbacks.on_step_start(182): Cycle 57/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:47.739 - [NOTICE] callbacks.on_step_start(182): Cycle 57/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:47.791 - [NOTICE] callbacks.on_step_start(182): Cycle 57/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:47.894 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.510 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:47.894 - [NOTICE] callbacks.on_cycle_start(174): Cycle 58/287 (14.062 s elapsed) --------------------
# 2023-01-05 11:34:47.904 - [NOTICE] callbacks.on_step_start(182): Cycle 58/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:47.964 - [NOTICE] callbacks.on_step_start(182): Cycle 58/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:47.976 - [NOTICE] callbacks.on_step_start(182): Cycle 58/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:48.027 - [NOTICE] callbacks.on_step_start(182): Cycle 58/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:48.135 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.504 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:48.136 - [NOTICE] callbacks.on_cycle_start(174): Cycle 59/287 (14.297 s elapsed) --------------------
# 2023-01-05 11:34:48.137 - [NOTICE] callbacks.on_step_start(182): Cycle 59/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:48.194 - [NOTICE] callbacks.on_step_start(182): Cycle 59/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:48.207 - [NOTICE] callbacks.on_step_start(182): Cycle 59/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:48.259 - [NOTICE] callbacks.on_step_start(182): Cycle 59/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:48.372 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.498 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:48.374 - [NOTICE] callbacks.on_cycle_start(174): Cycle 60/287 (14.534 s elapsed) --------------------
# 2023-01-05 11:34:48.375 - [NOTICE] callbacks.on_step_start(182): Cycle 60/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:48.431 - [NOTICE] callbacks.on_step_start(182): Cycle 60/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:48.444 - [NOTICE] callbacks.on_step_start(182): Cycle 60/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:48.495 - [NOTICE] callbacks.on_step_start(182): Cycle 60/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:48.597 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.492 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:48.597 - [NOTICE] callbacks.on_cycle_start(174): Cycle 61/287 (14.766 s elapsed) --------------------
# 2023-01-05 11:34:48.607 - [NOTICE] callbacks.on_step_start(182): Cycle 61/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:48.661 - [NOTICE] callbacks.on_step_start(182): Cycle 61/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:48.674 - [NOTICE] callbacks.on_step_start(182): Cycle 61/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:48.728 - [NOTICE] callbacks.on_step_start(182): Cycle 61/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:48.835 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.486 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:48.835 - [NOTICE] callbacks.on_cycle_start(174): Cycle 62/287 (14.997 s elapsed) --------------------
# 2023-01-05 11:34:48.835 - [NOTICE] callbacks.on_step_start(182): Cycle 62/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:48.893 - [NOTICE] callbacks.on_step_start(182): Cycle 62/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:48.906 - [NOTICE] callbacks.on_step_start(182): Cycle 62/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:48.960 - [NOTICE] callbacks.on_step_start(182): Cycle 62/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:49.069 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.480 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:49.070 - [NOTICE] callbacks.on_cycle_start(174): Cycle 63/287 (15.230 s elapsed) --------------------
# 2023-01-05 11:34:49.071 - [NOTICE] callbacks.on_step_start(182): Cycle 63/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:49.126 - [NOTICE] callbacks.on_step_start(182): Cycle 63/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:49.138 - [NOTICE] callbacks.on_step_start(182): Cycle 63/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:49.186 - [NOTICE] callbacks.on_step_start(182): Cycle 63/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:49.300 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.474 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:49.300 - [NOTICE] callbacks.on_cycle_start(174): Cycle 64/287 (15.466 s elapsed) --------------------
# 2023-01-05 11:34:49.300 - [NOTICE] callbacks.on_step_start(182): Cycle 64/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:49.368 - [NOTICE] callbacks.on_step_start(182): Cycle 64/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:49.381 - [NOTICE] callbacks.on_step_start(182): Cycle 64/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:49.438 - [NOTICE] callbacks.on_step_start(182): Cycle 64/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:49.548 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.468 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:49.548 - [NOTICE] callbacks.on_cycle_start(174): Cycle 65/287 (15.710 s elapsed) --------------------
# 2023-01-05 11:34:49.548 - [NOTICE] callbacks.on_step_start(182): Cycle 65/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:49.608 - [NOTICE] callbacks.on_step_start(182): Cycle 65/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:49.621 - [NOTICE] callbacks.on_step_start(182): Cycle 65/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:49.676 - [NOTICE] callbacks.on_step_start(182): Cycle 65/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:49.780 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.461 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:49.780 - [NOTICE] callbacks.on_cycle_start(174): Cycle 66/287 (15.946 s elapsed) --------------------
# 2023-01-05 11:34:49.780 - [NOTICE] callbacks.on_step_start(182): Cycle 66/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:49.843 - [NOTICE] callbacks.on_step_start(182): Cycle 66/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:49.855 - [NOTICE] callbacks.on_step_start(182): Cycle 66/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:49.906 - [NOTICE] callbacks.on_step_start(182): Cycle 66/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:50.014 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.455 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:50.014 - [NOTICE] callbacks.on_cycle_start(174): Cycle 67/287 (16.183 s elapsed) --------------------
# 2023-01-05 11:34:50.024 - [NOTICE] callbacks.on_step_start(182): Cycle 67/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:50.079 - [NOTICE] callbacks.on_step_start(182): Cycle 67/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:50.092 - [NOTICE] callbacks.on_step_start(182): Cycle 67/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:50.135 - [NOTICE] callbacks.on_step_start(182): Cycle 67/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:50.261 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.449 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:50.261 - [NOTICE] callbacks.on_cycle_start(174): Cycle 68/287 (16.422 s elapsed) --------------------
# 2023-01-05 11:34:50.261 - [NOTICE] callbacks.on_step_start(182): Cycle 68/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:50.316 - [NOTICE] callbacks.on_step_start(182): Cycle 68/287, step 2/4: Rest for 5 min
# 2023-01-05 11:34:50.327 - [NOTICE] callbacks.on_step_start(182): Cycle 68/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:34:50.375 - [NOTICE] callbacks.on_step_start(182): Cycle 68/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:34:50.483 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 4.443 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:34:50.483 - [NOTICE] callbacks.on_cycle_start(174): Cycle 69/287 (16.650 s elapsed) --------------------
# 2023-01-05 11:34:50.483 - [NOTICE] callbacks.on_step_start(182): Cycle 69/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:34:50.543 - [NOTICE] callbacks.on_step_start(182): Cycle 69/287, step 2/4: Rest for 5 min
# ...
# 2023-01-05 11:35:35.668 - [NOTICE] callbacks.on_cycle_start(174): Cycle 266/287 (1 minute, 2 seconds elapsed) --------------------
# 2023-01-05 11:35:35.669 - [NOTICE] callbacks.on_step_start(182): Cycle 266/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:35:35.715 - [NOTICE] callbacks.on_step_start(182): Cycle 266/287, step 2/4: Rest for 5 min
# 2023-01-05 11:35:35.728 - [NOTICE] callbacks.on_step_start(182): Cycle 266/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:35:35.764 - [NOTICE] callbacks.on_step_start(182): Cycle 266/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:35:35.883 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 3.280 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:35:35.883 - [NOTICE] callbacks.on_cycle_start(174): Cycle 267/287 (1 minute, 2 seconds elapsed) --------------------
# 2023-01-05 11:35:35.883 - [NOTICE] callbacks.on_step_start(182): Cycle 267/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:35:35.938 - [NOTICE] callbacks.on_step_start(182): Cycle 267/287, step 2/4: Rest for 5 min
# 2023-01-05 11:35:35.950 - [NOTICE] callbacks.on_step_start(182): Cycle 267/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:35:35.986 - [NOTICE] callbacks.on_step_start(182): Cycle 267/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:35:36.109 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 3.274 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:35:36.110 - [NOTICE] callbacks.on_cycle_start(174): Cycle 268/287 (1 minute, 2 seconds elapsed) --------------------
# 2023-01-05 11:35:36.111 - [NOTICE] callbacks.on_step_start(182): Cycle 268/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:35:36.161 - [NOTICE] callbacks.on_step_start(182): Cycle 268/287, step 2/4: Rest for 5 min
# 2023-01-05 11:35:36.177 - [NOTICE] callbacks.on_step_start(182): Cycle 268/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:35:36.213 - [NOTICE] callbacks.on_step_start(182): Cycle 268/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:35:36.330 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 3.268 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:35:36.330 - [NOTICE] callbacks.on_cycle_start(174): Cycle 269/287 (1 minute, 2 seconds elapsed) --------------------
# 2023-01-05 11:35:36.330 - [NOTICE] callbacks.on_step_start(182): Cycle 269/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:35:36.383 - [NOTICE] callbacks.on_step_start(182): Cycle 269/287, step 2/4: Rest for 5 min
# 2023-01-05 11:35:36.395 - [NOTICE] callbacks.on_step_start(182): Cycle 269/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:35:36.432 - [NOTICE] callbacks.on_step_start(182): Cycle 269/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:35:36.546 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 3.263 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:35:36.547 - [NOTICE] callbacks.on_cycle_start(174): Cycle 270/287 (1 minute, 3 seconds elapsed) --------------------
# 2023-01-05 11:35:36.547 - [NOTICE] callbacks.on_step_start(182): Cycle 270/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:35:36.597 - [NOTICE] callbacks.on_step_start(182): Cycle 270/287, step 2/4: Rest for 5 min
# 2023-01-05 11:35:36.611 - [NOTICE] callbacks.on_step_start(182): Cycle 270/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:35:36.649 - [NOTICE] callbacks.on_step_start(182): Cycle 270/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:35:36.754 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 3.257 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:35:36.754 - [NOTICE] callbacks.on_cycle_start(174): Cycle 271/287 (1 minute, 3 seconds elapsed) --------------------
# 2023-01-05 11:35:36.764 - [NOTICE] callbacks.on_step_start(182): Cycle 271/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:35:36.818 - [NOTICE] callbacks.on_step_start(182): Cycle 271/287, step 2/4: Rest for 5 min
# 2023-01-05 11:35:36.830 - [NOTICE] callbacks.on_step_start(182): Cycle 271/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:35:36.868 - [NOTICE] callbacks.on_step_start(182): Cycle 271/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:35:36.982 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 3.251 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:35:36.982 - [NOTICE] callbacks.on_cycle_start(174): Cycle 272/287 (1 minute, 3 seconds elapsed) --------------------
# 2023-01-05 11:35:36.983 - [NOTICE] callbacks.on_step_start(182): Cycle 272/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:35:37.033 - [NOTICE] callbacks.on_step_start(182): Cycle 272/287, step 2/4: Rest for 5 min
# 2023-01-05 11:35:37.046 - [NOTICE] callbacks.on_step_start(182): Cycle 272/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:35:37.088 - [NOTICE] callbacks.on_step_start(182): Cycle 272/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:35:37.217 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 3.246 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:35:37.217 - [NOTICE] callbacks.on_cycle_start(174): Cycle 273/287 (1 minute, 3 seconds elapsed) --------------------
# 2023-01-05 11:35:37.217 - [NOTICE] callbacks.on_step_start(182): Cycle 273/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:35:37.270 - [NOTICE] callbacks.on_step_start(182): Cycle 273/287, step 2/4: Rest for 5 min
# 2023-01-05 11:35:37.284 - [NOTICE] callbacks.on_step_start(182): Cycle 273/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:35:37.322 - [NOTICE] callbacks.on_step_start(182): Cycle 273/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:35:37.431 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 3.240 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:35:37.431 - [NOTICE] callbacks.on_cycle_start(174): Cycle 274/287 (1 minute, 4 seconds elapsed) --------------------
# 2023-01-05 11:35:37.441 - [NOTICE] callbacks.on_step_start(182): Cycle 274/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:35:37.491 - [NOTICE] callbacks.on_step_start(182): Cycle 274/287, step 2/4: Rest for 5 min
# 2023-01-05 11:35:37.503 - [NOTICE] callbacks.on_step_start(182): Cycle 274/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:35:37.540 - [NOTICE] callbacks.on_step_start(182): Cycle 274/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:35:37.649 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 3.234 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:35:37.649 - [NOTICE] callbacks.on_cycle_start(174): Cycle 275/287 (1 minute, 4 seconds elapsed) --------------------
# 2023-01-05 11:35:37.649 - [NOTICE] callbacks.on_step_start(182): Cycle 275/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:35:37.713 - [NOTICE] callbacks.on_step_start(182): Cycle 275/287, step 2/4: Rest for 5 min
# 2023-01-05 11:35:37.725 - [NOTICE] callbacks.on_step_start(182): Cycle 275/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:35:37.760 - [NOTICE] callbacks.on_step_start(182): Cycle 275/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:35:37.880 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 3.229 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:35:37.881 - [NOTICE] callbacks.on_cycle_start(174): Cycle 276/287 (1 minute, 4 seconds elapsed) --------------------
# 2023-01-05 11:35:37.882 - [NOTICE] callbacks.on_step_start(182): Cycle 276/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:35:37.931 - [NOTICE] callbacks.on_step_start(182): Cycle 276/287, step 2/4: Rest for 5 min
# 2023-01-05 11:35:37.942 - [NOTICE] callbacks.on_step_start(182): Cycle 276/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:35:37.982 - [NOTICE] callbacks.on_step_start(182): Cycle 276/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:35:38.105 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 3.223 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:35:38.105 - [NOTICE] callbacks.on_cycle_start(174): Cycle 277/287 (1 minute, 4 seconds elapsed) --------------------
# 2023-01-05 11:35:38.105 - [NOTICE] callbacks.on_step_start(182): Cycle 277/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:35:38.159 - [NOTICE] callbacks.on_step_start(182): Cycle 277/287, step 2/4: Rest for 5 min
# 2023-01-05 11:35:38.173 - [NOTICE] callbacks.on_step_start(182): Cycle 277/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:35:38.215 - [NOTICE] callbacks.on_step_start(182): Cycle 277/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:35:38.339 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 3.217 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:35:38.339 - [NOTICE] callbacks.on_cycle_start(174): Cycle 278/287 (1 minute, 5 seconds elapsed) --------------------
# 2023-01-05 11:35:38.339 - [NOTICE] callbacks.on_step_start(182): Cycle 278/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:35:38.393 - [NOTICE] callbacks.on_step_start(182): Cycle 278/287, step 2/4: Rest for 5 min
# 2023-01-05 11:35:38.407 - [NOTICE] callbacks.on_step_start(182): Cycle 278/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:35:38.450 - [NOTICE] callbacks.on_step_start(182): Cycle 278/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:35:38.570 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 3.212 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:35:38.570 - [NOTICE] callbacks.on_cycle_start(174): Cycle 279/287 (1 minute, 5 seconds elapsed) --------------------
# 2023-01-05 11:35:38.580 - [NOTICE] callbacks.on_step_start(182): Cycle 279/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:35:38.629 - [NOTICE] callbacks.on_step_start(182): Cycle 279/287, step 2/4: Rest for 5 min
# 2023-01-05 11:35:38.642 - [NOTICE] callbacks.on_step_start(182): Cycle 279/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:35:38.683 - [NOTICE] callbacks.on_step_start(182): Cycle 279/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:35:38.808 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 3.206 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:35:38.809 - [NOTICE] callbacks.on_cycle_start(174): Cycle 280/287 (1 minute, 5 seconds elapsed) --------------------
# 2023-01-05 11:35:38.810 - [NOTICE] callbacks.on_step_start(182): Cycle 280/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:35:38.856 - [NOTICE] callbacks.on_step_start(182): Cycle 280/287, step 2/4: Rest for 5 min
# 2023-01-05 11:35:38.869 - [NOTICE] callbacks.on_step_start(182): Cycle 280/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:35:38.910 - [NOTICE] callbacks.on_step_start(182): Cycle 280/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:35:39.036 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 3.200 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:35:39.036 - [NOTICE] callbacks.on_cycle_start(174): Cycle 281/287 (1 minute, 5 seconds elapsed) --------------------
# 2023-01-05 11:35:39.036 - [NOTICE] callbacks.on_step_start(182): Cycle 281/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:35:39.094 - [NOTICE] callbacks.on_step_start(182): Cycle 281/287, step 2/4: Rest for 5 min
# 2023-01-05 11:35:39.106 - [NOTICE] callbacks.on_step_start(182): Cycle 281/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:35:39.149 - [NOTICE] callbacks.on_step_start(182): Cycle 281/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:35:39.273 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 3.195 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:35:39.274 - [NOTICE] callbacks.on_cycle_start(174): Cycle 282/287 (1 minute, 5 seconds elapsed) --------------------
# 2023-01-05 11:35:39.274 - [NOTICE] callbacks.on_step_start(182): Cycle 282/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:35:39.318 - [NOTICE] callbacks.on_step_start(182): Cycle 282/287, step 2/4: Rest for 5 min
# 2023-01-05 11:35:39.331 - [NOTICE] callbacks.on_step_start(182): Cycle 282/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:35:39.374 - [NOTICE] callbacks.on_step_start(182): Cycle 282/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:35:39.505 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 3.189 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:35:39.505 - [NOTICE] callbacks.on_cycle_start(174): Cycle 283/287 (1 minute, 6 seconds elapsed) --------------------
# 2023-01-05 11:35:39.505 - [NOTICE] callbacks.on_step_start(182): Cycle 283/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:35:39.551 - [NOTICE] callbacks.on_step_start(182): Cycle 283/287, step 2/4: Rest for 5 min
# 2023-01-05 11:35:39.563 - [NOTICE] callbacks.on_step_start(182): Cycle 283/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:35:39.604 - [NOTICE] callbacks.on_step_start(182): Cycle 283/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:35:39.729 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 3.183 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:35:39.729 - [NOTICE] callbacks.on_cycle_start(174): Cycle 284/287 (1 minute, 6 seconds elapsed) --------------------
# 2023-01-05 11:35:39.729 - [NOTICE] callbacks.on_step_start(182): Cycle 284/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:35:39.779 - [NOTICE] callbacks.on_step_start(182): Cycle 284/287, step 2/4: Rest for 5 min
# 2023-01-05 11:35:39.790 - [NOTICE] callbacks.on_step_start(182): Cycle 284/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:35:39.831 - [NOTICE] callbacks.on_step_start(182): Cycle 284/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:35:39.947 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 3.178 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:35:39.947 - [NOTICE] callbacks.on_cycle_start(174): Cycle 285/287 (1 minute, 6 seconds elapsed) --------------------
# 2023-01-05 11:35:39.947 - [NOTICE] callbacks.on_step_start(182): Cycle 285/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:35:40.001 - [NOTICE] callbacks.on_step_start(182): Cycle 285/287, step 2/4: Rest for 5 min
# 2023-01-05 11:35:40.013 - [NOTICE] callbacks.on_step_start(182): Cycle 285/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:35:40.055 - [NOTICE] callbacks.on_step_start(182): Cycle 285/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:35:40.182 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 3.172 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:35:40.184 - [NOTICE] callbacks.on_cycle_start(174): Cycle 286/287 (1 minute, 6 seconds elapsed) --------------------
# 2023-01-05 11:35:40.185 - [NOTICE] callbacks.on_step_start(182): Cycle 286/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:35:40.234 - [NOTICE] callbacks.on_step_start(182): Cycle 286/287, step 2/4: Rest for 5 min
# 2023-01-05 11:35:40.249 - [NOTICE] callbacks.on_step_start(182): Cycle 286/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:35:40.293 - [NOTICE] callbacks.on_step_start(182): Cycle 286/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:35:40.419 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 3.166 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:35:40.419 - [NOTICE] callbacks.on_cycle_start(174): Cycle 287/287 (1 minute, 7 seconds elapsed) --------------------
# 2023-01-05 11:35:40.419 - [NOTICE] callbacks.on_step_start(182): Cycle 287/287, step 1/4: Discharge at 1.5C until 3V
# 2023-01-05 11:35:40.467 - [NOTICE] callbacks.on_step_start(182): Cycle 287/287, step 2/4: Rest for 5 min
# 2023-01-05 11:35:40.479 - [NOTICE] callbacks.on_step_start(182): Cycle 287/287, step 3/4: Charge at 1.5C until 4.2V
# 2023-01-05 11:35:40.521 - [NOTICE] callbacks.on_step_start(182): Cycle 287/287, step 4/4: Hold at 4.2V until C/50
# 2023-01-05 11:35:40.640 - [NOTICE] callbacks.on_cycle_end(196): Capacity is now 3.161 Ah (originally 4.847 Ah, will stop at 2.423 Ah)
# 2023-01-05 11:35:40.661 - [NOTICE] callbacks.on_experiment_end(222): Finish experiment simulation, took 1 minute, 7 seconds

# %%
# fig = plotc(all_suplt.savefig(fig_DIR +'plating_tuning_'+sim_des+'_'+cell_no+'_eSOH.png')mvars_dict,dfe);
x100=sol_long.summary_variables["x_100"]
y100=sol_long.summary_variables["y_100"]
x0=sol_long.summary_variables["x_0"]
y0=sol_long.summary_variables["y_0"]
Cap=sol_long.summary_variables["Capacity [A.h]"]
LoC_SEI_summ=sol_long.summary_variables["Loss of capacity to SEI [A.h]"]
LAM_P=sol_long.summary_variables["Loss of active material in positive electrode [%]"]
LAM_N=sol_long.summary_variables["Loss of active material in negative electrode [%]"]
C_Neg=sol_long.summary_variables["C_n"]
C_pos=sol_long.summary_variables["C_p"]
LLI=sol_long.summary_variables["Loss of lithium inventory [%]"]
cycle_num=sol_long.summary_variables["Cycle number"]
t = sol_long["Time [s]"].entries
I = sol_long["Current [A]"].entries
Q = sol_long['Discharge capacity [A.h]'].entries
LoC_SEI = sol_long["Loss of capacity to SEI [A.h]"].entries
N_SoC = sol_long["Negative electrode SOC"].entries
P_SoC = sol_long["Positive electrode SOC"].entries
Epsilon_n_s_cycled=sol_long["X-averaged negative electrode active material volume fraction"].entries
cycle_time=sol_long.summary_variables['Time [s]']


Q_dis = -sol_long['Discharge capacity [A.h]'].entries
Vt_t = sol_long["Terminal voltage [V]"].entries
Cell_thick_3e7 = 30e6*sol_long["Cell thickness change [m]"].entries

# %%
asfas

# %%
from scipy.io import savemat

# ident=""
mdic = {
    "x100": x100, "y100":y100, "x0":x0,"y0":y0,"Cap":Cap,
        "LoC_SEI_summ":LoC_SEI_summ,
        "LAM_P":LAM_P,"LAM_N":LAM_N,"C_Neg":C_Neg,"C_pos":C_pos,
        "LLI":LLI,"cycle_num":cycle_num,
        "t":t,"LoC_SEI":LoC_SEI,"N_SoC":N_SoC,"P_SoC":P_SoC,
        "Q":Q, "I":I,    
      "Epsilon_n_s_cycled":Epsilon_n_s_cycled, "cycle_time":cycle_time,
    "Q_dis":Q_dis, "Vt_t":Vt_t, "Cell_thick_3e7":Cell_thick_3e7,
    
    
    
       }
savemat("cell04_plating.mat",mdic)

# %%
# fig = plotc2(all_sumvars_dict,all_sumvars_dict1,dfe);
# fig.savefig(fig_DIR +'fast_sim_'+cell_no+'_plating_comp.png')

# %%
# sdfsdfs

# %%
# sim_des = "impact"
# fig = plotc2(all_sumvars_dict,all_sumvars_dict1,dfe,leg1="no plating",leg2="plating");
# plt.savefig(fig_DIR +'plating_tuning_'+sim_des+'_'+cell_no+'_eSOH_comp.png')

# %%
# fgfgfgfg

# %%
dis_set = " until 3V"

experiment_cyc_comp = pybamm.Experiment(
    [
        "Discharge at "+c_rate_d+dis_set,
        "Rest for 10 sec",
        "Charge at "+c_rate_c+" until 4.2V", 
        "Hold at 4.2V until C/50",
        "Discharge at "+c_rate_d+dis_set,
    ],
)
Ns = np.insert(N[1:]-1,0,0)

# %%
def load_cycling_data(cell,eSOH_DIR,oCV_DIR,cyc_DIR,cyc_no):
    cell_no,dfe,dfe_0,dfo_0,N,N_0 = load_data(cell,eSOH_DIR,oCV_DIR)
    cycles = np.array(dfe_0['N'].astype('int'))+1
    cycles = cycles[1:-1]
    print(cell_no)
    cyc_data_raw1 = pd.read_csv(cyc_DIR+'cycling_data_cell_'+cell_no+'.csv')
    N1 = cycles[cyc_no]
    cyc_data_raw = cyc_data_raw1[ cyc_data_raw1['Cycle number'] == N1 ]
    cyc_data = cyc_data_raw.reset_index(drop=True)
    t_c1 = cyc_data['Time [s]']-cyc_data['Time [s]'][0]
    t_c1 = t_c1.values
    I_c1 = cyc_data['Current [mA]']/1000
    I_c1 = I_c1.values
    V_c1 = cyc_data['Voltage [V]']
    V_c1 = V_c1.values
    idx_I = np.where(np.sign(I_c1[:-1]) != np.sign(I_c1[1:]))[0] 
    idx_I = idx_I[idx_I>50]
    # t = t_c1[:idx_I[0]]
    # V = V_c1[:idx_I[0]]
    # I = I_c1[:idx_I[0]]
    t = t_c1
    V = V_c1
    I = I_c1
    Q = integrate.cumtrapz(I,t, initial=0)/3600 #Ah
    
    return t,V,I,Q

# %%
def cyc_comp(cyc_no,eSOH,Q_d,V_d,parameter_values):
    # dfo = dfo_0[dfo_0['N']==N[cyc_no]]
    model = spm
    Vmin = 3.0
    Vmax = 4.2
    esoh_model = pybamm.lithium_ion.ElectrodeSOH()
    esoh_sim = pybamm.Simulation(esoh_model, parameter_values=parameter_values)
    param = model.param
    Cn = eSOH["C_n"][Ns[cyc_no]]
    # print(Cn)
    Cp = eSOH["C_p"][Ns[cyc_no]]
    c_n_max = parameter_values.evaluate(param.n.prim.c_max)
    c_p_max = parameter_values.evaluate(param.p.prim.c_max)
    n_Li_init = eSOH["Total lithium in particles [mol]"][Ns[cyc_no]]
    eps_n_data = parameter_values.evaluate(Cn*3600/(param.n.L * param.n.prim.c_max * param.F* param.A_cc))
    eps_p_data = parameter_values.evaluate(Cp*3600/(param.p.L * param.p.prim.c_max * param.F* param.A_cc))

    esoh_sol = esoh_sim.solve(
        [0],
        inputs={"V_min": Vmin, "V_max": Vmax, "C_n": Cn, "C_p": Cp, "n_Li": n_Li_init},
        solver=pybamm.AlgebraicSolver(),
    )

    parameter_values.update(
        {
            "Initial concentration in negative electrode [mol.m-3]": esoh_sol[
       "x_100"
            ].data[0]
            * c_n_max,
            "Initial concentration in positive electrode [mol.m-3]": esoh_sol[
                "y_100"
            ].data[0]
            * c_p_max,
            "Negative electrode active material volume fraction": eps_n_data,
            "Positive electrode active material volume fraction": eps_p_data,
            "Initial temperature [K]": 273.15+25,
            "Ambient temperature [K]": 273.15+25,
            
        }
    )

    sim_exp = pybamm.Simulation(
        model, experiment=experiment_cyc_comp, parameter_values=parameter_values,
        solver=pybamm.CasadiSolver("safe")
    )
    sol_exp = sim_exp.solve()
    t_t = sol_exp["Time [s]"].entries
    I_t = sol_exp["Current [A]"].entries
    Q_t = -sol_exp['Discharge capacity [A.h]'].entries
    Vt_t = sol_exp["Terminal voltage [V]"].entries
    exp_t = 30e6*sol_exp["Cell thickness change [m]"].entries
    idx = np.where(np.diff(np.sign(-I_t)))[0]
    I = I_t[idx[-1]:]
    t = t_t[idx[-1]:]-t_t[idx[-1]]
    Q = Q_t[idx[-1]:]-Q_t[idx[-1]]
    Vt = Vt_t[idx[-1]:]
    exp = exp_t[idx[-1]:]-exp_t[idx[-1]]
    I = I_t[idx[0]:]
    t = t_t[idx[0]:]-t_t[idx[0]]
    Q = Q_t[idx[0]:]-Q_t[idx[0]]
    Vt = Vt_t[idx[0]:]
    exp = exp_t[idx[0]:]-exp_t[idx[0]]
    # Q_filt = ((Q/max(Q))>0.15)
    # int_V = interpolate.CubicSpline(eSOH_data['Q'],eSOH_data['V'],extrapolate=True)
    # rmse_V = pybamm.rmse(Vt*Q_filt,int_V(Q)*Q_filt)
    # V_err = Vt*Q_filt-int_V(Q)*Q_filt
    # V_max_loc = np.argmax(abs(V_err))
    # V_err_Q = Q[V_max_loc]
    # V_err_max = V_err[V_max_loc]
    # if max(Q)<max(Q_d):
    #     int_V = interpolate.CubicSpline(Q_d,V_d,extrapolate=True)
    #     rmse_V = pybamm.rmse(Vt,int_V(Q))
    #     V_err = Vt-int_V(Q)
    #     max_V = abs(V_err[-2])
    #     V_max_loc = np.argmax(abs(V_err))
    #     V_err_Q = Q[V_max_loc]
    #     V_err_max = V_err[V_max_loc]
    #     Q_err = Q
    # else:
    #     int_V = interpolate.CubicSpline(Q,Vt,extrapolate=True)
    #     rmse_V = pybamm.rmse(V_d,int_V(Q_d))
    #     V_err = int_V(Q_d)-V_d
    #     max_V = abs(V_err[-2])
    #     V_max_loc = np.argmax(abs(V_err))
    #     V_err_Q = Q_d[V_max_loc]
    #     V_err_max = V_err[V_max_loc]
    rmse_V =0
    max_v = 0
    return t,Q,Vt,exp,rmse_V,max_V

# %%
i = 0
rmse_V_lc = []
titles = ["BOL","MOL","EOL"]
fig, axes = plt.subplots(1,3,figsize=(10,3))
for cyc_no in [0,int((len(N)+1)/2),len(N)-2]:

# for cyc_no in range(0,int((len(N)+1)/2),len(N)-1):
    # cyc_no=0
    print(cyc_no)
    t_d,V_d,I_d,Q_d = load_cycling_data(cell,eSOH_DIR,oCV_DIR,cyc_DIR,cyc_no)
    parameter_values.update(
    {
        "Positive electrode LAM constant proportional term [s-1]": par_val[1][0],
        "Negative electrode LAM constant proportional term [s-1]": par_val[1][1],
        "Positive electrode LAM constant exponential term": par_val[1][2],
        "Negative electrode LAM constant exponential term": par_val[1][2],
        "Lithium plating kinetic rate constant [m.s-1]": par_val[1][3],
    },
    check_already_exists=False,
    )
    t,Q,Vt,exp,rmse_V,max_V = cyc_comp(cyc_no,all_sumvars_dict,Q_d,V_d,parameter_values)
    parameter_values.update(
    {
        "Positive electrode LAM constant proportional term [s-1]": par_val[3][0],
        "Negative electrode LAM constant proportional term [s-1]": par_val[3][1],
        "Positive electrode LAM constant exponential term": par_val[3][2],
        "Negative electrode LAM constant exponential term": par_val[3][2],
        "Lithium plating kinetic rate constant [m.s-1]": par_val[3][3],
    },
    check_already_exists=False,
    )
    t2,Q2,Vt2,exp2,rmse_V2,max_V2 = cyc_comp(cyc_no,all_sumvars_dict1,Q_d,V_d,parameter_values)
    rmse_V_lc = np.append(rmse_V_lc,rmse_V)
    # if cyc_no in [0,int((len(N)+1)/2),len(N)-3]:
    ax2 = axes.flat[i]
    # ax2.plot(Q_d,V_d,'k',linewidth=1)
    # ax2.plot(Q,Vt,'b--',linewidth=1.5)
    # ax2.plot(Q2,Vt2,'r--',linewidth=1.5)
    ax2.set_ylim([3,4.21])
    # ax2.set_xlim([0,5.1])
    # ax2.set_xlabel('Q [Ah]')
    ax2.plot(t_d,V_d,'k',linewidth=1)
    ax2.plot(t,Vt,'b--',linewidth=1.5)
    # ax2.plot(t2,Vt2,'r--',linewidth=1.5)
    
    ax2.set_xlabel('Time [s]')
    # ax2.text(0.5,0.1,f'RMSE1: {rmse_V*1e3:0.1f} mV',transform=ax2.transAxes)
    # ax2.text(0.5,0.2,f'RMSE3: {rmse_V2*1e3:0.1f} mV',transform=ax2.transAxes)
    ax2.set_title('{}'.format(titles[i]))
    # if i ==0:
    ax2.legend(["Data","Sim",])
    ax2.set_ylabel('$V_t$ [Ah]')
        # ax1.set_ylabel('$\Delta$t [$\mu$m]')
    i+=1
fig.suptitle('Cell = '+cell_no)
fig.tight_layout()
# plt.savefig(fig_DIR +'plating_tuning_'+sim_des+'_'+cell_no+'_cyc_comp_cond.png')
# Out:
# 0
# 07
# 3
# 07
# 4
# 07
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
dfgdfg

# %%
i = 0
rmse_V_lc = []
titles = ["BOL","MOL","EOL"]
fig, axes = plt.subplots(1,3,figsize=(10,3))
for cyc_no in [0,int((len(N)+1)/2),len(N)-2]:

# for cyc_no in range(0,int((len(N)+1)/2),len(N)-1):
    # cyc_no=0
    print(cyc_no)
    t_d,V_d,I_d,Q_d = load_cycling_data(cell,eSOH_DIR,oCV_DIR,cyc_DIR,cyc_no)
    parameter_values.update(
    {
        "Positive electrode LAM constant proportional term [s-1]": par_val[1][0],
        "Negative electrode LAM constant proportional term [s-1]": par_val[1][1],
        "Positive electrode LAM constant exponential term": par_val[1][2],
        "Negative electrode LAM constant exponential term": par_val[1][2],
        "Lithium plating kinetic rate constant [m.s-1]": par_val[1][3],
    },
    check_already_exists=False,
    )
    t,Q,Vt,exp,rmse_V,max_V = cyc_comp(cyc_no,all_sumvars_dict,Q_d,V_d,parameter_values)
    parameter_values.update(
    {
        "Positive electrode LAM constant proportional term [s-1]": par_val[3][0],
        "Negative electrode LAM constant proportional term [s-1]": par_val[3][1],
        "Positive electrode LAM constant exponential term": par_val[3][2],
        "Negative electrode LAM constant exponential term": par_val[3][2],
        "Lithium plating kinetic rate constant [m.s-1]": par_val[3][3],
    },
    check_already_exists=False,
    )
    t2,Q2,Vt2,exp2,rmse_V2,max_V2 = cyc_comp(cyc_no,all_sumvars_dict1,Q_d,V_d,parameter_values)
    rmse_V_lc = np.append(rmse_V_lc,rmse_V)
    # if cyc_no in [0,int((len(N)+1)/2),len(N)-3]:
    ax2 = axes.flat[i]
    ax2.plot(Q_d,V_d,'k',linewidth=1)
    ax2.plot(Q,Vt,'b--',linewidth=1.5)
    ax2.plot(Q2,Vt2,'r--',linewidth=1.5)
    ax2.set_ylim([3,4.2])
    ax2.set_xlim([0,5.1])
    ax2.set_xlabel('Q [Ah]')
    ax2.text(0.5,0.1,f'RMSE1: {rmse_V*1e3:0.1f} mV',transform=ax2.transAxes)
    ax2.text(0.5,0.2,f'RMSE3: {rmse_V2*1e3:0.1f} mV',transform=ax2.transAxes)
    ax2.set_title('{}'.format(titles[i]))
    # if i ==0:
    ax2.legend(["Data","Cond 1","Cond 3"])
    ax2.set_ylabel('$V_t$ [Ah]')
        # ax1.set_ylabel('$\Delta$t [$\mu$m]')
    i+=1
fig.suptitle('Cell = '+cell_no)
fig.tight_layout()
plt.savefig(fig_DIR +'plating_tuning_'+sim_des+'_'+cell_no+'_cyc_comp_cond.png')
# Out:
# 0
# 07
# 3
# 07
# 4
# 07
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
spm.variables.search("Resistance")
# Out:
# Local ECM resistance
# Local ECM resistance [Ohm]
# Resistance [Ohm]
# X-averaged negative electrode resistance [Ohm.m2]

# %%
fdgfdgfdgfg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\spannala\PyBaMM\gmproj\cycling_aging\plot_cycling_mech_sei.ipynb Cell 22 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/spannala/PyBaMM/gmproj/cycling_aging/plot_cycling_mech_sei.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> fdgfdgfdgfg
#
# NameError: name 'fdgfdgfdgfg' is not defined

# %%
experiment_rev_exp = pybamm.Experiment(
    [
        "Discharge at "+'C/20'+" until 3V",
        "Rest for 60 min",
        "Charge at "+'C/20'+" until 4.2V", 
        # "Hold at 4.2V until C/50"
    ],
)
Ns = np.insert(N[1:]-1,0,0)

# %%
def rev_exp(cyc_no,eSOH,eSOH_data,parameter_values):
    # dfo = dfo_0[dfo_0['N']==N[cyc_no]]
    model = spm
    Vmin = 3.0
    Vmax = 4.2
    esoh_model = pybamm.lithium_ion.ElectrodeSOH()
    esoh_sim = pybamm.Simulation(esoh_model, parameter_values=parameter_values)
    param = model.param
    Cn = eSOH["C_n"][Ns[cyc_no]]
    # print(Cn)
    Cp = eSOH["C_p"][Ns[cyc_no]]
    c_n_max = parameter_values.evaluate(param.n.prim.c_max)
    c_p_max = parameter_values.evaluate(param.p.prim.c_max)
    n_Li_init = eSOH["Total lithium in particles [mol]"][Ns[cyc_no]]
    eps_n_data = parameter_values.evaluate(Cn*3600/(param.n.L * param.n.prim.c_max * param.F* param.A_cc))
    eps_p_data = parameter_values.evaluate(Cp*3600/(param.p.L * param.p.prim.c_max * param.F* param.A_cc))

    esoh_sol = esoh_sim.solve(
        [0],
        inputs={"V_min": Vmin, "V_max": Vmax, "C_n": Cn, "C_p": Cp, "n_Li": n_Li_init},
        solver=pybamm.AlgebraicSolver(),
    )

    parameter_values.update(
        {
            "Initial concentration in negative electrode [mol.m-3]": esoh_sol[
       "x_100"
            ].data[0]
            * c_n_max,
            "Initial concentration in positive electrode [mol.m-3]": esoh_sol[
                "y_100"
            ].data[0]
            * c_p_max,
            "Negative electrode active material volume fraction": eps_n_data,
            "Positive electrode active material volume fraction": eps_p_data,
            "Initial temperature [K]": 273.15+25,
            "Ambient temperature [K]": 273.15+25,
            
        }
    )

    sim_exp = pybamm.Simulation(
        model, experiment=experiment_rev_exp, parameter_values=parameter_values,
        solver=pybamm.CasadiSolver("safe")
    )
    sol_exp = sim_exp.solve()
    t_t = sol_exp["Time [min]"].entries
    I_t = sol_exp["Current [A]"].entries
    Q_t = -sol_exp['Discharge capacity [A.h]'].entries
    Vt_t = sol_exp["Terminal voltage [V]"].entries
    exp_t = 30e6*sol_exp["Cell thickness change [m]"].entries
    idx = np.where(np.diff(np.sign(I_t)))[0]
    I = I_t[idx[-1]:]
    t = t_t[idx[-1]:]-t_t[idx[-1]]
    Q = Q_t[idx[-1]:]-Q_t[idx[-1]]
    Vt = Vt_t[idx[-1]:]
    exp = exp_t[idx[-1]:]-exp_t[idx[-1]]
    # Q_filt = ((Q/max(Q))>0.15)
    # int_V = interpolate.CubicSpline(eSOH_data['Q'],eSOH_data['V'],extrapolate=True)
    # rmse_V = pybamm.rmse(Vt*Q_filt,int_V(Q)*Q_filt)
    # V_err = Vt*Q_filt-int_V(Q)*Q_filt
    # V_max_loc = np.argmax(abs(V_err))
    # V_err_Q = Q[V_max_loc]
    # V_err_max = V_err[V_max_loc]
    if max(Q)<max(eSOH_data['Q']):
        int_V = interpolate.CubicSpline(eSOH_data['Q'],eSOH_data['V'],extrapolate=True)
        rmse_V = pybamm.rmse(Vt,int_V(Q))
        V_err = Vt-int_V(Q)
        max_V = abs(V_err[-2])
        V_max_loc = np.argmax(abs(V_err))
        V_err_Q = Q[V_max_loc]
        V_err_max = V_err[V_max_loc]
        int_E = interpolate.CubicSpline(eSOH_data['Q'],eSOH_data['E']-eSOH_data['E'].iloc[0],extrapolate=True)
        rmse_E = pybamm.rmse(exp,int_E(Q))
        E_err = exp-int_E(Q)
        max_E = abs(E_err[-2])
        E_max_loc = np.argmax(abs(E_err))
        E_err_Q = Q[E_max_loc]
        E_err_max = E_err[E_max_loc]
        Q_err = Q
    else:
        int_V = interpolate.CubicSpline(Q,Vt,extrapolate=True)
        rmse_V = pybamm.rmse(eSOH_data['V'],int_V(eSOH_data['Q']))
        V_err = int_V(eSOH_data['Q'])-eSOH_data['V']
        max_V = abs(V_err.iloc[-2])
        V_max_loc = np.argmax(abs(V_err))
        V_err_Q = eSOH_data['Q'].iloc[V_max_loc]
        V_err_max = V_err.iloc[V_max_loc]
        int_E = interpolate.CubicSpline(Q,exp,extrapolate=True)
        rmse_E = pybamm.rmse(eSOH_data['E']-eSOH_data['E'].iloc[0],int_E(eSOH_data['Q']))
        E_err = int_E(eSOH_data['Q'])-eSOH_data['E']+eSOH_data['E'].iloc[0]
        max_E = abs(E_err.iloc[-2])
        E_max_loc = np.argmax(abs(E_err))
        E_err_Q = eSOH_data['Q'].iloc[E_max_loc]
        E_err_max = E_err.iloc[E_max_loc]
        Q_err = eSOH_data['Q']
    return Q,Vt,exp,rmse_V,rmse_E,max_V,max_E

# %%
i = 0
rmse_V_l = []
rmse_E_l = []
max_V_l = []
max_E_l = []
fig, axes = plt.subplots(2,3,figsize=(10,6))
for cyc_no in [0,int((len(N)+1)/2),len(N)-1]:
# for cyc_no in range(0,int((len(N)+1)/2),len(N)-1):
    # cyc_no=0
    print(cyc_no)
    dfo = dfo_0[dfo_0['N']==N_0[cyc_no+1]]
    parameter_values.update(
    {
        "Positive electrode LAM constant proportional term [s-1]": par_val[1][0],
        "Negative electrode LAM constant proportional term [s-1]": par_val[1][1],
        "Positive electrode LAM constant exponential term": par_val[1][2],
        "Negative electrode LAM constant exponential term": par_val[1][2],
        "Lithium plating kinetic rate constant [m.s-1]": par_val[1][3],
    },
    check_already_exists=False,
    )
    Q,Vt,exp,rmse_V,rmse_E,max_V,max_E = rev_exp(cyc_no,all_sumvars_dict,dfo,parameter_values)
    parameter_values.update(
    {
        "Positive electrode LAM constant proportional term [s-1]": par_val[3][0],
        "Negative electrode LAM constant proportional term [s-1]": par_val[3][1],
        "Positive electrode LAM constant exponential term": par_val[3][2],
        "Negative electrode LAM constant exponential term": par_val[3][2],
        "Lithium plating kinetic rate constant [m.s-1]": par_val[3][3],
    },
    check_already_exists=False,
    )
    Q2,Vt2,exp2,rmse_V2,rmse_E2,max_V2,max_E2 = rev_exp(cyc_no,all_sumvars_dict1,dfo,parameter_values)
    rmse_V_l = np.append(rmse_V_l,rmse_V)
    rmse_E_l = np.append(rmse_E_l,rmse_E)
    max_V_l = np.append(max_V_l,max_V)
    max_E_l = np.append(max_E_l,max_E)
    # if cyc_no in [0,int((len(N)+1)/2),len(N)-3]:
    ax1 = axes.flat[i]
    ax1.plot(dfo['Q'],dfo['E']-dfo['E'].iloc[0],'k',linewidth=1)
    ax1.plot(Q,exp,'b--',linewidth=1.5)
    ax1.plot(Q2,exp2,'r--',linewidth=1.5)
    ax1.set_ylim([0,110])
    ax1.set_xlim([0,5.1])
    ax1.set_xticklabels([])
    ax1.set_title('N = {}'.format(N[cyc_no]))
    ax1.text(0.1,0.9,f'RMSE: {rmse_E:0.1f} $\mu$m',transform=ax1.transAxes)
    ax2 = axes.flat[i+3]
    ax2.plot(dfo['Q'],dfo['V'],'k',linewidth=1)
    ax2.plot(Q,Vt,'b--',linewidth=1.5)
    ax2.plot(Q2,Vt2,'r--',linewidth=1.5)
    ax2.set_ylim([3,4.2])
    ax2.set_xlim([0,5.1])
    ax2.set_xlabel('Q [Ah]')
    ax2.text(0.5,0.1,f'RMSE1: {rmse_V*1e3:0.1f} mV',transform=ax2.transAxes)
    ax2.text(0.5,0.2,f'RMSE3: {rmse_V2*1e3:0.1f} mV',transform=ax2.transAxes)
    if i ==0:
        ax2.set_ylabel('$V_t$ [Ah]')
        ax1.set_ylabel('$\Delta$t [$\mu$m]')
    i+=1
fig.suptitle('Cell = '+cell_no)
fig.tight_layout()
plt.savefig(fig_DIR +'plating_tuning_'+sim_des+'_'+cell_no+'_cond.png')

# %%
print(np.round(rmse_V_l*1000,1))
print(np.round(rmse_V_lc*1000,1))
err_c20 = np.round(rmse_V_l*1000,1)
err_cyc = np.round(rmse_V_lc*1000,1)

# %%
col_names = ["cell","cond","c20_BOL","c20_MOL","c20_EOL","cyc_BOL","cyc_MOL","cyc_EOL"]
df_x = pd.DataFrame(columns=col_names, index=range(1))
df_x["cell"]=cell
df_x["cond"]=sno
df_x["c20_BOL"]=err_c20[0]
df_x["c20_MOL"]=err_c20[1]
df_x["c20_EOL"]=err_c20[2]
df_x["cyc_BOL"]=err_cyc[0]
df_x["cyc_MOL"]=err_cyc[1]
df_x["cyc_EOL"]=err_cyc[2]

# %%
df_x.to_csv("errors.csv", mode='a', index=False, header=False)

# %%
winsound.Beep(440, 2000)

# %%
xcxzx

# %%
def diff_analysis(cyc_no,eSOH,eSOH_data):
    model = spm
    Vmin = 3.0
    Vmax = 4.2
    esoh_model = pybamm.lithium_ion.ElectrodeSOH()
    esoh_sim = pybamm.Simulation(esoh_model, parameter_values=parameter_values)
    param = model.param
    Cn = eSOH["C_n"][Ns[cyc_no]]
    # print(Cn)
    Cp = eSOH["C_p"][Ns[cyc_no]]
    c_n_max = parameter_values.evaluate(param.n.prim.c_max)
    c_p_max = parameter_values.evaluate(param.p.prim.c_max)
    n_Li_init = eSOH["Total lithium in particles [mol]"][Ns[cyc_no]]
    eps_n_data = parameter_values.evaluate(Cn*3600/(param.n.L * param.n.prim.c_max * param.F* param.A_cc))
    eps_p_data = parameter_values.evaluate(Cp*3600/(param.p.L * param.p.prim.c_max * param.F* param.A_cc))

    esoh_sol = esoh_sim.solve(
        [0],
        inputs={"V_min": Vmin, "V_max": Vmax, "C_n": Cn, "C_p": Cp, "n_Li": n_Li_init},
        solver=pybamm.AlgebraicSolver(),
    )

    parameter_values.update(
        {
            "Initial concentration in negative electrode [mol.m-3]": esoh_sol[
       "x_100"
            ].data[0]
            * c_n_max,
            "Initial concentration in positive electrode [mol.m-3]": esoh_sol[
                "y_100"
            ].data[0]
            * c_p_max,
            "Negative electrode active material volume fraction": eps_n_data,
            "Positive electrode active material volume fraction": eps_p_data,
            "Initial temperature [K]": 273.15+25,
            "Ambient temperature [K]": 273.15+25,
            
        }
    )

    sim_exp = pybamm.Simulation(
        model, experiment=experiment_rev_exp, parameter_values=parameter_values,
        solver=pybamm.CasadiSolver("safe")
    )
    sol_exp = sim_exp.solve()
    t_t = sol_exp["Time [min]"].entries
    I_t = sol_exp["Current [A]"].entries
    Q_t = -sol_exp['Discharge capacity [A.h]'].entries
    Vt_t = sol_exp["Terminal voltage [V]"].entries
    exp_t = 30e6*sol_exp["Cell thickness change [m]"].entries
    idx = np.where(np.diff(np.sign(I_t)))[0]
    I = I_t[idx[-1]:]
    t = t_t[idx[-1]:]-t_t[idx[-1]]
    Q = Q_t[idx[-1]:]-Q_t[idx[-1]]
    Vt = Vt_t[idx[-1]:]
    exp = exp_t[idx[-1]:]-exp_t[idx[-1]]

    window_length=501
    polyorder=5
    Qf_d = savgol_filter(eSOH_data['Q'],window_length,polyorder)
    dQ_d = savgol_filter(eSOH_data['Q'],window_length,polyorder,1)
    Vf_d = savgol_filter(eSOH_data['V'],window_length,polyorder)
    dV_d = savgol_filter(eSOH_data['V'],window_length,polyorder,1)
    window_length=1701
    polyorder=3
    Ef_d = savgol_filter(eSOH_data['E']-eSOH_data['E'].iloc[0],window_length,polyorder)
    dE2_d = savgol_filter(Ef_d,window_length,polyorder,2)
    window_length=51
    polyorder=5
    Qf_s = savgol_filter(Q,window_length,polyorder)
    dQ_s = savgol_filter(Q,window_length,polyorder,1)
    Vf_s = savgol_filter(Vt,window_length,polyorder)
    dV_s = savgol_filter(Vt,window_length,polyorder,1)
    window_length=301
    polyorder=3
    Ef_s = savgol_filter(exp,window_length,polyorder)
    dE2_s = savgol_filter(exp,window_length,polyorder,2)
    dE2_s = savgol_filter(Ef_s,window_length,polyorder,2)

    dVdQ_d = dV_d/dQ_d
    dVdQf_d = dVdQ_d*(Qf_d/max(Qf_d)<0.8)
    dV_peaks_d,_ = find_peaks(dVdQf_d,height=0.16,width=0.1,prominence=0.0005)
    dV_peaks_d = dV_peaks_d[-3:]
    dV_peaks_d = dV_peaks_d[:-1]
    dVdQ_s = dV_s/dQ_s
    dVdQf_s = dVdQ_s*(dVdQ_s>0.16)
    dV_peaks_s,_ = find_peaks(dVdQf_s,height=0.1,width=0.1,prominence=0.01)
    dV_peaks_s = dV_peaks_s[-2:]  

    dQdV_d = dQ_d/dV_d
    dQdV_s = dQ_s/dV_s

    dEdQ2_d = dE2_d/dQ_d/dQ_d
    dEdQ2_s = dE2_s/dQ_s/dQ_s

    dEdQf2_d = dEdQ2_d*(dEdQ2_d>10)
    dE_peaks_d,_ = find_peaks(dEdQf2_d,height=0.1,width=0.1,prominence=0.2)
    dEdQf2_s = dEdQ2_s*(dEdQ2_s>10)
    dE_peaks_s,_ = find_peaks(dEdQf2_s,height=0.1,width=0.1,prominence=0.2)
    loc_d = np.where(np.diff(np.sign(dEdQ2_d[0:dE_peaks_d[0]])))[0]
    dE_zero_d = loc_d[-1]
    loc_s = np.where(np.diff(np.sign(dEdQ2_s[0:dE_peaks_s[0]])))[0]
    dE_zero_s = loc_s[-1]


    dQdVf_d = dQdV_d*(dQdV_d>8)
    dQ_peaks_d,_ = find_peaks(dQdVf_d,height=0.1,width=0.1,prominence=0.2)
    dQdVf_s = dQdV_s*(dQdV_s>8)
    dQ_peaks_s,_ = find_peaks(dQdVf_s,height=0.1,width=0.1,prominence=0.2)

    plt.figure(figsize=[10,8])
    ax2 = plt.subplot(1,1,1)
    ax2.plot(Qf_d,dVdQ_d,'k')
    ax2.plot(Qf_d[dV_peaks_d],dVdQ_d[dV_peaks_d],'mx')
    ax2.plot(Qf_s,dVdQ_s,'r--')
    ax2.plot(Qf_s[dV_peaks_s],dVdQ_s[dV_peaks_s],'bx')
    peak1_err = (Qf_s[dV_peaks_s[0]]/Qf_s[-1])-(Qf_d[dV_peaks_d[0]]/Qf_d[-1])
    ax2.text(0.2,0.8,f'Peak 1 Err: {peak1_err:0.4f}',transform=ax2.transAxes)
    peak2_err = (Qf_s[dV_peaks_s[1]]/Qf_s[-1])-(Qf_d[dV_peaks_d[1]]/Qf_d[-1])
    ax2.text(0.6,0.8,f'Peak 2 Err: {peak2_err:0.4f}',transform=ax2.transAxes)
    ax2.set_title('dVdQ')
    ax2.set_ylabel('Differential Voltage [V/Ah]')
    ax2.set_ylim([0,0.5])
    ax2.set_xlim(left=0)
    ax2.set_xlim([0,5])
    ax2.axvline(x=Qf_d[dV_peaks_d[-2]],color='k', linestyle='--',linewidth=0.5,clip_on=False,ymin=0,ymax=1)
    ax2.axvline(x=Qf_d[dV_peaks_d[-1]],color='k', linestyle='--',linewidth=0.5,clip_on=False,ymin=0,ymax=1)
    ax2.axvline(x=Qf_s[dV_peaks_s[0]],color='r', linestyle='--',linewidth=0.5,clip_on=False,ymin=0,ymax=1)
    ax2.axvline(x=Qf_s[dV_peaks_s[1]],color='r', linestyle='--',linewidth=0.5,clip_on=False,ymin=0,ymax=1)
    plt.suptitle('Cell: '+cell_no+' Cycle No: '+str(N[cyc_no]))
    plt.tight_layout()
    plt.savefig(fig_DIR +'deg_sim_'+cell_no+'_cyc_'+str(N[cyc_no]))
    return plt

# %%
# i = 0
# for cyc_no in [0,int((len(N)+1)/2),len(N)-1]:
# # for cyc_no in [len(N)-1]:
#     # cyc_no=0
#     print(cyc_no)
#     dfo = dfo_0[dfo_0['N']==N_0[cyc_no+1]]
#     plt = diff_analysis(cyc_no,all_sumvars_dict,dfo)
#     # plt.close()

# %%
def diff_analysis_2(cyc_no,eSOH,eSOH_data):
    model = spm
    Vmin = 3.0
    Vmax = 4.2
    esoh_model = pybamm.lithium_ion.ElectrodeSOH()
    esoh_sim = pybamm.Simulation(esoh_model, parameter_values=parameter_values)
    param = model.param
    Cn = eSOH["C_n"][cyc_no]
    # print(Cn)
    Cp = eSOH["C_p"][cyc_no]
    c_n_max = parameter_values.evaluate(param.n.prim.c_max)
    c_p_max = parameter_values.evaluate(param.p.prim.c_max)
    n_Li_init = eSOH["n_Li"][cyc_no]
    eps_n_data = parameter_values.evaluate(Cn*3600/(param.n.L * param.n.prim.c_max * param.F* param.A_cc))
    eps_p_data = parameter_values.evaluate(Cp*3600/(param.p.L * param.p.prim.c_max * param.F* param.A_cc))

    esoh_sol = esoh_sim.solve(
        [0],
        inputs={"V_min": Vmin, "V_max": Vmax, "C_n": Cn, "C_p": Cp, "n_Li": n_Li_init},
        solver=pybamm.AlgebraicSolver(),
    )

    parameter_values.update(
        {
            "Initial concentration in negative electrode [mol.m-3]": esoh_sol[
       "x_100"
            ].data[0]
            * c_n_max,
            "Initial concentration in positive electrode [mol.m-3]": esoh_sol[
                "y_100"
            ].data[0]
            * c_p_max,
            "Negative electrode active material volume fraction": eps_n_data,
            "Positive electrode active material volume fraction": eps_p_data,
            "Initial temperature [K]": 273.15+25,
            "Ambient temperature [K]": 273.15+25,
            
        }
    )

    sim_exp = pybamm.Simulation(
        model, experiment=experiment_rev_exp, parameter_values=parameter_values,
        solver=pybamm.CasadiSolver("safe")
    )
    sol_exp = sim_exp.solve()
    t_t = sol_exp["Time [min]"].entries
    I_t = sol_exp["Current [A]"].entries
    Q_t = -sol_exp['Discharge capacity [A.h]'].entries
    Vt_t = sol_exp["Terminal voltage [V]"].entries
    exp_t = 30e6*sol_exp["Cell thickness change [m]"].entries
    idx = np.where(np.diff(np.sign(I_t)))[0]
    I = I_t[idx[-1]:]
    t = t_t[idx[-1]:]-t_t[idx[-1]]
    Q = Q_t[idx[-1]:]-Q_t[idx[-1]]
    Vt = Vt_t[idx[-1]:]
    exp = exp_t[idx[-1]:]-exp_t[idx[-1]]

    window_length=501
    polyorder=5
    Qf_d = savgol_filter(eSOH_data['Q'],window_length,polyorder)
    dQ_d = savgol_filter(eSOH_data['Q'],window_length,polyorder,1)
    Vf_d = savgol_filter(eSOH_data['V'],window_length,polyorder)
    dV_d = savgol_filter(eSOH_data['V'],window_length,polyorder,1)
    window_length=1701
    polyorder=3
    Ef_d = savgol_filter(eSOH_data['E']-eSOH_data['E'].iloc[0],window_length,polyorder)
    dE2_d = savgol_filter(Ef_d,window_length,polyorder,2)
    window_length=51
    polyorder=5
    Qf_s = savgol_filter(Q,window_length,polyorder)
    dQ_s = savgol_filter(Q,window_length,polyorder,1)
    Vf_s = savgol_filter(Vt,window_length,polyorder)
    dV_s = savgol_filter(Vt,window_length,polyorder,1)
    window_length=301
    polyorder=3
    Ef_s = savgol_filter(exp,window_length,polyorder)
    dE2_s = savgol_filter(exp,window_length,polyorder,2)
    dE2_s = savgol_filter(Ef_s,window_length,polyorder,2)

    dVdQ_d = dV_d/dQ_d
    dVdQf_d = dVdQ_d*(Qf_d/max(Qf_d)<0.8)
    dV_peaks_d,_ = find_peaks(dVdQf_d,height=0.16,width=0.1,prominence=0.0005)
    dV_peaks_d = dV_peaks_d[-3:]
    dV_peaks_d = dV_peaks_d[:-1]
    dVdQ_s = dV_s/dQ_s
    dVdQf_s = dVdQ_s*(dVdQ_s>0.16)
    dV_peaks_s,_ = find_peaks(dVdQf_s,height=0.1,width=0.1,prominence=0.01)
    dV_peaks_s = dV_peaks_s[-2:]  

    dQdV_d = dQ_d/dV_d
    dQdV_s = dQ_s/dV_s

    dEdQ2_d = dE2_d/dQ_d/dQ_d
    dEdQ2_s = dE2_s/dQ_s/dQ_s

    dEdQf2_d = dEdQ2_d*(dEdQ2_d>10)
    dE_peaks_d,_ = find_peaks(dEdQf2_d,height=0.1,width=0.1,prominence=0.2)
    dEdQf2_s = dEdQ2_s*(dEdQ2_s>10)
    dE_peaks_s,_ = find_peaks(dEdQf2_s,height=0.1,width=0.1,prominence=0.2)
    loc_d = np.where(np.diff(np.sign(dEdQ2_d[0:dE_peaks_d[0]])))[0]
    dE_zero_d = loc_d[-1]
    loc_s = np.where(np.diff(np.sign(dEdQ2_s[0:dE_peaks_s[0]])))[0]
    dE_zero_s = loc_s[-1]


    dQdVf_d = dQdV_d*(dQdV_d>8)
    dQ_peaks_d,_ = find_peaks(dQdVf_d,height=0.1,width=0.1,prominence=0.2)
    dQdVf_s = dQdV_s*(dQdV_s>8)
    dQ_peaks_s,_ = find_peaks(dQdVf_s,height=0.1,width=0.1,prominence=0.2)

    plt.figure(figsize=[5,4])
    ax2 = plt.subplot(1,1,1)
    ax2.plot(Qf_d,dVdQ_d,'k')
    ax2.plot(Qf_d[dV_peaks_d],dVdQ_d[dV_peaks_d],'mx')
    ax2.plot(Qf_s,dVdQ_s,'r--')
    ax2.plot(Qf_s[dV_peaks_s],dVdQ_s[dV_peaks_s],'bx')
    peak1_err = (Qf_s[dV_peaks_s[0]]/Qf_s[-1])-(Qf_d[dV_peaks_d[0]]/Qf_d[-1])
    ax2.text(0.2,0.8,f'Peak 1 Err: {peak1_err:0.4f}',transform=ax2.transAxes)
    peak2_err = (Qf_s[dV_peaks_s[1]]/Qf_s[-1])-(Qf_d[dV_peaks_d[1]]/Qf_d[-1])
    ax2.text(0.6,0.8,f'Peak 2 Err: {peak2_err:0.4f}',transform=ax2.transAxes)
    ax2.set_title('dVdQ')
    ax2.set_ylabel('Differential Voltage [V/Ah]')
    ax2.set_ylim([0,0.5])
    ax2.set_xlim(left=0)
    ax2.set_xlim([0,5])
    ax2.axvline(x=Qf_d[dV_peaks_d[-2]],color='k', linestyle='--',linewidth=0.5,clip_on=False,ymin=0,ymax=1)
    ax2.axvline(x=Qf_d[dV_peaks_d[-1]],color='k', linestyle='--',linewidth=0.5,clip_on=False,ymin=0,ymax=1)
    ax2.axvline(x=Qf_s[dV_peaks_s[0]],color='r', linestyle='--',linewidth=0.5,clip_on=False,ymin=0,ymax=1)
    ax2.axvline(x=Qf_s[dV_peaks_s[1]],color='r', linestyle='--',linewidth=0.5,clip_on=False,ymin=0,ymax=1)
    plt.suptitle('Cell: '+cell_no+' Cycle No: '+str(N[cyc_no]))
    plt.tight_layout()
    plt.savefig(fig_DIR +'deg_sim_data_'+cell_no+'_cyc_'+str(N[cyc_no]))
    return plt

# %%
i = 0
for cyc_no in [0,int((len(N)+1)/2),len(N)-1]:
# for cyc_no in [len(N)-1]:
    # cyc_no=0
    print(cyc_no)
    dfo = dfo_0[dfo_0['N']==N_0[cyc_no+1]]
    plt = diff_analysis_2(cyc_no,dfe,dfo)
    # plt.close()

# %%
def rev_exp_2(cyc_no,eSOH,eSOH_data):
    # dfo = dfo_0[dfo_0['N']==N[cyc_no]]
    model = spm
    Vmin = 3.0
    Vmax = 4.2
    esoh_model = pybamm.lithium_ion.ElectrodeSOH()
    esoh_sim = pybamm.Simulation(esoh_model, parameter_values=parameter_values)
    param = model.param
    Cn = eSOH["C_n"][cyc_no]
    # print(Cn)
    Cp = eSOH["C_p"][cyc_no]
    c_n_max = parameter_values.evaluate(param.n.prim.c_max)
    c_p_max = parameter_values.evaluate(param.p.prim.c_max)
    n_Li_init = eSOH["n_Li"][cyc_no]
    eps_n_data = parameter_values.evaluate(Cn*3600/(param.n.L * param.n.prim.c_max * param.F* param.A_cc))
    eps_p_data = parameter_values.evaluate(Cp*3600/(param.p.L * param.p.prim.c_max * param.F* param.A_cc))

    esoh_sol = esoh_sim.solve(
        [0],
        inputs={"V_min": Vmin, "V_max": Vmax, "C_n": Cn, "C_p": Cp, "n_Li": n_Li_init},
        solver=pybamm.AlgebraicSolver(),
    )

    parameter_values.update(
        {
            "Initial concentration in negative electrode [mol.m-3]": esoh_sol[
       "x_100"
            ].data[0]
            * c_n_max,
            "Initial concentration in positive electrode [mol.m-3]": esoh_sol[
                "y_100"
            ].data[0]
            * c_p_max,
            "Negative electrode active material volume fraction": eps_n_data,
            "Positive electrode active material volume fraction": eps_p_data,
            "Initial temperature [K]": 273.15+25,
            "Ambient temperature [K]": 273.15+25,
            
        }
    )

    sim_exp = pybamm.Simulation(
        model, experiment=experiment_rev_exp, parameter_values=parameter_values,
        solver=pybamm.CasadiSolver("safe")
    )
    sol_exp = sim_exp.solve()
    t_t = sol_exp["Time [min]"].entries
    I_t = sol_exp["Current [A]"].entries
    Q_t = -sol_exp['Discharge capacity [A.h]'].entries
    Vt_t = sol_exp["Terminal voltage [V]"].entries
    exp_t = 30e6*sol_exp["Cell thickness change [m]"].entries
    idx = np.where(np.diff(np.sign(I_t)))[0]
    I = I_t[idx[-1]:]
    t = t_t[idx[-1]:]-t_t[idx[-1]]
    Q = Q_t[idx[-1]:]-Q_t[idx[-1]]
    Vt = Vt_t[idx[-1]:]
    exp = exp_t[idx[-1]:]-exp_t[idx[-1]]
    # Q_filt = ((Q/max(Q))>0.15)
    # int_V = interpolate.CubicSpline(eSOH_data['Q'],eSOH_data['V'],extrapolate=True)
    # rmse_V = pybamm.rmse(Vt*Q_filt,int_V(Q)*Q_filt)
    # V_err = Vt*Q_filt-int_V(Q)*Q_filt
    # V_max_loc = np.argmax(abs(V_err))
    # V_err_Q = Q[V_max_loc]
    # V_err_max = V_err[V_max_loc]
    if max(Q)<max(eSOH_data['Q']):
        int_V = interpolate.CubicSpline(eSOH_data['Q'],eSOH_data['V'],extrapolate=True)
        rmse_V = pybamm.rmse(Vt,int_V(Q))
        V_err = Vt-int_V(Q)
        max_V = abs(V_err[-2])
        V_max_loc = np.argmax(abs(V_err))
        V_err_Q = Q[V_max_loc]
        V_err_max = V_err[V_max_loc]
        int_E = interpolate.CubicSpline(eSOH_data['Q'],eSOH_data['E']-eSOH_data['E'].iloc[0],extrapolate=True)
        rmse_E = pybamm.rmse(exp,int_E(Q))
        E_err = exp-int_E(Q)
        max_E = abs(E_err[-2])
        E_max_loc = np.argmax(abs(E_err))
        E_err_Q = Q[E_max_loc]
        E_err_max = E_err[E_max_loc]
        Q_err = Q
    else:
        int_V = interpolate.CubicSpline(Q,Vt,extrapolate=True)
        rmse_V = pybamm.rmse(eSOH_data['V'],int_V(eSOH_data['Q']))
        V_err = int_V(eSOH_data['Q'])-eSOH_data['V']
        max_V = abs(V_err.iloc[-2])
        V_max_loc = np.argmax(abs(V_err))
        V_err_Q = eSOH_data['Q'].iloc[V_max_loc]
        V_err_max = V_err.iloc[V_max_loc]
        int_E = interpolate.CubicSpline(Q,exp,extrapolate=True)
        rmse_E = pybamm.rmse(eSOH_data['E']-eSOH_data['E'].iloc[0],int_E(eSOH_data['Q']))
        E_err = int_E(eSOH_data['Q'])-eSOH_data['E']+eSOH_data['E'].iloc[0]
        max_E = abs(E_err.iloc[-2])
        E_max_loc = np.argmax(abs(E_err))
        E_err_Q = eSOH_data['Q'].iloc[E_max_loc]
        E_err_max = E_err.iloc[E_max_loc]
        Q_err = eSOH_data['Q']
    return Q,Vt,exp,rmse_V,rmse_E,max_V,max_E

# %%
i = 0
rmse_V_l = []
rmse_E_l = []
max_V_l = []
max_E_l = []
fig, axes = plt.subplots(2,3,figsize=(10,6))
for cyc_no in [0,int((len(N)+1)/2),len(N)-1]:
# for cyc_no in range(0,int((len(N)+1)/2),len(N)-1):
    # cyc_no=0
    print(cyc_no)
    dfo = dfo_0[dfo_0['N']==N_0[cyc_no+1]]
    Q,Vt,exp,rmse_V,rmse_E,max_V,max_E = rev_exp_2(cyc_no,dfe,dfo)
    rmse_V_l = np.append(rmse_V_l,rmse_V)
    rmse_E_l = np.append(rmse_E_l,rmse_E)
    max_V_l = np.append(max_V_l,max_V)
    max_E_l = np.append(max_E_l,max_E)
    # if cyc_no in [0,int((len(N)+1)/2),len(N)-3]:
    ax1 = axes.flat[i]
    ax1.plot(dfo['Q'],dfo['E']-dfo['E'].iloc[0],'k',linewidth=1)
    ax1.plot(Q,exp,'b--',linewidth=1.5)
    ax1.set_ylim([0,110])
    ax1.set_xlim([0,5.1])
    ax1.set_xticklabels([])
    ax1.set_title('N = {}'.format(N[cyc_no]))
    ax1.text(0.1,0.9,f'RMSE: {rmse_E:0.1f} $\mu$m',transform=ax1.transAxes)
    ax2 = axes.flat[i+3]
    ax2.plot(dfo['Q'],dfo['V'],'k',linewidth=1)
    ax2.plot(Q,Vt,'b--',linewidth=1.5)
    ax2.set_ylim([3,4.2])
    ax2.set_xlim([0,5.1])
    ax2.set_xlabel('Q [Ah]')
    ax2.text(0.5,0.1,f'RMSE: {rmse_V*1e3:0.1f} mV',transform=ax2.transAxes)
    if i ==0:
        ax2.set_ylabel('$V_t$ [Ah]')
        ax1.set_ylabel('$\Delta$t [$\mu$m]')
    i+=1
fig.suptitle('Cell = '+cell_no)
fig.tight_layout()
plt.savefig(fig_DIR +'volt_exp_data_'+cell_no+'_CLi.png')

# %%
import pybamm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
import dfols
import signal
from scipy.integrate import solve_ivp
from scipy.fft import fft, fftfreq, fftshift
from scipy.signal import savgol_filter
from scipy.signal import find_peaks
from scipy import interpolate, integrate
from stopit import threading_timeoutable as timeoutable
import os, sys
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath("__file__"))))
from batfuns import *
plt.rcParams = set_rc_params(plt.rcParams)
import winsound

eSOH_DIR = "../data/esoh/"
oCV_DIR = "../data/ocv/"
cyc_DIR = "../data/cycling/"
fig_DIR = "../figures/figures_fit/"
res_DIR = "../data/results_fit/"
# %matplotlib widget

parameter_values = get_parameter_values()

spm = pybamm.lithium_ion.SPM(
    {
        "SEI": "ec reaction limited",
        "loss of active material": "stress-driven",
        "lithium plating": "irreversible",
    }
)
# spm.print_parameter_info()
param=spm.param

cell = 4
sno = 1
sim_des = f'cond{sno}'

cell_no,dfe,dfe_0,dfo_0,N,N_0 = load_data(cell,eSOH_DIR,oCV_DIR)
eps_n_data,eps_p_data,c_rate_c,c_rate_d,dis_set,Temp,SOC_0 = init_exp(cell_no,dfe,spm,parameter_values)
print(Temp)

pybamm.set_logging_level("WARNING")
# pybamm.set_logging_level("NOTICE")
experiment = pybamm.Experiment(
    [
        ("Discharge at "+c_rate_d+dis_set,
         "Rest for 5 min",
         "Charge at "+c_rate_c+" until 4.2V", 
         "Hold at 4.2V until C/50")
    ] *dfe.N.iloc[-1],
    # ] *40,
    termination="50% capacity",
#     cccv_handling="ode",
)

par_val = {}
# Previous i.e. tuning mech sim sep and then Li plating
par_val[0]=[1.2715e-07,1.2727e-06,1.1992,1.353e-9]
# Using only C/5 and 1.5C Cycling aging, cost function with Cn,Cp,x100,y0
par_val[1]=[1.4819e-07,1.5114e-06,1.2484,1.4732e-09]
# Using only C/5 and 1.5C Cycling aging, cost function with Cn,Cp,C,LLI(%)
par_val[2]=[1.4493e-07,1.3608e-06,1.199,1.2138e-09]
# Using C/5, 1.5C and mixed c-rate (Ch:C/5, Dh:1.5C) Cycling aging, cost function with Cn,Cp,x100,y0
par_val[3]=[1.043e-07,1.036e-06,1.208,1.6045e-09]
# Using C/5, 1.5C and mixed c-rate (Ch:C/5, Dh:1.5C) Cycling aging, cost function with Cn,Cp,C,LLI(%)
par_val[4]=[8.755e-08,8.572e-07,1.135,1.5788e-09]
# Using C/5, 1.5C and mixed c-rate (Ch:C/5, Dh:1.5C) Cycling aging, cost function with Cn,Cp,C,LLI(%) another initial condition
par_val[5]=[8.7698e-08,8.5848e-07,1.1354,1.5778e-09]

parameter_values = get_parameter_values()
parameter_values.update(
    {
        "Negative electrode active material volume fraction": eps_n_data,
        "Positive electrode active material volume fraction": eps_p_data,
        "Initial temperature [K]": 273.15+Temp,
        "Ambient temperature [K]": 273.15+Temp,
        "Positive electrode LAM constant proportional term [s-1]": par_val[sno][0],
        "Negative electrode LAM constant proportional term [s-1]": par_val[sno][1],
        "Positive electrode LAM constant exponential term": par_val[sno][2],
        "Negative electrode LAM constant exponential term": par_val[sno][2],
        "SEI kinetic rate constant [m.s-1]":  4.60788219e-16, #1.08494281e-16 , 
        "EC diffusivity [m2.s-1]": 4.56607447e-19,#8.30909086e-19,
        "SEI growth activation energy [J.mol-1]": 1.87422275e+04,#1.58777981e+04,
        "Lithium plating kinetic rate constant [m.s-1]": par_val[sno][3],
        # "SEI kinetic rate constant [m.s-1]": 1.6827e-16,
        # "EC diffusivity [m2.s-1]": 2e-18,
        # "SEI growth activation energy [J.mol-1]": 0,
    },
    check_already_exists=False,
)


all_sumvars_dict = cycle_adaptive_simulation(spm, parameter_values, experiment,SOC_0, save_at_cycles=1)

# fig = plotc(all_suplt.savefig(fig_DIR +'plating_tuning_'+sim_des+'_'+cell_no+'_eSOH.png')mvars_dict,dfe);


# sno = 1
# parameter_values.update(
#     {
#         "Positive electrode LAM constant proportional term [s-1]": par_val[sno][0],
#         "Negative electrode LAM constant proportional term [s-1]": par_val[sno][1],
#         "Positive electrode LAM constant exponential term": par_val[sno][2],
#         "Negative electrode LAM constant exponential term": par_val[sno][2],
#         "Lithium plating kinetic rate constant [m.s-1]": par_val[sno][3],
#     },
#     check_already_exists=False,
# )


# all_sumvars_dict1 = cycle_adaptive_simulation(spm, parameter_values, experiment,SOC_0, save_at_cycles=1)

# fig = plotc2(all_sumvars_dict,all_sumvars_dict1,dfe);
# fig.savefig(fig_DIR +'fast_sim_'+cell_no+'_plating_comp.png')

# sdfsdfs

# sim_des = "impact"
# fig = plotc2(all_sumvars_dict,all_sumvars_dict1,dfe,leg1="no plating",leg2="plating");
# plt.savefig(fig_DIR +'plating_tuning_'+sim_des+'_'+cell_no+'_eSOH_comp.png')

# fgfgfgfg

dis_set = " until 3V"

experiment_cyc_comp = pybamm.Experiment(
    [
        "Discharge at "+c_rate_d+dis_set,
        "Rest for 10 sec",
        "Charge at "+c_rate_c+" until 4.2V", 
        "Hold at 4.2V until C/50",
        "Discharge at "+c_rate_d+dis_set,
    ],
)
Ns = np.insert(N[1:]-1,0,0)

def load_cycling_data(cell,eSOH_DIR,oCV_DIR,cyc_DIR,cyc_no):
    cell_no,dfe,dfe_0,dfo_0,N,N_0 = load_data(cell,eSOH_DIR,oCV_DIR)
    cycles = np.array(dfe_0['N'].astype('int'))+1
    cycles = cycles[1:-1]
    print(cell_no)
    cyc_data_raw1 = pd.read_csv(cyc_DIR+'cycling_data_cell_'+cell_no+'.csv')
    N1 = cycles[cyc_no]
    cyc_data_raw = cyc_data_raw1[ cyc_data_raw1['Cycle number'] == N1 ]
    cyc_data = cyc_data_raw.reset_index(drop=True)
    t_c1 = cyc_data['Time [s]']-cyc_data['Time [s]'][0]
    t_c1 = t_c1.values
    I_c1 = cyc_data['Current [mA]']/1000
    I_c1 = I_c1.values
    V_c1 = cyc_data['Voltage [V]']
    V_c1 = V_c1.values
    idx_I = np.where(np.sign(I_c1[:-1]) != np.sign(I_c1[1:]))[0] 
    idx_I = idx_I[idx_I>50]
    # t = t_c1[:idx_I[0]]
    # V = V_c1[:idx_I[0]]
    # I = I_c1[:idx_I[0]]
    t = t_c1
    V = V_c1
    I = I_c1
    Q = integrate.cumtrapz(I,t, initial=0)/3600 #Ah
    
    return t,V,I,Q


def cyc_comp(cyc_no,eSOH,Q_d,V_d,parameter_values):
    # dfo = dfo_0[dfo_0['N']==N[cyc_no]]
    model = spm
    Vmin = 3.0
    Vmax = 4.2
    esoh_model = pybamm.lithium_ion.ElectrodeSOH()
    esoh_sim = pybamm.Simulation(esoh_model, parameter_values=parameter_values)
    param = model.param
    Cn = eSOH["C_n"][Ns[cyc_no]]
    # print(Cn)
    Cp = eSOH["C_p"][Ns[cyc_no]]
    c_n_max = parameter_values.evaluate(param.n.prim.c_max)
    c_p_max = parameter_values.evaluate(param.p.prim.c_max)
    n_Li_init = eSOH["Total lithium in particles [mol]"][Ns[cyc_no]]
    eps_n_data = parameter_values.evaluate(Cn*3600/(param.n.L * param.n.prim.c_max * param.F* param.A_cc))
    eps_p_data = parameter_values.evaluate(Cp*3600/(param.p.L * param.p.prim.c_max * param.F* param.A_cc))

    esoh_sol = esoh_sim.solve(
        [0],
        inputs={"V_min": Vmin, "V_max": Vmax, "C_n": Cn, "C_p": Cp, "n_Li": n_Li_init},
        solver=pybamm.AlgebraicSolver(),
    )

    parameter_values.update(
        {
            "Initial concentration in negative electrode [mol.m-3]": esoh_sol[
       "x_100"
            ].data[0]
            * c_n_max,
            "Initial concentration in positive electrode [mol.m-3]": esoh_sol[
                "y_100"
            ].data[0]
            * c_p_max,
            "Negative electrode active material volume fraction": eps_n_data,
            "Positive electrode active material volume fraction": eps_p_data,
            "Initial temperature [K]": 273.15+25,
            "Ambient temperature [K]": 273.15+25,
            
        }
    )

    sim_exp = pybamm.Simulation(
        model, experiment=experiment_cyc_comp, parameter_values=parameter_values,
        solver=pybamm.CasadiSolver("safe")
    )
    sol_exp = sim_exp.solve()
    t_t = sol_exp["Time [s]"].entries
    I_t = sol_exp["Current [A]"].entries
    Q_t = -sol_exp['Discharge capacity [A.h]'].entries
    Vt_t = sol_exp["Terminal voltage [V]"].entries
    exp_t = 30e6*sol_exp["Cell thickness change [m]"].entries
    idx = np.where(np.diff(np.sign(-I_t)))[0]
    I = I_t[idx[-1]:]
    t = t_t[idx[-1]:]-t_t[idx[-1]]
    Q = Q_t[idx[-1]:]-Q_t[idx[-1]]
    Vt = Vt_t[idx[-1]:]
    exp = exp_t[idx[-1]:]-exp_t[idx[-1]]
    I = I_t[idx[0]:]
    t = t_t[idx[0]:]-t_t[idx[0]]
    Q = Q_t[idx[0]:]-Q_t[idx[0]]
    Vt = Vt_t[idx[0]:]
    exp = exp_t[idx[0]:]-exp_t[idx[0]]
    # Q_filt = ((Q/max(Q))>0.15)
    # int_V = interpolate.CubicSpline(eSOH_data['Q'],eSOH_data['V'],extrapolate=True)
    # rmse_V = pybamm.rmse(Vt*Q_filt,int_V(Q)*Q_filt)
    # V_err = Vt*Q_filt-int_V(Q)*Q_filt
    # V_max_loc = np.argmax(abs(V_err))
    # V_err_Q = Q[V_max_loc]
    # V_err_max = V_err[V_max_loc]
    # if max(Q)<max(Q_d):
    #     int_V = interpolate.CubicSpline(Q_d,V_d,extrapolate=True)
    #     rmse_V = pybamm.rmse(Vt,int_V(Q))
    #     V_err = Vt-int_V(Q)
    #     max_V = abs(V_err[-2])
    #     V_max_loc = np.argmax(abs(V_err))
    #     V_err_Q = Q[V_max_loc]
    #     V_err_max = V_err[V_max_loc]
    #     Q_err = Q
    # else:
    #     int_V = interpolate.CubicSpline(Q,Vt,extrapolate=True)
    #     rmse_V = pybamm.rmse(V_d,int_V(Q_d))
    #     V_err = int_V(Q_d)-V_d
    #     max_V = abs(V_err[-2])
    #     V_max_loc = np.argmax(abs(V_err))
    #     V_err_Q = Q_d[V_max_loc]
    #     V_err_max = V_err[V_max_loc]
    rmse_V =0
    max_v = 0
    return t,Q,Vt,exp,rmse_V,max_V

i = 0
rmse_V_lc = []
titles = ["BOL","MOL","EOL"]
fig, axes = plt.subplots(1,3,figsize=(10,3))
for cyc_no in [0,int((len(N)+1)/2),len(N)-2]:

# for cyc_no in range(0,int((len(N)+1)/2),len(N)-1):
    # cyc_no=0
    print(cyc_no)
    t_d,V_d,I_d,Q_d = load_cycling_data(cell,eSOH_DIR,oCV_DIR,cyc_DIR,cyc_no)
    parameter_values.update(
    {
        "Positive electrode LAM constant proportional term [s-1]": par_val[1][0],
        "Negative electrode LAM constant proportional term [s-1]": par_val[1][1],
        "Positive electrode LAM constant exponential term": par_val[1][2],
        "Negative electrode LAM constant exponential term": par_val[1][2],
        "Lithium plating kinetic rate constant [m.s-1]": par_val[1][3],
    },
    check_already_exists=False,
    )
    t,Q,Vt,exp,rmse_V,max_V = cyc_comp(cyc_no,all_sumvars_dict,Q_d,V_d,parameter_values)
    parameter_values.update(
    {
        "Positive electrode LAM constant proportional term [s-1]": par_val[3][0],
        "Negative electrode LAM constant proportional term [s-1]": par_val[3][1],
        "Positive electrode LAM constant exponential term": par_val[3][2],
        "Negative electrode LAM constant exponential term": par_val[3][2],
        "Lithium plating kinetic rate constant [m.s-1]": par_val[3][3],
    },
    check_already_exists=False,
    )
    t2,Q2,Vt2,exp2,rmse_V2,max_V2 = cyc_comp(cyc_no,all_sumvars_dict1,Q_d,V_d,parameter_values)
    rmse_V_lc = np.append(rmse_V_lc,rmse_V)
    # if cyc_no in [0,int((len(N)+1)/2),len(N)-3]:
    ax2 = axes.flat[i]
    # ax2.plot(Q_d,V_d,'k',linewidth=1)
    # ax2.plot(Q,Vt,'b--',linewidth=1.5)
    # ax2.plot(Q2,Vt2,'r--',linewidth=1.5)
    ax2.set_ylim([3,4.21])
    # ax2.set_xlim([0,5.1])
    # ax2.set_xlabel('Q [Ah]')
    ax2.plot(t_d,V_d,'k',linewidth=1)
    ax2.plot(t,Vt,'b--',linewidth=1.5)
    # ax2.plot(t2,Vt2,'r--',linewidth=1.5)
    
    ax2.set_xlabel('Time [s]')
    # ax2.text(0.5,0.1,f'RMSE1: {rmse_V*1e3:0.1f} mV',transform=ax2.transAxes)
    # ax2.text(0.5,0.2,f'RMSE3: {rmse_V2*1e3:0.1f} mV',transform=ax2.transAxes)
    ax2.set_title('{}'.format(titles[i]))
    # if i ==0:
    ax2.legend(["Data","Sim",])
    ax2.set_ylabel('$V_t$ [Ah]')
        # ax1.set_ylabel('$\Delta$t [$\mu$m]')
    i+=1
fig.suptitle('Cell = '+cell_no)
fig.tight_layout()
# plt.savefig(fig_DIR +'plating_tuning_'+sim_des+'_'+cell_no+'_cyc_comp_cond.png')

dfgdfg

i = 0
rmse_V_lc = []
titles = ["BOL","MOL","EOL"]
fig, axes = plt.subplots(1,3,figsize=(10,3))
for cyc_no in [0,int((len(N)+1)/2),len(N)-2]:

# for cyc_no in range(0,int((len(N)+1)/2),len(N)-1):
    # cyc_no=0
    print(cyc_no)
    t_d,V_d,I_d,Q_d = load_cycling_data(cell,eSOH_DIR,oCV_DIR,cyc_DIR,cyc_no)
    parameter_values.update(
    {
        "Positive electrode LAM constant proportional term [s-1]": par_val[1][0],
        "Negative electrode LAM constant proportional term [s-1]": par_val[1][1],
        "Positive electrode LAM constant exponential term": par_val[1][2],
        "Negative electrode LAM constant exponential term": par_val[1][2],
        "Lithium plating kinetic rate constant [m.s-1]": par_val[1][3],
    },
    check_already_exists=False,
    )
    t,Q,Vt,exp,rmse_V,max_V = cyc_comp(cyc_no,all_sumvars_dict,Q_d,V_d,parameter_values)
    parameter_values.update(
    {
        "Positive electrode LAM constant proportional term [s-1]": par_val[3][0],
        "Negative electrode LAM constant proportional term [s-1]": par_val[3][1],
        "Positive electrode LAM constant exponential term": par_val[3][2],
        "Negative electrode LAM constant exponential term": par_val[3][2],
        "Lithium plating kinetic rate constant [m.s-1]": par_val[3][3],
    },
    check_already_exists=False,
    )
    t2,Q2,Vt2,exp2,rmse_V2,max_V2 = cyc_comp(cyc_no,all_sumvars_dict1,Q_d,V_d,parameter_values)
    rmse_V_lc = np.append(rmse_V_lc,rmse_V)
    # if cyc_no in [0,int((len(N)+1)/2),len(N)-3]:
    ax2 = axes.flat[i]
    ax2.plot(Q_d,V_d,'k',linewidth=1)
    ax2.plot(Q,Vt,'b--',linewidth=1.5)
    ax2.plot(Q2,Vt2,'r--',linewidth=1.5)
    ax2.set_ylim([3,4.2])
    ax2.set_xlim([0,5.1])
    ax2.set_xlabel('Q [Ah]')
    ax2.text(0.5,0.1,f'RMSE1: {rmse_V*1e3:0.1f} mV',transform=ax2.transAxes)
    ax2.text(0.5,0.2,f'RMSE3: {rmse_V2*1e3:0.1f} mV',transform=ax2.transAxes)
    ax2.set_title('{}'.format(titles[i]))
    # if i ==0:
    ax2.legend(["Data","Cond 1","Cond 3"])
    ax2.set_ylabel('$V_t$ [Ah]')
        # ax1.set_ylabel('$\Delta$t [$\mu$m]')
    i+=1
fig.suptitle('Cell = '+cell_no)
fig.tight_layout()
plt.savefig(fig_DIR +'plating_tuning_'+sim_des+'_'+cell_no+'_cyc_comp_cond.png')

spm.variables.search("Resistance")

fdgfdgfdgfg

experiment_rev_exp = pybamm.Experiment(
    [
        "Discharge at "+'C/20'+" until 3V",
        "Rest for 60 min",
        "Charge at "+'C/20'+" until 4.2V", 
        # "Hold at 4.2V until C/50"
    ],
)
Ns = np.insert(N[1:]-1,0,0)

def rev_exp(cyc_no,eSOH,eSOH_data,parameter_values):
    # dfo = dfo_0[dfo_0['N']==N[cyc_no]]
    model = spm
    Vmin = 3.0
    Vmax = 4.2
    esoh_model = pybamm.lithium_ion.ElectrodeSOH()
    esoh_sim = pybamm.Simulation(esoh_model, parameter_values=parameter_values)
    param = model.param
    Cn = eSOH["C_n"][Ns[cyc_no]]
    # print(Cn)
    Cp = eSOH["C_p"][Ns[cyc_no]]
    c_n_max = parameter_values.evaluate(param.n.prim.c_max)
    c_p_max = parameter_values.evaluate(param.p.prim.c_max)
    n_Li_init = eSOH["Total lithium in particles [mol]"][Ns[cyc_no]]
    eps_n_data = parameter_values.evaluate(Cn*3600/(param.n.L * param.n.prim.c_max * param.F* param.A_cc))
    eps_p_data = parameter_values.evaluate(Cp*3600/(param.p.L * param.p.prim.c_max * param.F* param.A_cc))

    esoh_sol = esoh_sim.solve(
        [0],
        inputs={"V_min": Vmin, "V_max": Vmax, "C_n": Cn, "C_p": Cp, "n_Li": n_Li_init},
        solver=pybamm.AlgebraicSolver(),
    )

    parameter_values.update(
        {
            "Initial concentration in negative electrode [mol.m-3]": esoh_sol[
       "x_100"
            ].data[0]
            * c_n_max,
            "Initial concentration in positive electrode [mol.m-3]": esoh_sol[
                "y_100"
            ].data[0]
            * c_p_max,
            "Negative electrode active material volume fraction": eps_n_data,
            "Positive electrode active material volume fraction": eps_p_data,
            "Initial temperature [K]": 273.15+25,
            "Ambient temperature [K]": 273.15+25,
            
        }
    )

    sim_exp = pybamm.Simulation(
        model, experiment=experiment_rev_exp, parameter_values=parameter_values,
        solver=pybamm.CasadiSolver("safe")
    )
    sol_exp = sim_exp.solve()
    t_t = sol_exp["Time [min]"].entries
    I_t = sol_exp["Current [A]"].entries
    Q_t = -sol_exp['Discharge capacity [A.h]'].entries
    Vt_t = sol_exp["Terminal voltage [V]"].entries
    exp_t = 30e6*sol_exp["Cell thickness change [m]"].entries
    idx = np.where(np.diff(np.sign(I_t)))[0]
    I = I_t[idx[-1]:]
    t = t_t[idx[-1]:]-t_t[idx[-1]]
    Q = Q_t[idx[-1]:]-Q_t[idx[-1]]
    Vt = Vt_t[idx[-1]:]
    exp = exp_t[idx[-1]:]-exp_t[idx[-1]]
    # Q_filt = ((Q/max(Q))>0.15)
    # int_V = interpolate.CubicSpline(eSOH_data['Q'],eSOH_data['V'],extrapolate=True)
    # rmse_V = pybamm.rmse(Vt*Q_filt,int_V(Q)*Q_filt)
    # V_err = Vt*Q_filt-int_V(Q)*Q_filt
    # V_max_loc = np.argmax(abs(V_err))
    # V_err_Q = Q[V_max_loc]
    # V_err_max = V_err[V_max_loc]
    if max(Q)<max(eSOH_data['Q']):
        int_V = interpolate.CubicSpline(eSOH_data['Q'],eSOH_data['V'],extrapolate=True)
        rmse_V = pybamm.rmse(Vt,int_V(Q))
        V_err = Vt-int_V(Q)
        max_V = abs(V_err[-2])
        V_max_loc = np.argmax(abs(V_err))
        V_err_Q = Q[V_max_loc]
        V_err_max = V_err[V_max_loc]
        int_E = interpolate.CubicSpline(eSOH_data['Q'],eSOH_data['E']-eSOH_data['E'].iloc[0],extrapolate=True)
        rmse_E = pybamm.rmse(exp,int_E(Q))
        E_err = exp-int_E(Q)
        max_E = abs(E_err[-2])
        E_max_loc = np.argmax(abs(E_err))
        E_err_Q = Q[E_max_loc]
        E_err_max = E_err[E_max_loc]
        Q_err = Q
    else:
        int_V = interpolate.CubicSpline(Q,Vt,extrapolate=True)
        rmse_V = pybamm.rmse(eSOH_data['V'],int_V(eSOH_data['Q']))
        V_err = int_V(eSOH_data['Q'])-eSOH_data['V']
        max_V = abs(V_err.iloc[-2])
        V_max_loc = np.argmax(abs(V_err))
        V_err_Q = eSOH_data['Q'].iloc[V_max_loc]
        V_err_max = V_err.iloc[V_max_loc]
        int_E = interpolate.CubicSpline(Q,exp,extrapolate=True)
        rmse_E = pybamm.rmse(eSOH_data['E']-eSOH_data['E'].iloc[0],int_E(eSOH_data['Q']))
        E_err = int_E(eSOH_data['Q'])-eSOH_data['E']+eSOH_data['E'].iloc[0]
        max_E = abs(E_err.iloc[-2])
        E_max_loc = np.argmax(abs(E_err))
        E_err_Q = eSOH_data['Q'].iloc[E_max_loc]
        E_err_max = E_err.iloc[E_max_loc]
        Q_err = eSOH_data['Q']
    return Q,Vt,exp,rmse_V,rmse_E,max_V,max_E

i = 0
rmse_V_l = []
rmse_E_l = []
max_V_l = []
max_E_l = []
fig, axes = plt.subplots(2,3,figsize=(10,6))
for cyc_no in [0,int((len(N)+1)/2),len(N)-1]:
# for cyc_no in range(0,int((len(N)+1)/2),len(N)-1):
    # cyc_no=0
    print(cyc_no)
    dfo = dfo_0[dfo_0['N']==N_0[cyc_no+1]]
    parameter_values.update(
    {
        "Positive electrode LAM constant proportional term [s-1]": par_val[1][0],
        "Negative electrode LAM constant proportional term [s-1]": par_val[1][1],
        "Positive electrode LAM constant exponential term": par_val[1][2],
        "Negative electrode LAM constant exponential term": par_val[1][2],
        "Lithium plating kinetic rate constant [m.s-1]": par_val[1][3],
    },
    check_already_exists=False,
    )
    Q,Vt,exp,rmse_V,rmse_E,max_V,max_E = rev_exp(cyc_no,all_sumvars_dict,dfo,parameter_values)
    parameter_values.update(
    {
        "Positive electrode LAM constant proportional term [s-1]": par_val[3][0],
        "Negative electrode LAM constant proportional term [s-1]": par_val[3][1],
        "Positive electrode LAM constant exponential term": par_val[3][2],
        "Negative electrode LAM constant exponential term": par_val[3][2],
        "Lithium plating kinetic rate constant [m.s-1]": par_val[3][3],
    },
    check_already_exists=False,
    )
    Q2,Vt2,exp2,rmse_V2,rmse_E2,max_V2,max_E2 = rev_exp(cyc_no,all_sumvars_dict1,dfo,parameter_values)
    rmse_V_l = np.append(rmse_V_l,rmse_V)
    rmse_E_l = np.append(rmse_E_l,rmse_E)
    max_V_l = np.append(max_V_l,max_V)
    max_E_l = np.append(max_E_l,max_E)
    # if cyc_no in [0,int((len(N)+1)/2),len(N)-3]:
    ax1 = axes.flat[i]
    ax1.plot(dfo['Q'],dfo['E']-dfo['E'].iloc[0],'k',linewidth=1)
    ax1.plot(Q,exp,'b--',linewidth=1.5)
    ax1.plot(Q2,exp2,'r--',linewidth=1.5)
    ax1.set_ylim([0,110])
    ax1.set_xlim([0,5.1])
    ax1.set_xticklabels([])
    ax1.set_title('N = {}'.format(N[cyc_no]))
    ax1.text(0.1,0.9,f'RMSE: {rmse_E:0.1f} $\mu$m',transform=ax1.transAxes)
    ax2 = axes.flat[i+3]
    ax2.plot(dfo['Q'],dfo['V'],'k',linewidth=1)
    ax2.plot(Q,Vt,'b--',linewidth=1.5)
    ax2.plot(Q2,Vt2,'r--',linewidth=1.5)
    ax2.set_ylim([3,4.2])
    ax2.set_xlim([0,5.1])
    ax2.set_xlabel('Q [Ah]')
    ax2.text(0.5,0.1,f'RMSE1: {rmse_V*1e3:0.1f} mV',transform=ax2.transAxes)
    ax2.text(0.5,0.2,f'RMSE3: {rmse_V2*1e3:0.1f} mV',transform=ax2.transAxes)
    if i ==0:
        ax2.set_ylabel('$V_t$ [Ah]')
        ax1.set_ylabel('$\Delta$t [$\mu$m]')
    i+=1
fig.suptitle('Cell = '+cell_no)
fig.tight_layout()
plt.savefig(fig_DIR +'plating_tuning_'+sim_des+'_'+cell_no+'_cond.png')

print(np.round(rmse_V_l*1000,1))
print(np.round(rmse_V_lc*1000,1))
err_c20 = np.round(rmse_V_l*1000,1)
err_cyc = np.round(rmse_V_lc*1000,1)

col_names = ["cell","cond","c20_BOL","c20_MOL","c20_EOL","cyc_BOL","cyc_MOL","cyc_EOL"]
df_x = pd.DataFrame(columns=col_names, index=range(1))
df_x["cell"]=cell
df_x["cond"]=sno
df_x["c20_BOL"]=err_c20[0]
df_x["c20_MOL"]=err_c20[1]
df_x["c20_EOL"]=err_c20[2]
df_x["cyc_BOL"]=err_cyc[0]
df_x["cyc_MOL"]=err_cyc[1]
df_x["cyc_EOL"]=err_cyc[2]


df_x.to_csv("errors.csv", mode='a', index=False, header=False)

winsound.Beep(440, 2000)

xcxzx

def diff_analysis(cyc_no,eSOH,eSOH_data):
    model = spm
    Vmin = 3.0
    Vmax = 4.2
    esoh_model = pybamm.lithium_ion.ElectrodeSOH()
    esoh_sim = pybamm.Simulation(esoh_model, parameter_values=parameter_values)
    param = model.param
    Cn = eSOH["C_n"][Ns[cyc_no]]
    # print(Cn)
    Cp = eSOH["C_p"][Ns[cyc_no]]
    c_n_max = parameter_values.evaluate(param.n.prim.c_max)
    c_p_max = parameter_values.evaluate(param.p.prim.c_max)
    n_Li_init = eSOH["Total lithium in particles [mol]"][Ns[cyc_no]]
    eps_n_data = parameter_values.evaluate(Cn*3600/(param.n.L * param.n.prim.c_max * param.F* param.A_cc))
    eps_p_data = parameter_values.evaluate(Cp*3600/(param.p.L * param.p.prim.c_max * param.F* param.A_cc))

    esoh_sol = esoh_sim.solve(
        [0],
        inputs={"V_min": Vmin, "V_max": Vmax, "C_n": Cn, "C_p": Cp, "n_Li": n_Li_init},
        solver=pybamm.AlgebraicSolver(),
    )

    parameter_values.update(
        {
            "Initial concentration in negative electrode [mol.m-3]": esoh_sol[
       "x_100"
            ].data[0]
            * c_n_max,
            "Initial concentration in positive electrode [mol.m-3]": esoh_sol[
                "y_100"
            ].data[0]
            * c_p_max,
            "Negative electrode active material volume fraction": eps_n_data,
            "Positive electrode active material volume fraction": eps_p_data,
            "Initial temperature [K]": 273.15+25,
            "Ambient temperature [K]": 273.15+25,
            
        }
    )

    sim_exp = pybamm.Simulation(
        model, experiment=experiment_rev_exp, parameter_values=parameter_values,
        solver=pybamm.CasadiSolver("safe")
    )
    sol_exp = sim_exp.solve()
    t_t = sol_exp["Time [min]"].entries
    I_t = sol_exp["Current [A]"].entries
    Q_t = -sol_exp['Discharge capacity [A.h]'].entries
    Vt_t = sol_exp["Terminal voltage [V]"].entries
    exp_t = 30e6*sol_exp["Cell thickness change [m]"].entries
    idx = np.where(np.diff(np.sign(I_t)))[0]
    I = I_t[idx[-1]:]
    t = t_t[idx[-1]:]-t_t[idx[-1]]
    Q = Q_t[idx[-1]:]-Q_t[idx[-1]]
    Vt = Vt_t[idx[-1]:]
    exp = exp_t[idx[-1]:]-exp_t[idx[-1]]

    window_length=501
    polyorder=5
    Qf_d = savgol_filter(eSOH_data['Q'],window_length,polyorder)
    dQ_d = savgol_filter(eSOH_data['Q'],window_length,polyorder,1)
    Vf_d = savgol_filter(eSOH_data['V'],window_length,polyorder)
    dV_d = savgol_filter(eSOH_data['V'],window_length,polyorder,1)
    window_length=1701
    polyorder=3
    Ef_d = savgol_filter(eSOH_data['E']-eSOH_data['E'].iloc[0],window_length,polyorder)
    dE2_d = savgol_filter(Ef_d,window_length,polyorder,2)
    window_length=51
    polyorder=5
    Qf_s = savgol_filter(Q,window_length,polyorder)
    dQ_s = savgol_filter(Q,window_length,polyorder,1)
    Vf_s = savgol_filter(Vt,window_length,polyorder)
    dV_s = savgol_filter(Vt,window_length,polyorder,1)
    window_length=301
    polyorder=3
    Ef_s = savgol_filter(exp,window_length,polyorder)
    dE2_s = savgol_filter(exp,window_length,polyorder,2)
    dE2_s = savgol_filter(Ef_s,window_length,polyorder,2)

    dVdQ_d = dV_d/dQ_d
    dVdQf_d = dVdQ_d*(Qf_d/max(Qf_d)<0.8)
    dV_peaks_d,_ = find_peaks(dVdQf_d,height=0.16,width=0.1,prominence=0.0005)
    dV_peaks_d = dV_peaks_d[-3:]
    dV_peaks_d = dV_peaks_d[:-1]
    dVdQ_s = dV_s/dQ_s
    dVdQf_s = dVdQ_s*(dVdQ_s>0.16)
    dV_peaks_s,_ = find_peaks(dVdQf_s,height=0.1,width=0.1,prominence=0.01)
    dV_peaks_s = dV_peaks_s[-2:]  

    dQdV_d = dQ_d/dV_d
    dQdV_s = dQ_s/dV_s

    dEdQ2_d = dE2_d/dQ_d/dQ_d
    dEdQ2_s = dE2_s/dQ_s/dQ_s

    dEdQf2_d = dEdQ2_d*(dEdQ2_d>10)
    dE_peaks_d,_ = find_peaks(dEdQf2_d,height=0.1,width=0.1,prominence=0.2)
    dEdQf2_s = dEdQ2_s*(dEdQ2_s>10)
    dE_peaks_s,_ = find_peaks(dEdQf2_s,height=0.1,width=0.1,prominence=0.2)
    loc_d = np.where(np.diff(np.sign(dEdQ2_d[0:dE_peaks_d[0]])))[0]
    dE_zero_d = loc_d[-1]
    loc_s = np.where(np.diff(np.sign(dEdQ2_s[0:dE_peaks_s[0]])))[0]
    dE_zero_s = loc_s[-1]


    dQdVf_d = dQdV_d*(dQdV_d>8)
    dQ_peaks_d,_ = find_peaks(dQdVf_d,height=0.1,width=0.1,prominence=0.2)
    dQdVf_s = dQdV_s*(dQdV_s>8)
    dQ_peaks_s,_ = find_peaks(dQdVf_s,height=0.1,width=0.1,prominence=0.2)

    plt.figure(figsize=[10,8])
    ax2 = plt.subplot(1,1,1)
    ax2.plot(Qf_d,dVdQ_d,'k')
    ax2.plot(Qf_d[dV_peaks_d],dVdQ_d[dV_peaks_d],'mx')
    ax2.plot(Qf_s,dVdQ_s,'r--')
    ax2.plot(Qf_s[dV_peaks_s],dVdQ_s[dV_peaks_s],'bx')
    peak1_err = (Qf_s[dV_peaks_s[0]]/Qf_s[-1])-(Qf_d[dV_peaks_d[0]]/Qf_d[-1])
    ax2.text(0.2,0.8,f'Peak 1 Err: {peak1_err:0.4f}',transform=ax2.transAxes)
    peak2_err = (Qf_s[dV_peaks_s[1]]/Qf_s[-1])-(Qf_d[dV_peaks_d[1]]/Qf_d[-1])
    ax2.text(0.6,0.8,f'Peak 2 Err: {peak2_err:0.4f}',transform=ax2.transAxes)
    ax2.set_title('dVdQ')
    ax2.set_ylabel('Differential Voltage [V/Ah]')
    ax2.set_ylim([0,0.5])
    ax2.set_xlim(left=0)
    ax2.set_xlim([0,5])
    ax2.axvline(x=Qf_d[dV_peaks_d[-2]],color='k', linestyle='--',linewidth=0.5,clip_on=False,ymin=0,ymax=1)
    ax2.axvline(x=Qf_d[dV_peaks_d[-1]],color='k', linestyle='--',linewidth=0.5,clip_on=False,ymin=0,ymax=1)
    ax2.axvline(x=Qf_s[dV_peaks_s[0]],color='r', linestyle='--',linewidth=0.5,clip_on=False,ymin=0,ymax=1)
    ax2.axvline(x=Qf_s[dV_peaks_s[1]],color='r', linestyle='--',linewidth=0.5,clip_on=False,ymin=0,ymax=1)
    plt.suptitle('Cell: '+cell_no+' Cycle No: '+str(N[cyc_no]))
    plt.tight_layout()
    plt.savefig(fig_DIR +'deg_sim_'+cell_no+'_cyc_'+str(N[cyc_no]))
    return plt


# i = 0
# for cyc_no in [0,int((len(N)+1)/2),len(N)-1]:
# # for cyc_no in [len(N)-1]:
#     # cyc_no=0
#     print(cyc_no)
#     dfo = dfo_0[dfo_0['N']==N_0[cyc_no+1]]
#     plt = diff_analysis(cyc_no,all_sumvars_dict,dfo)
#     # plt.close()
    

def diff_analysis_2(cyc_no,eSOH,eSOH_data):
    model = spm
    Vmin = 3.0
    Vmax = 4.2
    esoh_model = pybamm.lithium_ion.ElectrodeSOH()
    esoh_sim = pybamm.Simulation(esoh_model, parameter_values=parameter_values)
    param = model.param
    Cn = eSOH["C_n"][cyc_no]
    # print(Cn)
    Cp = eSOH["C_p"][cyc_no]
    c_n_max = parameter_values.evaluate(param.n.prim.c_max)
    c_p_max = parameter_values.evaluate(param.p.prim.c_max)
    n_Li_init = eSOH["n_Li"][cyc_no]
    eps_n_data = parameter_values.evaluate(Cn*3600/(param.n.L * param.n.prim.c_max * param.F* param.A_cc))
    eps_p_data = parameter_values.evaluate(Cp*3600/(param.p.L * param.p.prim.c_max * param.F* param.A_cc))

    esoh_sol = esoh_sim.solve(
        [0],
        inputs={"V_min": Vmin, "V_max": Vmax, "C_n": Cn, "C_p": Cp, "n_Li": n_Li_init},
        solver=pybamm.AlgebraicSolver(),
    )

    parameter_values.update(
        {
            "Initial concentration in negative electrode [mol.m-3]": esoh_sol[
       "x_100"
            ].data[0]
            * c_n_max,
            "Initial concentration in positive electrode [mol.m-3]": esoh_sol[
                "y_100"
            ].data[0]
            * c_p_max,
            "Negative electrode active material volume fraction": eps_n_data,
            "Positive electrode active material volume fraction": eps_p_data,
            "Initial temperature [K]": 273.15+25,
            "Ambient temperature [K]": 273.15+25,
            
        }
    )

    sim_exp = pybamm.Simulation(
        model, experiment=experiment_rev_exp, parameter_values=parameter_values,
        solver=pybamm.CasadiSolver("safe")
    )
    sol_exp = sim_exp.solve()
    t_t = sol_exp["Time [min]"].entries
    I_t = sol_exp["Current [A]"].entries
    Q_t = -sol_exp['Discharge capacity [A.h]'].entries
    Vt_t = sol_exp["Terminal voltage [V]"].entries
    exp_t = 30e6*sol_exp["Cell thickness change [m]"].entries
    idx = np.where(np.diff(np.sign(I_t)))[0]
    I = I_t[idx[-1]:]
    t = t_t[idx[-1]:]-t_t[idx[-1]]
    Q = Q_t[idx[-1]:]-Q_t[idx[-1]]
    Vt = Vt_t[idx[-1]:]
    exp = exp_t[idx[-1]:]-exp_t[idx[-1]]

    window_length=501
    polyorder=5
    Qf_d = savgol_filter(eSOH_data['Q'],window_length,polyorder)
    dQ_d = savgol_filter(eSOH_data['Q'],window_length,polyorder,1)
    Vf_d = savgol_filter(eSOH_data['V'],window_length,polyorder)
    dV_d = savgol_filter(eSOH_data['V'],window_length,polyorder,1)
    window_length=1701
    polyorder=3
    Ef_d = savgol_filter(eSOH_data['E']-eSOH_data['E'].iloc[0],window_length,polyorder)
    dE2_d = savgol_filter(Ef_d,window_length,polyorder,2)
    window_length=51
    polyorder=5
    Qf_s = savgol_filter(Q,window_length,polyorder)
    dQ_s = savgol_filter(Q,window_length,polyorder,1)
    Vf_s = savgol_filter(Vt,window_length,polyorder)
    dV_s = savgol_filter(Vt,window_length,polyorder,1)
    window_length=301
    polyorder=3
    Ef_s = savgol_filter(exp,window_length,polyorder)
    dE2_s = savgol_filter(exp,window_length,polyorder,2)
    dE2_s = savgol_filter(Ef_s,window_length,polyorder,2)

    dVdQ_d = dV_d/dQ_d
    dVdQf_d = dVdQ_d*(Qf_d/max(Qf_d)<0.8)
    dV_peaks_d,_ = find_peaks(dVdQf_d,height=0.16,width=0.1,prominence=0.0005)
    dV_peaks_d = dV_peaks_d[-3:]
    dV_peaks_d = dV_peaks_d[:-1]
    dVdQ_s = dV_s/dQ_s
    dVdQf_s = dVdQ_s*(dVdQ_s>0.16)
    dV_peaks_s,_ = find_peaks(dVdQf_s,height=0.1,width=0.1,prominence=0.01)
    dV_peaks_s = dV_peaks_s[-2:]  

    dQdV_d = dQ_d/dV_d
    dQdV_s = dQ_s/dV_s

    dEdQ2_d = dE2_d/dQ_d/dQ_d
    dEdQ2_s = dE2_s/dQ_s/dQ_s

    dEdQf2_d = dEdQ2_d*(dEdQ2_d>10)
    dE_peaks_d,_ = find_peaks(dEdQf2_d,height=0.1,width=0.1,prominence=0.2)
    dEdQf2_s = dEdQ2_s*(dEdQ2_s>10)
    dE_peaks_s,_ = find_peaks(dEdQf2_s,height=0.1,width=0.1,prominence=0.2)
    loc_d = np.where(np.diff(np.sign(dEdQ2_d[0:dE_peaks_d[0]])))[0]
    dE_zero_d = loc_d[-1]
    loc_s = np.where(np.diff(np.sign(dEdQ2_s[0:dE_peaks_s[0]])))[0]
    dE_zero_s = loc_s[-1]


    dQdVf_d = dQdV_d*(dQdV_d>8)
    dQ_peaks_d,_ = find_peaks(dQdVf_d,height=0.1,width=0.1,prominence=0.2)
    dQdVf_s = dQdV_s*(dQdV_s>8)
    dQ_peaks_s,_ = find_peaks(dQdVf_s,height=0.1,width=0.1,prominence=0.2)

    plt.figure(figsize=[5,4])
    ax2 = plt.subplot(1,1,1)
    ax2.plot(Qf_d,dVdQ_d,'k')
    ax2.plot(Qf_d[dV_peaks_d],dVdQ_d[dV_peaks_d],'mx')
    ax2.plot(Qf_s,dVdQ_s,'r--')
    ax2.plot(Qf_s[dV_peaks_s],dVdQ_s[dV_peaks_s],'bx')
    peak1_err = (Qf_s[dV_peaks_s[0]]/Qf_s[-1])-(Qf_d[dV_peaks_d[0]]/Qf_d[-1])
    ax2.text(0.2,0.8,f'Peak 1 Err: {peak1_err:0.4f}',transform=ax2.transAxes)
    peak2_err = (Qf_s[dV_peaks_s[1]]/Qf_s[-1])-(Qf_d[dV_peaks_d[1]]/Qf_d[-1])
    ax2.text(0.6,0.8,f'Peak 2 Err: {peak2_err:0.4f}',transform=ax2.transAxes)
    ax2.set_title('dVdQ')
    ax2.set_ylabel('Differential Voltage [V/Ah]')
    ax2.set_ylim([0,0.5])
    ax2.set_xlim(left=0)
    ax2.set_xlim([0,5])
    ax2.axvline(x=Qf_d[dV_peaks_d[-2]],color='k', linestyle='--',linewidth=0.5,clip_on=False,ymin=0,ymax=1)
    ax2.axvline(x=Qf_d[dV_peaks_d[-1]],color='k', linestyle='--',linewidth=0.5,clip_on=False,ymin=0,ymax=1)
    ax2.axvline(x=Qf_s[dV_peaks_s[0]],color='r', linestyle='--',linewidth=0.5,clip_on=False,ymin=0,ymax=1)
    ax2.axvline(x=Qf_s[dV_peaks_s[1]],color='r', linestyle='--',linewidth=0.5,clip_on=False,ymin=0,ymax=1)
    plt.suptitle('Cell: '+cell_no+' Cycle No: '+str(N[cyc_no]))
    plt.tight_layout()
    plt.savefig(fig_DIR +'deg_sim_data_'+cell_no+'_cyc_'+str(N[cyc_no]))
    return plt


i = 0
for cyc_no in [0,int((len(N)+1)/2),len(N)-1]:
# for cyc_no in [len(N)-1]:
    # cyc_no=0
    print(cyc_no)
    dfo = dfo_0[dfo_0['N']==N_0[cyc_no+1]]
    plt = diff_analysis_2(cyc_no,dfe,dfo)
    # plt.close()
    

def rev_exp_2(cyc_no,eSOH,eSOH_data):
    # dfo = dfo_0[dfo_0['N']==N[cyc_no]]
    model = spm
    Vmin = 3.0
    Vmax = 4.2
    esoh_model = pybamm.lithium_ion.ElectrodeSOH()
    esoh_sim = pybamm.Simulation(esoh_model, parameter_values=parameter_values)
    param = model.param
    Cn = eSOH["C_n"][cyc_no]
    # print(Cn)
    Cp = eSOH["C_p"][cyc_no]
    c_n_max = parameter_values.evaluate(param.n.prim.c_max)
    c_p_max = parameter_values.evaluate(param.p.prim.c_max)
    n_Li_init = eSOH["n_Li"][cyc_no]
    eps_n_data = parameter_values.evaluate(Cn*3600/(param.n.L * param.n.prim.c_max * param.F* param.A_cc))
    eps_p_data = parameter_values.evaluate(Cp*3600/(param.p.L * param.p.prim.c_max * param.F* param.A_cc))

    esoh_sol = esoh_sim.solve(
        [0],
        inputs={"V_min": Vmin, "V_max": Vmax, "C_n": Cn, "C_p": Cp, "n_Li": n_Li_init},
        solver=pybamm.AlgebraicSolver(),
    )

    parameter_values.update(
        {
            "Initial concentration in negative electrode [mol.m-3]": esoh_sol[
       "x_100"
            ].data[0]
            * c_n_max,
            "Initial concentration in positive electrode [mol.m-3]": esoh_sol[
                "y_100"
            ].data[0]
            * c_p_max,
            "Negative electrode active material volume fraction": eps_n_data,
            "Positive electrode active material volume fraction": eps_p_data,
            "Initial temperature [K]": 273.15+25,
            "Ambient temperature [K]": 273.15+25,
            
        }
    )

    sim_exp = pybamm.Simulation(
        model, experiment=experiment_rev_exp, parameter_values=parameter_values,
        solver=pybamm.CasadiSolver("safe")
    )
    sol_exp = sim_exp.solve()
    t_t = sol_exp["Time [min]"].entries
    I_t = sol_exp["Current [A]"].entries
    Q_t = -sol_exp['Discharge capacity [A.h]'].entries
    Vt_t = sol_exp["Terminal voltage [V]"].entries
    exp_t = 30e6*sol_exp["Cell thickness change [m]"].entries
    idx = np.where(np.diff(np.sign(I_t)))[0]
    I = I_t[idx[-1]:]
    t = t_t[idx[-1]:]-t_t[idx[-1]]
    Q = Q_t[idx[-1]:]-Q_t[idx[-1]]
    Vt = Vt_t[idx[-1]:]
    exp = exp_t[idx[-1]:]-exp_t[idx[-1]]
    # Q_filt = ((Q/max(Q))>0.15)
    # int_V = interpolate.CubicSpline(eSOH_data['Q'],eSOH_data['V'],extrapolate=True)
    # rmse_V = pybamm.rmse(Vt*Q_filt,int_V(Q)*Q_filt)
    # V_err = Vt*Q_filt-int_V(Q)*Q_filt
    # V_max_loc = np.argmax(abs(V_err))
    # V_err_Q = Q[V_max_loc]
    # V_err_max = V_err[V_max_loc]
    if max(Q)<max(eSOH_data['Q']):
        int_V = interpolate.CubicSpline(eSOH_data['Q'],eSOH_data['V'],extrapolate=True)
        rmse_V = pybamm.rmse(Vt,int_V(Q))
        V_err = Vt-int_V(Q)
        max_V = abs(V_err[-2])
        V_max_loc = np.argmax(abs(V_err))
        V_err_Q = Q[V_max_loc]
        V_err_max = V_err[V_max_loc]
        int_E = interpolate.CubicSpline(eSOH_data['Q'],eSOH_data['E']-eSOH_data['E'].iloc[0],extrapolate=True)
        rmse_E = pybamm.rmse(exp,int_E(Q))
        E_err = exp-int_E(Q)
        max_E = abs(E_err[-2])
        E_max_loc = np.argmax(abs(E_err))
        E_err_Q = Q[E_max_loc]
        E_err_max = E_err[E_max_loc]
        Q_err = Q
    else:
        int_V = interpolate.CubicSpline(Q,Vt,extrapolate=True)
        rmse_V = pybamm.rmse(eSOH_data['V'],int_V(eSOH_data['Q']))
        V_err = int_V(eSOH_data['Q'])-eSOH_data['V']
        max_V = abs(V_err.iloc[-2])
        V_max_loc = np.argmax(abs(V_err))
        V_err_Q = eSOH_data['Q'].iloc[V_max_loc]
        V_err_max = V_err.iloc[V_max_loc]
        int_E = interpolate.CubicSpline(Q,exp,extrapolate=True)
        rmse_E = pybamm.rmse(eSOH_data['E']-eSOH_data['E'].iloc[0],int_E(eSOH_data['Q']))
        E_err = int_E(eSOH_data['Q'])-eSOH_data['E']+eSOH_data['E'].iloc[0]
        max_E = abs(E_err.iloc[-2])
        E_max_loc = np.argmax(abs(E_err))
        E_err_Q = eSOH_data['Q'].iloc[E_max_loc]
        E_err_max = E_err.iloc[E_max_loc]
        Q_err = eSOH_data['Q']
    return Q,Vt,exp,rmse_V,rmse_E,max_V,max_E

i = 0
rmse_V_l = []
rmse_E_l = []
max_V_l = []
max_E_l = []
fig, axes = plt.subplots(2,3,figsize=(10,6))
for cyc_no in [0,int((len(N)+1)/2),len(N)-1]:
# for cyc_no in range(0,int((len(N)+1)/2),len(N)-1):
    # cyc_no=0
    print(cyc_no)
    dfo = dfo_0[dfo_0['N']==N_0[cyc_no+1]]
    Q,Vt,exp,rmse_V,rmse_E,max_V,max_E = rev_exp_2(cyc_no,dfe,dfo)
    rmse_V_l = np.append(rmse_V_l,rmse_V)
    rmse_E_l = np.append(rmse_E_l,rmse_E)
    max_V_l = np.append(max_V_l,max_V)
    max_E_l = np.append(max_E_l,max_E)
    # if cyc_no in [0,int((len(N)+1)/2),len(N)-3]:
    ax1 = axes.flat[i]
    ax1.plot(dfo['Q'],dfo['E']-dfo['E'].iloc[0],'k',linewidth=1)
    ax1.plot(Q,exp,'b--',linewidth=1.5)
    ax1.set_ylim([0,110])
    ax1.set_xlim([0,5.1])
    ax1.set_xticklabels([])
    ax1.set_title('N = {}'.format(N[cyc_no]))
    ax1.text(0.1,0.9,f'RMSE: {rmse_E:0.1f} $\mu$m',transform=ax1.transAxes)
    ax2 = axes.flat[i+3]
    ax2.plot(dfo['Q'],dfo['V'],'k',linewidth=1)
    ax2.plot(Q,Vt,'b--',linewidth=1.5)
    ax2.set_ylim([3,4.2])
    ax2.set_xlim([0,5.1])
    ax2.set_xlabel('Q [Ah]')
    ax2.text(0.5,0.1,f'RMSE: {rmse_V*1e3:0.1f} mV',transform=ax2.transAxes)
    if i ==0:
        ax2.set_ylabel('$V_t$ [Ah]')
        ax1.set_ylabel('$\Delta$t [$\mu$m]')
    i+=1
fig.suptitle('Cell = '+cell_no)
fig.tight_layout()
plt.savefig(fig_DIR +'volt_exp_data_'+cell_no+'_CLi.png')
